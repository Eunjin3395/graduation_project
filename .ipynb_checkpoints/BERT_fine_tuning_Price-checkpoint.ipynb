# %%
#tensorflow 버전 확인
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# GPU 사용하는 경우, device list에 GPU 있는지 확인
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6275398496062487145
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7799308288
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3014703086911239912
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
#필요한 모듈 불러오기
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification,utils

# attention mask 시각화를 위한 모듈
from bertviz import model_view
utils.logging.set_verbosity_error()

from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd

from tabulate import tabulate
from tqdm import trange
import random
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')


print("GPU available:",torch.cuda.is_available())
# Out:
# GPU available: True

# %%
def printNpRatio(df):
    neg = len(df[df['polarity'] == 0])
    pos=len(df[df['polarity'] == 1])
    print("positive: {}, negative: {}".format(pos,neg))
    print("positive {:.4f}, negative {:.4f}".format(pos/(pos+neg),neg/(pos+neg)))
    
def printLenStat(df,colName):
    lendf = pd.DataFrame()
    lendf['length'] = df[colName].apply(len)
    print(lendf.length.describe())

# %%
# data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
# Price 속성 리뷰
url='./data/price_total.csv'
df = pd.read_csv(url,sep=',', header=0, encoding_errors='ignore')
df.head(5)
# Out:
#           id                                               text category  \
# 0  1476493:3  When you add it all together, it just doesn't ...    price
# 1       2156     The bagels are also reasonably priced for NYC.    price
# 2       2424                It's true, this place is not cheap.    price
# 3      Z#3:2   I paid just about $60 for a good meal, though :)    price
# 4       2645  BUt their best dish is thh Thai spiced curry n...    price
#
#    polarity
# 0         0
# 1         1
# 2         0
# 3         1
# 4         1

# %%
printNpRatio(df)
print()
printLenStat(df,'text')
# Out:
# positive: 216, negative: 184
# positive 0.5400, negative 0.4600
#
# count    400.000000
# mean      79.477500
# std       47.393616
# min        6.000000
# 25%       47.000000
# 50%       70.000000
# 75%      102.000000
# max      370.000000
# Name: length, dtype: float64

# %%
text = df.text.values
labels = df.polarity.values

# %%
# 전처리를 위한 tokenizer 불러오기
tokenizer = BertTokenizer.from_pretrained(
    'bert-base-uncased',
    do_lower_case = True
    )

# %%
#전처리
MAX_LENGTH=150
token_id = []
attention_masks = []

def preprocessing(input_text, tokenizer,max_len_input=MAX_LENGTH):
  '''
  Returns <class transformers.tokenization_utils_base.BatchEncoding> with the following fields:
    - input_ids: list of token ids
    - token_type_ids: list of token type ids
    - attention_mask: list of indices (0,1) specifying which tokens should considered by the model (return_attention_mask = True).
  '''
  return tokenizer.encode_plus(
                        input_text,
                        add_special_tokens = True,
                        max_length = max_len_input,
                        pad_to_max_length = True,
                        return_attention_mask = True,
                        return_tensors = 'pt',
                        truncation=True
                   )


for sample in text:
  encoding_dict = preprocessing(sample, tokenizer)

  # token_id 리스트 추출
  token_id.append(encoding_dict['input_ids']) 
  # attention_mask 리스트 추출
  attention_masks.append(encoding_dict['attention_mask'])


# 리스트를 텐서로
token_id = torch.cat(token_id, dim = 0)
attention_masks = torch.cat(attention_masks, dim = 0)
labels = torch.tensor(labels)

# %%
#데이터 train set, validation set 분리
VAL_RATIO= 0.2
batch_size = 8 

# Indices of the train and validation splits stratified by labels
train_idx, val_idx = train_test_split(
    np.arange(len(labels)),
    test_size = VAL_RATIO,
    shuffle = True,
    stratify = labels)

# Train and validation sets
train_set = TensorDataset(token_id[train_idx], 
                          attention_masks[train_idx], 
                          labels[train_idx])

val_set = TensorDataset(token_id[val_idx], 
                        attention_masks[val_idx], 
                        labels[val_idx])

# Prepare DataLoader
train_dataloader = DataLoader(
            train_set,
            sampler = RandomSampler(train_set),
            batch_size = batch_size
        )

validation_dataloader = DataLoader(
            val_set,
            sampler = SequentialSampler(val_set),
            batch_size = batch_size
        )


print("train: {}".format(len(train_idx)))
print("validation: {}".format(len(val_idx)))
# Out:
# train: 320
# validation: 80

# %%
def b_tp(preds, labels):
  '''Returns True Positives (TP): count of correct predictions of actual class 1'''
  return sum([preds == labels and preds == 1 for preds, labels in zip(preds, labels)])

def b_tn(preds, labels):
  '''Returns True Negatives (TN): count of correct predictions of actual class 0'''
  return sum([preds == labels and preds == 0 for preds, labels in zip(preds, labels)])


def b_metrics(preds, labels):
  '''
  Returns the following metrics:
    - accuracy    = (TP + TN) / N

  '''
  preds = np.argmax(preds, axis = 1).flatten()
  labels = labels.flatten()
  tp = b_tp(preds, labels)
  tn = b_tn(preds, labels)
  b_accuracy = (tp + tn) / len(labels)

  return b_accuracy

# %%
# BERT 모델 불러오기
model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels = 2,
    output_attentions = True,
    output_hidden_states = False,
)


optimizer = torch.optim.AdamW(model.parameters(), 
                              lr = 5e-5, # learning rate 설정
                              eps = 1e-08
                              )


# GPU 확인 및 할당
if torch.cuda.is_available():
    device=torch.device('cuda')
    print("GPU available.")
else:
    device=torch.device("cpu")
    print("No GPU available, using CPU instead.")


#model.cuda()
model.to(device)
# Out:
# GPU available.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# GPU로 학습하도록 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 학습 횟수 설정
epochs = 15

idx=0
epo_list=[]
train_loss_list=[]
val_accuracy_list=[]

for _ in trange(epochs, desc = 'Epoch'):
    idx+=1
    epo_list.append(idx)

    # ========== Training ==========
    model.train()
    
    # Tracking variables
    tr_loss = 0
    nb_tr_examples, nb_tr_steps = 0, 0

    for step, batch in enumerate(train_dataloader):
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch
        optimizer.zero_grad()
        # Forward pass
        train_output = model(b_input_ids, 
                             token_type_ids = None, 
                             attention_mask = b_input_mask, 
                             labels = b_labels)
        # Backward pass
        train_output.loss.backward()
        optimizer.step()
        # Update tracking variables
        tr_loss += train_output.loss.item()
        nb_tr_examples += b_input_ids.size(0)
        nb_tr_steps += 1

    # ========== Validation ==========
    model.eval()

    # Tracking variables 
    val_accuracy = []
    val_precision = []
    val_recall = []
    val_specificity = []

    for batch in validation_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
          # Forward pass
          eval_output = model(b_input_ids, 
                              token_type_ids = None, 
                              attention_mask = b_input_mask)
        logits = eval_output.logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        # Calculate validation metrics
        b_accuracy = b_metrics(logits, label_ids)
        val_accuracy.append(b_accuracy)
        
        

    print('\n\t - Train loss: {:.4f}'.format(tr_loss / nb_tr_steps))
    print('\t - Validation Accuracy: {:.4f}'.format(sum(val_accuracy)/len(val_accuracy)))
    val_accuracy_temp=sum(val_accuracy)/len(val_accuracy)
    train_loss_list.append(round(tr_loss / nb_tr_steps,4))
    val_accuracy_list.append(round(val_accuracy_temp,4))
# Out:
# Epoch:   7%|█████                                                                       | 1/15 [00:08<02:03,  8.80s/it]
# 	 - Train loss: 0.6689
# 	 - Validation Accuracy: 0.8125
# Epoch:  13%|██████████▏                                                                 | 2/15 [00:11<01:11,  5.50s/it]
# 	 - Train loss: 0.4773
# 	 - Validation Accuracy: 0.8500
# Epoch:  20%|███████████████▏                                                            | 3/15 [00:14<00:52,  4.34s/it]
# 	 - Train loss: 0.1732
# 	 - Validation Accuracy: 0.8500
# Epoch:  27%|████████████████████▎                                                       | 4/15 [00:17<00:41,  3.80s/it]
# 	 - Train loss: 0.0631
# 	 - Validation Accuracy: 0.9000
# Epoch:  33%|█████████████████████████▎                                                  | 5/15 [00:20<00:35,  3.54s/it]
# 	 - Train loss: 0.0346
# 	 - Validation Accuracy: 0.8125
# Epoch:  40%|██████████████████████████████▍                                             | 6/15 [00:23<00:30,  3.36s/it]
# 	 - Train loss: 0.1061
# 	 - Validation Accuracy: 0.8500
# Epoch:  47%|███████████████████████████████████▍                                        | 7/15 [00:26<00:25,  3.23s/it]
# 	 - Train loss: 0.0514
# 	 - Validation Accuracy: 0.8375
# Epoch:  53%|████████████████████████████████████████▌                                   | 8/15 [00:30<00:22,  3.18s/it]
# 	 - Train loss: 0.0399
# 	 - Validation Accuracy: 0.8375
# Epoch:  60%|█████████████████████████████████████████████▌                              | 9/15 [00:33<00:18,  3.13s/it]
# 	 - Train loss: 0.0408
# 	 - Validation Accuracy: 0.8375
# Epoch:  67%|██████████████████████████████████████████████████                         | 10/15 [00:36<00:15,  3.10s/it]
# 	 - Train loss: 0.0273
# 	 - Validation Accuracy: 0.8875
# Epoch:  73%|██████████████████████████████████████████████████████▉                    | 11/15 [00:39<00:12,  3.07s/it]
# 	 - Train loss: 0.0124
# 	 - Validation Accuracy: 0.8750
# Epoch:  80%|████████████████████████████████████████████████████████████               | 12/15 [00:42<00:09,  3.06s/it]
# 	 - Train loss: 0.0071
# 	 - Validation Accuracy: 0.8750
# Epoch:  87%|█████████████████████████████████████████████████████████████████          | 13/15 [00:45<00:06,  3.05s/it]
# 	 - Train loss: 0.0053
# 	 - Validation Accuracy: 0.8625
# Epoch:  93%|██████████████████████████████████████████████████████████████████████     | 14/15 [00:48<00:03,  3.03s/it]
# 	 - Train loss: 0.0048
# 	 - Validation Accuracy: 0.8625
# Epoch: 100%|███████████████████████████████████████████████████████████████████████████| 15/15 [00:51<00:00,  3.41s/it]
# 	 - Train loss: 0.0057
# 	 - Validation Accuracy: 0.8750

# %%
# train loss 그래프
plt.plot(epo_list, train_loss_list)
plt.xlabel('epoch')
plt.ylabel('train loss')
plt.show()

# %%
#validation accuracy 그래프
plt.plot(epo_list, val_accuracy_list)
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.axis([1,epochs , 0.75, 1])
plt.show()

# %%
#새로운 리뷰를 분류해보자

def test_sentence(sentence):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []

    # 전처리
    encoding = preprocessing(sentence, tokenizer)
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))

    prediction = 'Positive' if np.argmax(output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    return prediction
    

    
    
new_sentence ='The food was bad, but it was cheap'
# 'It''s good, but the owner is so unkind. Some of the plates didn''t clean properly because there was something on them. But it''s cost-effective.'

print('입력 문장:', new_sentence)
print('분류:', test_sentence(new_sentence))
# Out:
# 입력 문장: The food was bad, but it was cheap and reasonable price
# 분류: Positive

# %%
def testAccuracy(text,labels):
    count=0
    wrongResult=[] # [[String text,Boolean prediction ], ... ]
    rightResult=[] # [[String text,Boolean prediction ], ... ]

    for i in range(len(labels)):
        t = text[i]
        color_s='\033[31m' 
        color_e='\033[0m'
    
        prediction=test_sentence(t)
        if(prediction=="Negative"):
            result=0
        else:
            result=1
        
        if(result==labels[i]):
            count+=1     
            color_s=''
            color_e=''
            rightResult.append([t,1 if prediction=="Positive" else 0])
        else:
            wrongResult.append([t,1 if prediction=="Positive" else 0])
        print(color_s+"=============================== Input {} ===============================".format(i+1))
        print(t)
        print("model result:",prediction,"\nanswer:", labels[i],color_e)
        print("")


    print("test accuracy: {:.4f}".format(count/len(labels)))
    return rightResult,wrongResult

# %%
# 개별 문장의 attention 추출하는 함수
def get_attention(encoding):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        model_output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))
        
    prediction = 'Positive' if np.argmax(model_output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    attention=model_output[-1]
    last_attention=attention[-1]
    tokens=tokenizer.convert_ids_to_tokens(encoding['input_ids'][0])
    
    return attention,last_attention,tokens,prediction

# %%
def get_val_len(ids):
    count=0
    for elem in ids:
        if(elem!=0):
            count+=1
    return count

# %%
def sort_by_att(attention,tokens):
    '''
        last layer의 attention tensor를 입력 받아 각 token의 attention 값을 head에 대한 평균을 낸 뒤, attention이 높은 token 순으로 idx를 반환하는 함수
    '''
    
    attention=attention[0] # shape: 12,len,len
    
    size=len(tokens)
    
    total_atts_sum=[] # 각 head에 대한 각 토큰의 attention값의 합
    for head in range(0,12):
        att_of_head=attention[head] # 한 head의 attention
        atts_sum_of_head=[0.0]*size # 해당 head 하나의 attention의 합
        for row in att_of_head:
            col=0
            for elem in row:
                value=elem.item()
                atts_sum_of_head[col]+=value # head 하나에 대한 토큰이 가지는 attention 값
                col+=1
        total_atts_sum.append(atts_sum_of_head)
    
    total_sum_value=[0.0]*size
    for elem in total_atts_sum:
        for i in range(0,size):
            total_sum_value[i]+=elem[i]
            

    total_mean=[]
    for elem in total_sum_value:
        total_mean.append(elem/12)
    
    


    idxs=sorted(range(len(total_mean)), key=lambda k: total_mean[k], reverse=True)
    return(idxs)

# %%
# attention 순서대로 텍스트 배경색 주기
color_code=[
    "\033[48;5;243m",
    "\033[48;5;245m",
    "\033[48;5;247m",
    "\033[48;5;249m",
    "\033[48;5;251m",
    "\033[48;5;253m",
    "\033[48;5;255m"
]
def emp_by_att(attIdxs,tokens):   
    valTokens=[]
    for tok in tokens:
        if(tok!='[CLS]' and tok!='[PAD]' and tok!='[SEP]'):
            valTokens.append(tok)
        
    valIdxs=[]
    for idx in attIdxs:
        if len(valIdxs)==7:
            break;
        
        if(idx>0 and idx<=len(valTokens)):
            if(valTokens[idx-1]!=',' and valTokens[idx-1]!='.'):
                valIdxs.append(idx-1)
    
    resultSent=""
    for i in range(len(valTokens)):
        if(i in valIdxs):
            outTok=color_code[valIdxs.index(i)]+valTokens[i]+"\033[0m"
        else:
            outTok=valTokens[i]
        resultSent+=outTok
        resultSent+=' '
    
    print("========================= emphasize by attention result==========================")
    print(resultSent)

# %%
def get_highest_att_tok(idxs,retTok,num):
    count=0
    print("highest attention: ",end="")
    for i in idxs:
        if(i<len(retTok)):
            if(retTok[i]!='[CLS]' and retTok[i]!='[SEP]' and retTok[i]!='.' and retTok[i]!=','):
                if(count<num):
                    print(retTok[i],end=" ")
                    count+=1

# %%
def empSentByAtt(sent,length,high):
    encoding = preprocessing(sent, tokenizer,length)
    
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])
    print('MAX_LEN: ',MAX_LEN_IN)
    
    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)
    idxs=sort_by_att(retLastAtt,retTok)
    emp_by_att(idxs,retTok)
    get_highest_att_tok(idxs,retTok,high)

# %%
#test data 세팅

# data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/price_test.csv'
test_df = pd.read_csv(test_url,sep=',', header=0, encoding_errors='ignore')
test_df.head(5)
# Out:
#                                 id  \
# 0  en_SnoozeanAMEatery_480171723:7
# 1                32899414#512291#3
# 2                13383936#420974#1
# 3               11538980#1053497#4
# 4                     32889544#0#0
#
#                                                 text category  polarity
# 0  The pancakes were certainly inventive but $8.5...    price         0
# 1  Cuisine is billed as asian fusion - doesn't me...    price         0
# 2  I found the food to be just as good as its own...    price         1
# 3  But make sure you have enough room on your cre...    price         0
# 4  A mix of students and area residents crowd int...    price         1

# %%
# review data의 label 분포
sns.set_style('darkgrid')

# Create a count plot of the "Liked" column
sns.countplot(x='polarity', data=df)

# Set the title of the plot
plt.title('Count of Reviews by Liked Status')

# Set the label for the x-axis
plt.xlabel('label')

# Set the label for the y-axis
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
# 모든 test data에 대한 분류 및 accuracy 측정
count=0

test_text = df.text.values
test_labels = df.polarity.values

wrongResult=[]
rightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
    else:
        result=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        rightResult.append(t)
    else:
        wrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# The pancakes were certainly inventive but $8.50 for 3 - 6" pancakes (one of them was more like 5") in the pancake flight (sample of 3 different pancakes) is well over-priced.
# model result: Negative
# answer: 0
#
# =============================== Input 2 ===============================
# Cuisine is billed as asian fusion - doesn't meet the bill.
# model result: Negative
# answer: 0
#
# =============================== Input 3 ===============================
# I found the food to be just as good as its owner, Da Silvano, just much less expensive.
# model result: Positive
# answer: 1
#
# =============================== Input 4 ===============================
# But make sure you have enough room on your credit card as the bill will leave a big dent in your wallet.
# model result: Negative
# answer: 0
#
# =============================== Input 5 ===============================
# A mix of students and area residents crowd into this narrow, barely there space for its quick, tasty treats at dirt-cheap prices.
# model result: Negative
# answer: 1
#
# =============================== Input 6 ===============================
# The best thing is, the prices are also quite reasonable.
# model result: Positive
# answer: 1
#
# =============================== Input 7 ===============================
# Anywhere else, the prices would be 3x as high!
# model result: Negative
# answer: 1
#
# =============================== Input 8 ===============================
# The chips  and salsa are so yummy, and the prices are fabulous.
# model result: Positive
# answer: 1
#
# =============================== Input 9 ===============================
# – The sushi here is perfectly good, but for $5 a piece, either the slices of fish should be larger, or there should be no pretense that this is a moderately priced restaurant (even for NYC).
# model result: Positive
# answer: 0
#
# =============================== Input 10 ===============================
# The price was right too.
# model result: Positive
# answer: 1
#
# =============================== Input 11 ===============================
# Could have had better for 1/3 the price in Chinatown.
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# The service was pretty poor all around, the food was well below average relative to the cost, and outside there is a crazy bum who harasses every customer who leaves the place.
# model result: Negative
# answer: 0
#
# =============================== Input 13 ===============================
# We were very impressed with the food and value.
# model result: Positive
# answer: 1
#
# =============================== Input 14 ===============================
# The only drawback is that it's a little pricey.
# model result: Negative
# answer: 0
#
# =============================== Input 15 ===============================
# Simple healthy unglamorous food cheap.
# model result: Positive
# answer: 1
#
# =============================== Input 16 ===============================
# Terrible service, food ok, pricey
# model result: Negative
# answer: 0
#
# =============================== Input 17 ===============================
# Speedy delivers, great food, decent prices, and friendly service combine to ensure an enjoyable repast.
# model result: Positive
# answer: 1
#
# =============================== Input 18 ===============================
# It took a bigger bite from my wallet than my appetite - I would not reccomend this to anyone that I would want to talk to me again!!
# model result: Negative
# answer: 0
#
# =============================== Input 19 ===============================
# I thought the food isn't cheap at all compared to Chinatown.
# model result: Negative
# answer: 0
#
# =============================== Input 20 ===============================
# My g/f and I both agreed the food was very mediocre especially considering the price.
# model result: Positive
# answer: 0
#
# =============================== Input 21 ===============================
# 15% gratuity automatically added to the bill.
# model result: Negative
# answer: 0
#
# =============================== Input 22 ===============================
# Best Chinese on the Upper East, prompt delivery, good value.
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# Food wise, its ok but a bit pricey for what you get considering the restaurant isn't a fancy place.
# model result: Negative
# answer: 0
#
# =============================== Input 24 ===============================
# the food - not worth the price.
# model result: Negative
# answer: 0
#
# =============================== Input 25 ===============================
# We easily spent more than $40 per person (not including alcohol) and were still hungry.
# model result: Negative
# answer: 0
#
# =============================== Input 26 ===============================
# The new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but I must agree with the person that wrote about their favorite words: No, can't, sorry..., boy, they won't bend the rules for anyone.
# model result: Negative
# answer: 0
#
# =============================== Input 27 ===============================
# The service is really fast and friendly, and the value is great.
# model result: Positive
# answer: 1
#
# =============================== Input 28 ===============================
# Prices even outside of restaurant week were great.
# model result: Positive
# answer: 1
#
# =============================== Input 29 ===============================
# However, the value and service are both severely lacking.
# model result: Negative
# answer: 0
#
# =============================== Input 30 ===============================
# The most pleasant surprise was the check that did not exceed my expectations as it always happens in most of the places.
# model result: Positive
# answer: 1
#
# =============================== Input 31 ===============================
# I can understand the prices if it served better food, like some Chinese restaurants in midtown/uptown area.
# model result: Negative
# answer: 0
#
# =============================== Input 32 ===============================
# It also has lots of other Korean dishes that are affordable and just as yummy.
# model result: Positive
# answer: 1
#
# =============================== Input 33 ===============================
# At best, the food was good and definately overpriced.
# model result: Negative
# answer: 0
#
# =============================== Input 34 ===============================
# This place has beautiful sushi, and it's delicious CHEAP.
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# I've eaten at all three locations and I always love, love the food, the service is always wonderful and the prices are really reasonable.
# model result: Positive
# answer: 1
#
# =============================== Input 36 ===============================
# Most importantly, it is reasonably priced.
# model result: Positive
# answer: 1
#
# =============================== Input 37 ===============================
# The pancakes should be larger (at least 8") to justify the expense even with the unique offerings.
# model result: Negative
# answer: 0
#
# =============================== Input 38 ===============================
# I'm astonished that this restaurant is categorized as $$$ rather than $$$$.
# model result: Negative
# answer: 0
#
# =============================== Input 39 ===============================
# The only drawback is that this place is really expensive and the portions are on the small side.
# model result: Negative
# answer: 0
#
# =============================== Input 40 ===============================
# Overpriced
# model result: Negative
# answer: 0
#
# =============================== Input 41 ===============================
# The unattractive lighting made me want to gag, the food was overpriced, there was the most awful disco pop duo performing-and my escargot looked like it might crawl off the plate.
# model result: Negative
# answer: 0
#
# =============================== Input 42 ===============================
# How can they survive serving mediocre food at exorbitant prices?!
# model result: Negative
# answer: 0
#
# =============================== Input 43 ===============================
# Everything is very cheap.
# model result: Positive
# answer: 1
#
# =============================== Input 44 ===============================
# – Pretty cheap for sit down Mexican AND downtown.
# model result: Positive
# answer: 1
#
# =============================== Input 45 ===============================
# The sushi is reasonably priced and fresh.
# model result: Positive
# answer: 1
#
# =============================== Input 46 ===============================
# ) It's not the best Japanese restaurant in the East Village, but it's a pretty solid one for its modest prices, and worth repeat visits.
# model result: Positive
# answer: 1
#
# =============================== Input 47 ===============================
# – As with most restaurants in Seattle, Mioposto's service was bad and the food was overpriced.
# model result: Negative
# answer: 0
#
# =============================== Input 48 ===============================
# The staff is arrogant, the prices are way high for Brooklyn.
# model result: Negative
# answer: 0
#
# =============================== Input 49 ===============================
# Chinatown definitely has better quality with cheaper prices.
# model result: Positive
# answer: 0
#
# =============================== Input 50 ===============================
# Way too much money for such a terrible meal.
# model result: Negative
# answer: 0
#
# =============================== Input 51 ===============================
# Another great thing about Glechik-everything is very cheap!
# model result: Positive
# answer: 1
#
# =============================== Input 52 ===============================
# The open sesame combo plate is a bargain for the heap of food given.
# model result: Positive
# answer: 1
#
# =============================== Input 53 ===============================
# i have eaten here on a different occasion - the food is mediocre for the prices.
# model result: Negative
# answer: 0
#
# =============================== Input 54 ===============================
# The traditional Italian items are great - cheap and served in a cozy setting.
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# The happy hour is so cheap, but that does not reflect the service or the atmosphere.
# model result: Positive
# answer: 1
#
# =============================== Input 56 ===============================
# Great value sushi with high quality & nice setting.
# model result: Positive
# answer: 1
# =============================== Input 57 ===============================
# His food is excellent (and not expensive by NYC standards- no entrees over $30, most appetizers $12 to 14).
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# I liked the atmosphere very much but the food was not worth the price.
# model result: Negative
# answer: 0
#
# =============================== Input 59 ===============================
# Good Sushi, High Price
# model result: Positive
# answer: 0
#
# =============================== Input 60 ===============================
# Although I moved uptown I try to stop in as often as possible for the GREAT cheap food and to pay the friendly staff a visit.
# model result: Positive
# answer: 1
#
# =============================== Input 61 ===============================
# Insultingly Overpriced
# model result: Negative
# answer: 0
#
# =============================== Input 62 ===============================
# I can say that the wraps, burgers and salads were all fresh, tasty and the mango margareta at $9 was WELL WORTH the money.
# model result: Positive
# answer: 1
#
# =============================== Input 63 ===============================
# They serve it in a tall, skinny hour-glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket.
# model result: Negative
# answer: 0
#
# =============================== Input 64 ===============================
# In the end our check came to $27 for 4 small pancakes, a breakfast burrito, an orange juice and an iced tea (I had water).
# model result: Negative
# answer: 0
#
# =============================== Input 65 ===============================
# Good service, great food, good value, and never have to wait in line!
# model result: Positive
# answer: 1
#
# =============================== Input 66 ===============================
# You can eat gourmet food at a fast food price.
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# The food was good, the service prompt, and the price very reasonable.
# model result: Positive
# answer: 1
#
# =============================== Input 68 ===============================
# Food is excellent quality for a good restaurant price.
# model result: Positive
# answer: 1
#
# =============================== Input 69 ===============================
# Service is excellent, no wait, and you get a lot for the price.
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# But dinner here is never disappointing, even if the prices are a bit over the top.
# model result: Positive
# answer: 0
#
# =============================== Input 71 ===============================
# Casablanca servces delicious falafel, tabouleh, humus and other Mediterranean delights, which are all very inexpensive.
# model result: Positive
# answer: 1
#
# =============================== Input 72 ===============================
# You're going to drop some coin, but completely worth it, especially if you are looking to impress someone.
# model result: Negative
# answer: 1
#
# =============================== Input 73 ===============================
# Although the service could be improved considering the money you put in.
# model result: Negative
# answer: 0
#
# =============================== Input 74 ===============================
# Finally let into the store 5 at a time, to buy expensive slices from a harried staff.
# model result: Negative
# answer: 0
#
# =============================== Input 75 ===============================
# Excellent food, nice ambience, fairly expensive
# model result: Positive
# answer: 0
#
# =============================== Input 76 ===============================
# The wine list is extensive, well priced and covers alot of regions.
# model result: Positive
# answer: 1
#
# =============================== Input 77 ===============================
# The food is fantastic, authentic, delicious and very, very affordable.
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# I recommend it for a night when you want to splurge! (it was a bit expensive)
# model result: Negative
# answer: 0
#
# =============================== Input 79 ===============================
# I have been here, spent tons of money on a chef special dinner and it was a major dissappointment.
# model result: Negative
# answer: 0
#
# =============================== Input 80 ===============================
# To start off, approximately 8-10 oz of orange juice will cost you $3.
# model result: Negative
# answer: 0
#
# =============================== Input 81 ===============================
# It's *very* reasonably priced, esp for the quality of the food.
# model result: Positive
# answer: 1
#
# =============================== Input 82 ===============================
# The lunch menu is an awesome deal!
# model result: Positive
# answer: 1
#
# =============================== Input 83 ===============================
# The food is great and the prices are reasonable.
# model result: Positive
# answer: 1
#
# =============================== Input 84 ===============================
# The food is great (big selection, reasonable prices) and the drinks are really good.
# model result: Positive
# answer: 1
#
# =============================== Input 85 ===============================
# We were so happy with our food and were even more thrilled when we saw the bill.
# model result: Positive
# answer: 1
#
# =============================== Input 86 ===============================
# The food was definitely good, but when all was said and done, I just couldn't justify it for the price (including 2 drinks, $100/person)...
# model result: Negative
# answer: 0
#
# =============================== Input 87 ===============================
# but for the value, it was a great affordable spot to enjoy a fun night out with small group.
# model result: Positive
# answer: 1
#
# =============================== Input 88 ===============================
# The main draw of this place is the price.
# model result: Positive
# answer: 0
#
# =============================== Input 89 ===============================
# Over priced, overrated....stay away!
# model result: Negative
# answer: 0
#
# =============================== Input 90 ===============================
# Food was good and cheap.
# model result: Positive
# answer: 1
#
# =============================== Input 91 ===============================
# If your looking for nasty high priced food with a dash of ghetto scenery cheap BX A$$ this is the place to be!!
# model result: Positive
# answer: 0
#
# =============================== Input 92 ===============================
# The food is not what it once was (potions have seriously seen downsizing) prices have gone up, and the service is the worst I have experienced anywhere (including mainland Europe).
# model result: Negative
# answer: 0
#
# =============================== Input 93 ===============================
# Reasonably priced with very fresh sushi.
# model result: Positive
# answer: 1
#
# =============================== Input 94 ===============================
# The prices are not terrible.
# model result: Positive
# answer: 1
#
# =============================== Input 95 ===============================
# excellent tapas at great prices, romantic, small but not overly crowed, excellent
# model result: Positive
# answer: 1
#
# =============================== Input 96 ===============================
# $6 with tip.
# model result: Negative
# answer: 1
#
# =============================== Input 97 ===============================
# The presentation of Snooze is excellent and it is one of those places that you feel more sophisticated just for being there; but peel back the layers and you have an overpriced IHOP with a high brow menu.
# model result: Positive
# answer: 0
#
# =============================== Input 98 ===============================
# Huge portions, great and attentive service, and pretty good prices.
# model result: Positive
# answer: 1
#
# =============================== Input 99 ===============================
# Fancy pieces of exotic fish on a $100 dollar plate and NOT ONE was eatable.
# model result: Negative
# answer: 0
#
# =============================== Input 100 ===============================
# For the amount of food we got the prices should have been lower.
# model result: Negative
# answer: 0
#
# test accuracy: 0.8700

# %%
print(wrongResult)
# Out:
# ['Anywhere else, the prices would be 3x as high!', 'The price was right too.', 'Simple healthy unglamorous food cheap.', 'I can understand the prices if it served better food, like some Chinese restaurants in midtown/uptown area.', "I'm astonished that this restaurant is categorized as $$$ rather than $$$$.", 'Chinatown definitely has better quality with cheaper prices.', 'i have eaten here on a different occasion - the food is mediocre for the prices.', 'The happy hour is so cheap, but that does not reflect the service or the atmosphere.', 'Although I moved uptown I try to stop in as often as possible for the GREAT cheap food and to pay the friendly staff a visit.', 'In the end our check came to $27 for 4 small pancakes, a breakfast burrito, an orange juice and an iced tea (I had water).', "You're going to drop some coin, but completely worth it, especially if you are looking to impress someone.", 'Excellent food, nice ambience, fairly expensive', 'I recommend it for a night when you want to splurge! (it was a bit expensive)', 'Fancy pieces of exotic fish on a $100 dollar plate and NOT ONE was eatable.']

# %%
#문장의 BERT attention을 추출해보자

# 개별 문장의 attention 추출하는 함수
def get_attention(encoding):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        model_output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))
        
    prediction = 'Positive' if np.argmax(model_output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    attention=model_output[-1]
    last_attention=attention[-1]
    tokens=tokenizer.convert_ids_to_tokens(encoding['input_ids'][0])
    
    return attention,last_attention,tokens,prediction

# %%
def get_val_len(ids):
    count=0
    for elem in ids:
        if(elem!=0):
            count+=1
    return count

# %%
# bertviz를 이용한 attention 시각화
from bertviz import head_view

sent="Cheap price, and the food was delicious, but staff was not kind."

# 전처리
encoding = preprocessing(sent, tokenizer,20)


retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

print('입력 문장:', sent)
print('분류:', prediction)
print()

#head_view(retAtt,retTok)
# Out:
# 입력 문장: Cheap price, and the food was delicious, but staff was not kind.
# 분류: Positive

# %%
def sort_by_att(attention,tokens):
    '''
        last layer의 attention tensor를 입력 받아 각 token의 attention 값을 head에 대한 평균을 낸 뒤, attention이 높은 token 순으로 idx를 반환하는 함수
    '''
    
    attention=attention[0] # shape: 12,len,len
    
    size=len(tokens)
    
    total_atts_sum=[] # 각 head에 대한 각 토큰의 attention값의 합
    for head in range(0,12):
        att_of_head=attention[head] # 한 head의 attention
        atts_sum_of_head=[0.0]*size # 해당 head 하나의 attention의 합
        for row in att_of_head:
            col=0
            for elem in row:
                value=elem.item()
                atts_sum_of_head[col]+=value # head 하나에 대한 토큰이 가지는 attention 값
                col+=1
        total_atts_sum.append(atts_sum_of_head)
    
    total_sum_value=[0.0]*size
    for elem in total_atts_sum:
        for i in range(0,size):
            total_sum_value[i]+=elem[i]
            

    total_mean=[]
    for elem in total_sum_value:
        total_mean.append(elem/12)
    
    


    idxs=sorted(range(len(total_mean)), key=lambda k: total_mean[k], reverse=True)
    return(idxs)

# %%
# attention 순서대로 텍스트 배경색 주기
color_code=[
    "\033[48;5;243m",
    "\033[48;5;245m",
    "\033[48;5;247m",
    "\033[48;5;249m",
    "\033[48;5;251m",
    "\033[48;5;253m",
    "\033[48;5;255m"
]
def emp_by_att(attIdxs,tokens):   
    valTokens=[]
    for tok in tokens:
        if(tok!='[CLS]' and tok!='[PAD]' and tok!='[SEP]'):
            valTokens.append(tok)
        
    valIdxs=[]
    for idx in attIdxs:
        if len(valIdxs)==7:
            break;
        
        if(idx>0 and idx<=len(valTokens)):
            if(valTokens[idx-1]!=',' and valTokens[idx-1]!='.'):
                valIdxs.append(idx-1)
    
    resultSent=""
    for i in range(len(valTokens)):
        if(i in valIdxs):
            outTok=color_code[valIdxs.index(i)]+valTokens[i]+"\033[0m"
        else:
            outTok=valTokens[i]
        resultSent+=outTok
        resultSent+=' '
    
    print("========================= emphasize by attention result==========================")
    print(resultSent)

# %%
def get_highest_att_tok(idxs,retTok,num):
    count=0
    print("highest attention: ",end="")
    for i in idxs:
        if(i<len(retTok)):
            if(retTok[i]!='[CLS]' and retTok[i]!='[SEP]' and retTok[i]!='.' and retTok[i]!=','):
                if(count<num):
                    print(retTok[i],end=" ")
                    count+=1

# %%
# 개별 문장을 attention이 높은 token 순으로 강조해 보여주기
idxs=sort_by_att(retLastAtt,retTok)

emp_by_att(idxs,retTok)

get_highest_att_tok(idxs,retTok,3)
# Out:
# ========================= emphasize by attention result==========================
# cheap price , and the food was delicious , but staff was not kind .
# highest attention: cheap delicious price

# %%
#잘못 분류된 문장의 attention
for sent in wrongResult:
    encoding = preprocessing(sent, tokenizer,50)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,8)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: The pancakes were certainly inventive but $8.50 for 3 - 6" pancakes (one of them was more like 5") in the pancake flight (sample of 3 different pancakes) is well over-priced.
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# the pancakes were certainly in ##vent ##ive but $ 8 . 50 for 3 - 6 " pancakes ( one of them was more like 5 " ) in the pan ##cake flight ( sample of 3 different pancakes ) is well over - priced .
# highest attention: ) but ( - - well 3 in
#
#
#
# 입력 문장: I found the food to be just as good as its owner, Da Silvano, just much less expensive.
# 분류: Negative
# MAX_LEN:  24
# ========================= emphasize by attention result==========================
# i found the food to be just as good as its owner , da silva ##no , just much less expensive .
# highest attention: as da less expensive found i ##no just
#
#
#
# 입력 문장: Anywhere else, the prices would be 3x as high!
# 분류: Negative
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# anywhere else , the prices would be 3 ##x as high !
# highest attention: as anywhere ! would high be else ##x
#
#
#
# 입력 문장: – The sushi here is perfectly good, but for $5 a piece, either the slices of fish should be larger, or there should be no pretense that this is a moderately priced restaurant (even for NYC).
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# – the su ##shi here is perfectly good , but for $ 5 a piece , either the slices of fish should be larger , or there should be no pre ##tens ##e that this is a moderately priced restaurant ( even for nyc ) .
# highest attention: ) either moderately should but or should priced
#
#
#
# 입력 문장: The price was right too.
# 분류: Negative
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# the price was right too .
# highest attention: price too right the was [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: Could have had better for 1/3 the price in Chinatown.
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# could have had better for 1 / 3 the price in chinatown .
# highest attention: chinatown could for in 3 have price /
#
#
#
# 입력 문장: I can understand the prices if it served better food, like some Chinese restaurants in midtown/uptown area.
# 분류: Positive
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# i can understand the prices if it served better food , like some chinese restaurants in midtown / uptown area .
# highest attention: like / if better can understand the i
#
#
#
# 입력 문장: The happy hour is so cheap, but that does not reflect the service or the atmosphere.
# 분류: Negative
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# the happy hour is so cheap , but that does not reflect the service or the atmosphere .
# highest attention: but not does so that reflect cheap is
#
#
#
# 입력 문장: Good Sushi, High Price
# 분류: Positive
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# good su ##shi , high price
# highest attention: high ##shi price good su [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: In the end our check came to $27 for 4 small pancakes, a breakfast burrito, an orange juice and an iced tea (I had water).
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# in the end our check came to $ 27 for 4 small pancakes , a breakfast burr ##ito , an orange juice and an iced tea ( i had water ) .
# highest attention: ) our 4 i and small ( end
#
#
#
# 입력 문장: You're going to drop some coin, but completely worth it, especially if you are looking to impress someone.
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# you ' re going to drop some coin , but completely worth it , especially if you are looking to impress someone .
# highest attention: re but you ' if are completely worth
#
#
#
# 입력 문장: The main draw of this place is the price.
# 분류: Positive
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# the main draw of this place is the price .
# highest attention: this main place is draw price the the
#
#
#
# 입력 문장: If your looking for nasty high priced food with a dash of ghetto scenery cheap BX A$$ this is the place to be!!
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# if your looking for nasty high priced food with a dash of ghetto scenery cheap b ##x a $ $ this is the place to be ! !
# highest attention: nasty with cheap ghetto high scenery if priced

# %%
#잘 분류된 문장의 attention
for sent in rightResult:
    encoding = preprocessing(sent, tokenizer,50)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,8)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: Cuisine is billed as asian fusion - doesn't meet the bill.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# cuisine is billed as asian fusion - doesn ' t meet the bill .
# highest attention: - is doesn t ' billed as the
#
#
#
# 입력 문장: But make sure you have enough room on your credit card as the bill will leave a big dent in your wallet.
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# but make sure you have enough room on your credit card as the bill will leave a big dent in your wallet .
# highest attention: but make as you will big sure leave
#
#
#
# 입력 문장: A mix of students and area residents crowd into this narrow, barely there space for its quick, tasty treats at dirt-cheap prices.
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# a mix of students and area residents crowd into this narrow , barely there space for its quick , ta ##sty treats at dirt - cheap prices .
# highest attention: and crowd a this its barely - mix
#
#
#
# 입력 문장: The best thing is, the prices are also quite reasonable.
# 분류: Positive
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# the best thing is , the prices are also quite reasonable .
# highest attention: prices also reasonable quite are the best thing
#
#
#
# 입력 문장: The chips  and salsa are so yummy, and the prices are fabulous.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the chips and salsa are so yu ##mmy , and the prices are fabulous .
# highest attention: and so prices fabulous are are the the
#
#
#
# 입력 문장: The service was pretty poor all around, the food was well below average relative to the cost, and outside there is a crazy bum who harasses every customer who leaves the place.
# 분류: Negative
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# the service was pretty poor all around , the food was well below average relative to the cost , and outside there is a crazy bum who hara ##sse ##s every customer who leaves the place .
# highest attention: and cost well poor pretty crazy outside was
#
#
#
# 입력 문장: We were very impressed with the food and value.
# 분류: Positive
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# we were very impressed with the food and value .
# highest attention: and we value food impressed the with were
#
#
#
# 입력 문장: The only drawback is that it's a little pricey.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the only draw ##back is that it ' s a little price ##y .
# highest attention: s that only ' is little it the
#
#
#
# 입력 문장: Simple healthy unglamorous food cheap.
# 분류: Positive
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# simple healthy un ##gl ##amo ##rous food cheap .
# highest attention: cheap simple food healthy ##rous un ##gl ##amo
#
#
#
# 입력 문장: Terrible service, food ok, pricey
# 분류: Negative
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# terrible service , food ok , price ##y
# highest attention: terrible ok ##y price food service [PAD] [PAD]
#
#
#
# 입력 문장: Speedy delivers, great food, decent prices, and friendly service combine to ensure an enjoyable repast.
# 분류: Positive
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# speedy delivers , great food , decent prices , and friendly service combine to ensure an enjoyable rep ##ast .
# highest attention: and friendly great decent to prices food combine
#
#
#
# 입력 문장: It took a bigger bite from my wallet than my appetite - I would not reccomend this to anyone that I would want to talk to me again!!
# 분류: Negative
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# it took a bigger bite from my wallet than my appetite - i would not rec ##com ##end this to anyone that i would want to talk to me again ! !
# highest attention: - not anyone i would took this that
#
#
#
# 입력 문장: I thought the food isn't cheap at all compared to Chinatown.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# i thought the food isn ' t cheap at all compared to chinatown .
# highest attention: thought chinatown i isn t ' cheap to
#
#
#
# 입력 문장: My g/f and I both agreed the food was very mediocre especially considering the price.
# 분류: Negative
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# my g / f and i both agreed the food was very med ##io ##cre especially considering the price .
# highest attention: especially very agreed considering my was the ##cre
#
#
#
# 입력 문장: 15% gratuity automatically added to the bill.
# 분류: Negative
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# 15 % gr ##at ##uity automatically added to the bill .
# highest attention: automatically added ##uity the bill % 15 to
#
#
#
# 입력 문장: Best Chinese on the Upper East, prompt delivery, good value.
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# best chinese on the upper east , prompt delivery , good value .
# highest attention: good value best prompt chinese delivery on the
#
#
#
# 입력 문장: Food wise, its ok but a bit pricey for what you get considering the restaurant isn't a fancy place.
# 분류: Negative
# MAX_LEN:  26
# ========================= emphasize by attention result==========================
# food wise , its ok but a bit price ##y for what you get considering the restaurant isn ' t a fancy place .
# highest attention: but for bit you considering isn price a
#
#
#
# 입력 문장: the food - not worth the price.
# 분류: Negative
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# the food - not worth the price .
# highest attention: not the - worth food the price [PAD]
#
#
#
# 입력 문장: We easily spent more than $40 per person (not including alcohol) and were still hungry.
# 분류: Negative
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# we easily spent more than $ 40 per person ( not including alcohol ) and were still hungry .
# highest attention: ) and we were still easily ( not
#
#
#
# 입력 문장: The new menu has a few creative items,they were smart enough to keep some of the old favorites (but they raised the prices), the staff is friendly most of the time, but I must agree with the person that wrote about their favorite words: No, can't, sorry..., boy, they won't bend the rules for anyone.
# 분류: Negative
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# the new menu has a few creative items , they were smart enough to keep some of the old favorites ( but they raised the prices ) , the staff is friendly most of the time , but i must agree with the person that wrote about their
# highest attention: but but few they has friendly raised with
#
#
#
# 입력 문장: The service is really fast and friendly, and the value is great.
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the service is really fast and friendly , and the value is great .
# highest attention: and and friendly is great is fast value
#
#
#
# 입력 문장: Prices even outside of restaurant week were great.
# 분류: Positive
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# prices even outside of restaurant week were great .
# highest attention: great were even prices restaurant outside week of
#
#
#
# 입력 문장: However, the value and service are both severely lacking.
# 분류: Negative
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# however , the value and service are both severely lacking .
# highest attention: and however are both severely lacking value the
#
#
#
# 입력 문장: The most pleasant surprise was the check that did not exceed my expectations as it always happens in most of the places.
# 분류: Positive
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# the most pleasant surprise was the check that did not exceed my expectations as it always happens in most of the places .
# highest attention: not as that my always pleasant happens did
#
#
#
# 입력 문장: It also has lots of other Korean dishes that are affordable and just as yummy.
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it also has lots of other korean dishes that are affordable and just as yu ##mmy .
# highest attention: and that as just affordable lots korean also
#
#
#
# 입력 문장: At best, the food was good and definately overpriced.
# 분류: Negative
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# at best , the food was good and def ##inate ##ly over ##pr ##ice ##d .
# highest attention: and best good was ##ly over the ##d
#
#
#
# 입력 문장: This place has beautiful sushi, and it's delicious CHEAP.
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# this place has beautiful su ##shi , and it ' s delicious cheap .
# highest attention: and delicious beautiful cheap ##shi it s '
#
#
#
# 입력 문장: I've eaten at all three locations and I always love, love the food, the service is always wonderful and the prices are really reasonable.
# 분류: Positive
# MAX_LEN:  31
# ========================= emphasize by attention result==========================
# i ' ve eaten at all three locations and i always love , love the food , the service is always wonderful and the prices are really reasonable .
# highest attention: and and always always prices really the reasonable
#
#
#
# 입력 문장: Most importantly, it is reasonably priced.
# 분류: Positive
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# most importantly , it is reasonably priced .
# highest attention: priced reasonably is importantly most it [PAD] [PAD]
#
#
#
# 입력 문장: The pancakes should be larger (at least 8") to justify the expense even with the unique offerings.
# 분류: Negative
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# the pancakes should be larger ( at least 8 " ) to justify the expense even with the unique offerings .
# highest attention: ) should the even unique the with be
#
#
#
# 입력 문장: I'm astonished that this restaurant is categorized as $$$ rather than $$$$.
# 분류: Negative
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# i ' m astonished that this restaurant is categorized as $ $ $ rather than $ $ $ $ .
# highest attention: is that astonished categorized this rather i m
#
#
#
# 입력 문장: The only drawback is that this place is really expensive and the portions are on the small side.
# 분류: Negative
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# the only draw ##back is that this place is really expensive and the portions are on the small side .
# highest attention: and is only is really the that expensive
#
#
#
# 입력 문장: Overpriced
# 분류: Negative
# MAX_LEN:  6
# ========================= emphasize by attention result==========================
# over ##pr ##ice ##d
# highest attention: over ##d ##ice ##pr [PAD] [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: The unattractive lighting made me want to gag, the food was overpriced, there was the most awful disco pop duo performing-and my escargot looked like it might crawl off the plate.
# 분류: Negative
# MAX_LEN:  46
# ========================= emphasize by attention result==========================
# the una ##tt ##ractive lighting made me want to gag , the food was over ##pr ##ice ##d , there was the most awful disco pop duo performing - and my es ##car ##go ##t looked like it might crawl off the plate .
# highest attention: was and the me the was there my
#
#
#
# 입력 문장: How can they survive serving mediocre food at exorbitant prices?!
# 분류: Negative
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# how can they survive serving med ##io ##cre food at ex ##or ##bit ##ant prices ? !
# highest attention: they can ! how survive ##cre ? ##ant
#
#
#
# 입력 문장: Everything is very cheap.
# 분류: Positive
# MAX_LEN:  7
# ========================= emphasize by attention result==========================
# everything is very cheap .
# highest attention: cheap very is everything [PAD] [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: – Pretty cheap for sit down Mexican AND downtown.
# 분류: Positive
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# – pretty cheap for sit down mexican and downtown .
# highest attention: and mexican downtown for – pretty cheap sit
#
#
#
# 입력 문장: The sushi is reasonably priced and fresh.
# 분류: Positive
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# the su ##shi is reasonably priced and fresh .
# highest attention: and priced reasonably is fresh ##shi the su
#
#
#
# 입력 문장: ) It's not the best Japanese restaurant in the East Village, but it's a pretty solid one for its modest prices, and worth repeat visits.
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# ) it ' s not the best japanese restaurant in the east village , but it ' s a pretty solid one for its modest prices , and worth repeat visits .
# highest attention: and modest for worth ) japanese restaurant best
#
#
#
# 입력 문장: – As with most restaurants in Seattle, Mioposto's service was bad and the food was overpriced.
# 분류: Negative
# MAX_LEN:  28
# ========================= emphasize by attention result==========================
# – as with most restaurants in seattle , mi ##op ##ost ##o ' s service was bad and the food was over ##pr ##ice ##d .
# highest attention: and as – with the was most was
#
#
#
# 입력 문장: The staff is arrogant, the prices are way high for Brooklyn.
# 분류: Negative
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# the staff is arrogant , the prices are way high for brooklyn .
# highest attention: is arrogant for brooklyn way the the are
#
#
#
# 입력 문장: Chinatown definitely has better quality with cheaper prices.
# 분류: Negative
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# chinatown definitely has better quality with cheaper prices .
# highest attention: chinatown with has definitely cheaper better prices quality
#
#
#
# 입력 문장: Way too much money for such a terrible meal.
# 분류: Negative
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# way too much money for such a terrible meal .
# highest attention: too way for terrible much such a money
#
#
#
# 입력 문장: Another great thing about Glechik-everything is very cheap!
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# another great thing about g ##le ##chi ##k - everything is very cheap !
# highest attention: - ! cheap everything is very great another
#
#
#
# 입력 문장: The open sesame combo plate is a bargain for the heap of food given.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the open sesame combo plate is a bargain for the heap of food given .
# highest attention: is the sesame a heap the given for
#
#
#
# 입력 문장: i have eaten here on a different occasion - the food is mediocre for the prices.
# 분류: Negative
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# i have eaten here on a different occasion - the food is med ##io ##cre for the prices .
# highest attention: - have different is ##cre i the a
#
#
#
# 입력 문장: The traditional Italian items are great - cheap and served in a cozy setting.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the traditional italian items are great - cheap and served in a cozy setting .
# highest attention: and - a cozy great italian in cheap
#
#
#
# 입력 문장: Great value sushi with high quality & nice setting.
# 분류: Positive
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# great value su ##shi with high quality & nice setting .
# highest attention: & with nice high setting great ##shi quality
#
#
#
# 입력 문장: His food is excellent (and not expensive by NYC standards- no entrees over $30, most appetizers $12 to 14).
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# his food is excellent ( and not expensive by nyc standards - no en ##tree ##s over $ 30 , most app ##eti ##zers $ 12 to 14 ) .
# highest attention: not no his nyc excellent is and most
#
#
#
# 입력 문장: I liked the atmosphere very much but the food was not worth the price.
# 분류: Negative
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# i liked the atmosphere very much but the food was not worth the price .
# highest attention: but not i was the worth very price
#
#
#
# 입력 문장: Although I moved uptown I try to stop in as often as possible for the GREAT cheap food and to pay the friendly staff a visit.
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# although i moved uptown i try to stop in as often as possible for the great cheap food and to pay the friendly staff a visit .
# highest attention: and although cheap i great food to the
#
#
#
# 입력 문장: Insultingly Overpriced
# 분류: Negative
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# insulting ##ly over ##pr ##ice ##d
# highest attention: ##d ##ly insulting over ##ice ##pr [PAD] [PAD]
#
#
#
# 입력 문장: I can say that the wraps, burgers and salads were all fresh, tasty and the mango margareta at $9 was WELL WORTH the money.
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# i can say that the wraps , burger ##s and salad ##s were all fresh , ta ##sty and the mango margaret ##a at $ 9 was well worth the money .
# highest attention: and all fresh ##sty were that and was
#
#
#
# 입력 문장: They serve it in a tall, skinny hour-glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket.
# 분류: Negative
# MAX_LEN:  37
# ========================= emphasize by attention result==========================
# they serve it in a tall , skinny hour - glass shaped glass to disguise the fact that you a getting a small juice at the price of a half gallon in a supermarket .
# highest attention: a that you to disguise they the a
#
#
#
# 입력 문장: Good service, great food, good value, and never have to wait in line!
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# good service , great food , good value , and never have to wait in line !
# highest attention: and good great good never food value !
#
#
#
# 입력 문장: You can eat gourmet food at a fast food price.
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# you can eat go ##ur ##met food at a fast food price .
# highest attention: can a you at fast price go food
#
#
#
# 입력 문장: The food was good, the service prompt, and the price very reasonable.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the food was good , the service prompt , and the price very reasonable .
# highest attention: and price reasonable good very the was prompt
#
#
#
# 입력 문장: Food is excellent quality for a good restaurant price.
# 분류: Positive
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# food is excellent quality for a good restaurant price .
# highest attention: for good a excellent is price quality restaurant
#
#
#
# 입력 문장: Service is excellent, no wait, and you get a lot for the price.
# 분류: Positive
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# service is excellent , no wait , and you get a lot for the price .
# highest attention: and excellent is you no price service lot
#
#
#
# 입력 문장: But dinner here is never disappointing, even if the prices are a bit over the top.
# 분류: Negative
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# but dinner here is never disappointing , even if the prices are a bit over the top .
# highest attention: is are bit but the a prices the
#
#
#
# 입력 문장: Casablanca servces delicious falafel, tabouleh, humus and other Mediterranean delights, which are all very inexpensive.
# 분류: Positive
# MAX_LEN:  31
# ========================= emphasize by attention result==========================
# casablanca ser ##vc ##es delicious fa ##la ##fe ##l , tab ##ou ##le ##h , hum ##us and other mediterranean delight ##s , which are all very inexpensive .
# highest attention: casablanca very delicious which mediterranean ##es all and
#
#
#
# 입력 문장: Although the service could be improved considering the money you put in.
# 분류: Negative
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# although the service could be improved considering the money you put in .
# highest attention: you although considering money the put could service
#
#
#
# 입력 문장: Finally let into the store 5 at a time, to buy expensive slices from a harried staff.
# 분류: Negative
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# finally let into the store 5 at a time , to buy expensive slices from a ha ##rrie ##d staff .
# highest attention: to finally a expensive the into staff let
#
#
#
# 입력 문장: Excellent food, nice ambience, fairly expensive
# 분류: Negative
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# excellent food , nice am ##bie ##nce , fairly expensive
# highest attention: nice expensive fairly excellent ##nce am food ##bie
#
#
#
# 입력 문장: The wine list is extensive, well priced and covers alot of regions.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the wine list is extensive , well priced and covers al ##ot of regions .
# highest attention: and of well priced wine extensive regions covers
#
#
#
# 입력 문장: The food is fantastic, authentic, delicious and very, very affordable.
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the food is fantastic , authentic , delicious and very , very affordable .
# highest attention: and delicious authentic fantastic affordable very is very
#
#
#
# 입력 문장: I recommend it for a night when you want to splurge! (it was a bit expensive)
# 분류: Negative
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# i recommend it for a night when you want to sp ##lu ##rge ! ( it was a bit expensive )
# highest attention: bit was a ! expensive ( you for
#
#
#
# 입력 문장: I have been here, spent tons of money on a chef special dinner and it was a major dissappointment.
# 분류: Negative
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# i have been here , spent tons of money on a chef special dinner and it was a major di ##ssa ##pp ##oint ##ment .
# highest attention: and have i here tons spent major a
#
#
#
# 입력 문장: To start off, approximately 8-10 oz of orange juice will cost you $3.
# 분류: Negative
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# to start off , approximately 8 - 10 oz of orange juice will cost you $ 3 .
# highest attention: you will start off approximately to cost of
#
#
#
# 입력 문장: It's *very* reasonably priced, esp for the quality of the food.
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# it ' s * very * reasonably priced , es ##p for the quality of the food .
# highest attention: * priced reasonably for quality * the es
#
#
#
# 입력 문장: The lunch menu is an awesome deal!
# 분류: Positive
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# the lunch menu is an awesome deal !
# highest attention: is awesome an ! deal the lunch menu
#
#
#
# 입력 문장: The food is great and the prices are reasonable.
# 분류: Positive
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# the food is great and the prices are reasonable .
# highest attention: prices and reasonable great are the food is
#
#
#
# 입력 문장: The food is great (big selection, reasonable prices) and the drinks are really good.
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# the food is great ( big selection , reasonable prices ) and the drinks are really good .
# highest attention: and reasonable prices ( big ) good great
#
#
#
# 입력 문장: We were so happy with our food and were even more thrilled when we saw the bill.
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# we were so happy with our food and were even more thrilled when we saw the bill .
# highest attention: so and we happy saw more thrilled were
#
#
#
# 입력 문장: The food was definitely good, but when all was said and done, I just couldn't justify it for the price (including 2 drinks, $100/person)...
# 분류: Negative
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# the food was definitely good , but when all was said and done , i just couldn ' t justify it for the price ( including 2 drinks , $ 100 / person ) . . .
# highest attention: ' ) but justify when including i and
#
#
#
# 입력 문장: but for the value, it was a great affordable spot to enjoy a fun night out with small group.
# 분류: Positive
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# but for the value , it was a great affordable spot to enjoy a fun night out with small group .
# highest attention: small great fun to with but a was
#
#
#
# 입력 문장: Over priced, overrated....stay away!
# 분류: Negative
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# over priced , over ##rated . . . . stay away !
# highest attention: stay ##rated ! away over over priced [PAD]
#
#
#
# 입력 문장: Food was good and cheap.
# 분류: Positive
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# food was good and cheap .
# highest attention: and cheap good was food [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: The food is not what it once was (potions have seriously seen downsizing) prices have gone up, and the service is the worst I have experienced anywhere (including mainland Europe).
# 분류: Negative
# MAX_LEN:  40
# ========================= emphasize by attention result==========================
# the food is not what it once was ( potion ##s have seriously seen downs ##izing ) prices have gone up , and the service is the worst i have experienced anywhere ( including mainland europe ) .
# highest attention: ) ( not i and is ) the
#
#
#
# 입력 문장: Reasonably priced with very fresh sushi.
# 분류: Positive
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# reasonably priced with very fresh su ##shi .
# highest attention: with reasonably very priced fresh ##shi su [PAD]
#
#
#
# 입력 문장: The prices are not terrible.
# 분류: Positive
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# the prices are not terrible .
# highest attention: terrible not prices the are [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: excellent tapas at great prices, romantic, small but not overly crowed, excellent
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# excellent tap ##as at great prices , romantic , small but not overly crowe ##d , excellent
# highest attention: but great romantic at excellent excellent prices not
#
#
#
# 입력 문장: $6 with tip.
# 분류: Positive
# MAX_LEN:  7
# ========================= emphasize by attention result==========================
# $ 6 with tip .
# highest attention: with tip $ 6 [PAD] [PAD] [PAD] [PAD]
#
#
#
# 입력 문장: The presentation of Snooze is excellent and it is one of those places that you feel more sophisticated just for being there; but peel back the layers and you have an overpriced IHOP with a high brow menu.
# 분류: Negative
# MAX_LEN:  49
# ========================= emphasize by attention result==========================
# the presentation of s ##no ##oz ##e is excellent and it is one of those places that you feel more sophisticated just for being there ; but peel back the layers and you have an over ##pr ##ice ##d i ##hop with a high brow menu .
# highest attention: but high a and brow and sophisticated is
#
#
#
# 입력 문장: Huge portions, great and attentive service, and pretty good prices.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# huge portions , great and at ##ten ##tive service , and pretty good prices .
# highest attention: and and great prices huge good pretty service
#
#
#
# 입력 문장: Fancy pieces of exotic fish on a $100 dollar plate and NOT ONE was eatable.
# 분류: Negative
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# fancy pieces of exotic fish on a $ 100 dollar plate and not one was eat ##able .
# highest attention: and not a on was fancy dollar 100
#
#
#
# 입력 문장: For the amount of food we got the prices should have been lower.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# for the amount of food we got the prices should have been lower .
# highest attention: should the have we for been got lower

# %%
#NAVER test data 세팅

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/naver_price_test.csv'
df = pd.read_csv(test_url,sep=',', header=0,encoding="CP949")
df.head(5)
# Out:
#      id category                                               text  polarity  \
# 0  1605    price            가격대는 좀 있네요.  이건물 식당들.\n모임했는데 분위기 괜찮았어요.         0
# 1  1192    price  맛은 물론이고 오마카세를 가성비 좋은 가격에 즐기기 좋았습니다 평택에서 스시는 여기...         1
# 2   175    price                                     가격도 저렴 하고 맛있어요         1
# 3  1666    price   가격이 좀 비싸긴 하지만... 맛있습니다! \n지나갈 때마다 그냥지나치지 못하네요~~          0
# 4  1188    price  친구들과 점심 뭐먹을까 찾다가 당일로 예약하고갔습니다~ 하나하나 꼼꼼한 설명과 가격...         1
#
#                                           trans_text
# 0  There's a bit of a price range.  The restauran...
# 1  It was good to enjoy omakase at a cost-effecti...
# 2                           It's cheap and delicious
# 3  It's a little expensive, but... It's delicious...
# 4  I was looking for what to eat for lunch with m...

# %%
# naver data에 대한 분류 및 accuracy 측정
count=0

test_text = df.trans_text.values
test_labels = df.polarity.values

NaverWrongResult=[]
NaverRightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].trans_text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
    else:
        result=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        NaverRightResult.append(t)
    else:
        NaverWrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# There's a bit of a price range.  The restaurants in this building.. We had a meeting and the atmosphere was good.
# model result: Positive
# answer: 0
#
# =============================== Input 2 ===============================
# It was good to enjoy omakase at a cost-effective price as well as the taste This is the best sushi restaurant in Pyeongtaek><
# model result: Positive
# answer: 1
#
# =============================== Input 3 ===============================
# It's cheap and delicious
# model result: Positive
# answer: 1
#
# =============================== Input 4 ===============================
# It's a little expensive, but... It's delicious. Every time I pass by, I can't just pass by~~
# model result: Positive
# answer: 0
#
# =============================== Input 5 ===============================
# I was looking for what to eat for lunch with my friends, and I made a reservation for the day. The atmosphere was good and delicious with detailed explanations one by one! I'm willing to come back to dinner next time!
# model result: Positive
# answer: 1
#
# =============================== Input 6 ===============================
# It's been renewed and it's gotten a lot cleaner. Galbi is always cost-effective You can also bring extra meat by yourself and eat snacks at a self-bar, so the cost-effectiveness has improved
# model result: Positive
# answer: 1
#
# =============================== Input 7 ===============================
# It's delicious but it feels expensive.
# model result: Negative
# answer: 0
#
# =============================== Input 8 ===============================
# It's not cheap, but it's delicious♡
# model result: Positive
# answer: 0
#
# =============================== Input 9 ===============================
# Coffee is cheap
# model result: Positive
# answer: 1
#
# =============================== Input 10 ===============================
# Brunch cafe that I came out with my wife after a long time at a reasonable price and the taste is great. I think I'll come often when I think of brunch on the weekend
# model result: Positive
# answer: 1
#
# =============================== Input 11 ===============================
# It's not a lot compared to the price, but it's convenient because you can make a reservation for lunch and it's set up right away.. However, the space between the seats is narrow, but it's a single-person crater, so the inside is a little hot because of the steam everywhere.
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# Kind and cost-effective brunch ^^. It's nice to have a brunch cafe like this in the neighborhood. Coffee is sour and strong, so it's good
# model result: Positive
# answer: 1
#
# =============================== Input 13 ===============================
# In short, rice cake is love. It's cheap and delicious
# model result: Positive
# answer: 1
#
# =============================== Input 14 ===============================
# It is one of the few omakase stores in Anseong, Pyeongtaek, but it was a satisfactory visit because of its good quality for the price It looks okay if the beginners of Omakase go there
# model result: Positive
# answer: 1
#
# =============================== Input 15 ===============================
# It's good for the price. It's good
# model result: Positive
# answer: 1
#
# =============================== Input 16 ===============================
# I want to eat it often if I live close by. It's my second time eating it. It's so delicious that I want to eat it again.. There's a price range. I want to eat it again when I go to Seoul
# model result: Positive
# answer: 0
#
# =============================== Input 17 ===============================
# It's expensive but delicious!
# model result: Negative
# answer: 0
#
# =============================== Input 18 ===============================
# Red bean cream cheese bread is really delicious Ice americano is also the best cost-effectiveness. But it's a bit expensive. Every single one of them is excluded. But it reminds me of the taste
# model result: Negative
# answer: 0
#
# =============================== Input 19 ===============================
# It's good. Cost-effective
# model result: Positive
# answer: 1
#
# =============================== Input 20 ===============================
# Cheese topping is better than chocolate. Isn't the price evil
# model result: Negative
# answer: 0
#
# =============================== Input 21 ===============================
# I went to eat omakase for the first time, and it was kind and the sushi was delicious and I was very satisfiedThe price is good and I want to go to dinner next time!
# model result: Positive
# answer: 1
#
# =============================== Input 22 ===============================
# The price is good and it's so good (Crying)
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# It was delicious, but the amount is small compared to the price.
# model result: Negative
# answer: 0
#
# =============================== Input 24 ===============================
# An old waffle restaurant! I think it was so delicious even though it's been a while since I visited. It's expensive, but it reminds me of the taste
# model result: Negative
# answer: 0
#
# =============================== Input 25 ===============================
# It's good. It's a lot more expensive than when we did the limber waffle
# model result: Negative
# answer: 0
#
# =============================== Input 26 ===============================
# It's too expensive.
# model result: Negative
# answer: 0
#
# =============================== Input 27 ===============================
# The composition is good for the price. There was a terrace, so I enjoyed the meal in a good weather.. I think it'll be a better brunch restaurant if we improve our customer service.
# model result: Positive
# answer: 1
#
# =============================== Input 28 ===============================
# The store is pretty, the staff is kind, and most of all, it's delicious and the amount is large, but it's cheap and good! I ate it deliciously
# model result: Positive
# answer: 1
#
# =============================== Input 29 ===============================
# It's so good. I'm satisfied every time I go, but it's expensive
# model result: Negative
# answer: 0
#
# =============================== Input 30 ===============================
# I bought the Stavia (sugar replacement powder) that Dr. Robin uses. I'm satisfied with putting sugar instead of sugar when I cook at home. I believe it's good for my health and eat it. It's a little expensive, but...
# model result: Negative
# answer: 0
#
# =============================== Input 31 ===============================
# It's a little expensive for lunch, but the steak set is delicious
# model result: Negative
# answer: 0
#
# =============================== Input 32 ===============================
# You were kind even though you were busy. . After going around Deoksugung Palace, it was good to eat on the stone wall.. It's a bit expensive, but I think I'll buy ice cream toppings next time I come near.
# model result: Negative
# answer: 0
#
# =============================== Input 33 ===============================
# The price goes up and the size goes down
# model result: Positive
# answer: 0
#
# =============================== Input 34 ===============================
# It's good to have brunch reasonable price is reasonable
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# It's cheap and delicious!
# model result: Positive
# answer: 1
#
# =============================== Input 36 ===============================
# It's not as good as I expected. Rice grains and fish play separately for sushi, and the cost-effectiveness is not good.
# model result: Negative
# answer: 0
#
# =============================== Input 37 ===============================
# Lunch sets are cheap and plentiful! I really enjoyed the meal. They even gave me an apple because it's Indian Chuseok. Thank you.
# model result: Positive
# answer: 1
#
# =============================== Input 38 ===============================
# The food was delicious for the price. I stuttered when I ordered. It seems like a very suitable store at a sensitive time due to COVID-19. Willing to visit again. I think I can order better next time
# model result: Positive
# answer: 1
#
# =============================== Input 39 ===============================
# It's a bit pricey, but it's good
# model result: Negative
# answer: 0
#
# =============================== Input 40 ===============================
# The taste is okay, but it's too expensive
# model result: Negative
# answer: 0
#
# =============================== Input 41 ===============================
# It's the best jokbal ever. It's so good. Even makguksu...!! It's a little expensive, but I'm satisfied with the taste!
# model result: Negative
# answer: 0
#
# =============================== Input 42 ===============================
# The interior is clean and kind, and I really enjoyed the meal. The quality is so good for the price. It's the best sushi restaurant in Pyeongtaek
# model result: Positive
# answer: 1
#
# =============================== Input 43 ===============================
# Considering the brunch, the price was good and the taste was good
# model result: Positive
# answer: 1
#
# =============================== Input 44 ===============================
# It's my first time going to a restaurant, but the food tastes good and the price range is good, so I think it's a good cost-effective restaurant!! Haha
# model result: Positive
# answer: 1
#
# =============================== Input 45 ===============================
# The price is rather high compared to the taste. It's not a special taste
# model result: Negative
# answer: 0
#
# =============================== Input 46 ===============================
# It feels a little expensive, but I sometimes go there because it's delicious
# model result: Negative
# answer: 0
#
# =============================== Input 47 ===============================
# It's such a famous place that there are many people. It's expensive, but quality is good
# model result: Negative
# answer: 0
#
# =============================== Input 48 ===============================
# It tastes good, but it's expensive
# model result: Negative
# answer: 0
#
# =============================== Input 49 ===============================
# It's a bit expensive, but it's delicious
# model result: Negative
# answer: 0
#
# =============================== Input 50 ===============================
# Both my husband and I felt that it was too salty. It's not soft, but if you try to pick up meat, it gets crushed and the composition is expensive.
# model result: Negative
# answer: 0
#
# =============================== Input 51 ===============================
# Pollack roe mayo crab meat sandwich with a good speed and a 500 won discount if you pack it, so I packed it for breakfast the next day! It was just as delicious the next day! Thank you for the delicious meal
# model result: Positive
# answer: 1
#
# =============================== Input 52 ===============================
# Panini is good. It's good to eat lightly. Personally, I don't think the price/composition is enough
# model result: Positive
# answer: 0
#
# =============================== Input 53 ===============================
# They bake it right away, but there are a lot of customers who buy boxes, so you have to wait! I think the ingredients are good, but the waffle dough tastes bland. I think it's expensive for the price.
# model result: Negative
# answer: 0
#
# =============================== Input 54 ===============================
# It's cheap, but it's high quality and delicious. This is the Omakase restaurant that I'm willing to revisit whenever I go to Pyeongtaek
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# The price goes up and the size of the bread goes down..I'm not coming back
# model result: Negative
# answer: 0
#
# =============================== Input 56 ===============================
# I waited and bought it because I was looking forward to it and bought it. I bought two sets of five, but it tastes good, but it's expensive and tastes better than I expected^^;
# model result: Negative
# answer: 0
#
# =============================== Input 57 ===============================
# It's good, cheap, and good
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# French toast is delicious! It's sweet and soft! Affordable and price satisfaction! Thank you for the food
# model result: Positive
# answer: 1
#
# =============================== Input 59 ===============================
# It's delicious but expensive
# model result: Negative
# answer: 0
#
# =============================== Input 60 ===============================
# Personally, it's not that great for the price It's personal, but the taste is medium or higher, so I think I'll eat something else at a low price If the price is a little cheap, it's not bad for the cost-effectiveness
# model result: Positive
# answer: 0
#
# =============================== Input 61 ===============================
# It's salty and delicious. The meat tastes really good. It's really good. The price is cheap and the chocolate you get for dessert is great. This is my second time visiting because you were so kind :)
# model result: Positive
# answer: 1
#
# =============================== Input 62 ===============================
# I ate tonkotsu ramen, and the soup was strong, there were a lot of bean sprouts, and it was delicious. Above all, the price was very cheap, so considering that it was 7,000 won, it was a very satisfying meal
# model result: Positive
# answer: 1
#
# =============================== Input 63 ===============================
# It's good! And there's too much! The big advantage is that you can choose the low price and spicy level. Fried rice is good, too. He's so kind Thank you for the food!!
# model result: Positive
# answer: 1
# =============================== Input 64 ===============================
# It's very cost-effective. It tastes like tteokbokki that I ate in front of my school.
# model result: Positive
# answer: 1
#
# =============================== Input 65 ===============================
# Found it while looking for a brunch place near my house to move in! The price is cheap, but both of the menus are so delicious that I often make a reservation. The owner is so kind too~~ :D
# model result: Positive
# answer: 1
#
# =============================== Input 66 ===============================
# I bought a coupon and ate it cheaper~It's cheap and is easy to eat because it's unlimited refills~
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# It was a great time to be able to eat this quality food at this price.
# model result: Positive
# answer: 1
#
# =============================== Input 68 ===============================
# Overall, the Sharigan was reasonable and was the most delicious among the nearby omakase for the price. I think I will go there often.
# model result: Positive
# answer: 1
#
# =============================== Input 69 ===============================
# It's cheap, and it tastes good
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# Sukiyaki is a little expensive, but it's delicious
# model result: Negative
# answer: 0
#
# =============================== Input 71 ===============================
# The amount is a little small for the price. It doesn't smell bad. Just record it in your mouth!
# model result: Negative
# answer: 0
#
# =============================== Input 72 ===============================
# It's a brunch restaurant with good cost-effectiveness
# model result: Positive
# answer: 1
#
# =============================== Input 73 ===============================
# It's an interesting restaurant that you don't go to because it's near the company. Fresh hot waffles are chewy and delicious. It's just that the price has gone up a lot.. 3,900 won is a bit..
# model result: Positive
# answer: 0
#
# =============================== Input 74 ===============================
# Since it's a university street, brunch is cheap and has a cozy atmosphere. I'd love to.
# model result: Positive
# answer: 1
#
# =============================== Input 75 ===============================
# It's cheap and delicious
# model result: Positive
# answer: 1
#
# =============================== Input 76 ===============================
# The staff is not friendly. The food is a little salty and I don't know about the price…
# model result: Negative
# answer: 0
#
# =============================== Input 77 ===============================
# It's fresh and delicious lol. I'm a woman and I'm not a big eater.. The amount was less. I think men need more. The price is cheap for omakase, so that's why
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# Cost-effective sushi omakase. I hope you pay more attention to Shari. I look forward to matching it with wine next time!
# model result: Negative
# answer: 1
#
# =============================== Input 79 ===============================
# It's my first time going to Omakase for the price
# model result: Negative
# answer: 0
#
# =============================== Input 80 ===============================
# The owner was kind, cared about the cleanliness, and the table was wide-spaced, so I could eat comfortably! The food is good for the price They pack and order a lot!
# model result: Positive
# answer: 1
#
# =============================== Input 81 ===============================
# It's the best cost-effective!
# model result: Positive
# answer: 1
#
# =============================== Input 82 ===============================
# It's a house I go to often, but it feels expensive.
# model result: Negative
# answer: 0
#
# =============================== Input 83 ===============================
# It's a waste of money. When I asked for a bowl, you didn't understand, and when I asked if I was giving you pickled radish, you screamed that it was in the container. I don't know. The tea is thin, unfriendly, and the ramen taste is not good, so I came out while eating it
# model result: Negative
# answer: 0
#
# =============================== Input 84 ===============================
# It's a good restaurant with good cost-effectiveness^^
# model result: Positive
# answer: 1
#
# =============================== Input 85 ===============================
# It's my first time using Omakase, and they kindly explained it to me. I really enjoyed the foodAnd the price based on omakase is good, so I'm satisfied with many things!!
# model result: Positive
# answer: 1
#
# =============================== Input 86 ===============================
# It's good. It's cost effective
# model result: Positive
# answer: 1
#
# =============================== Input 87 ===============================
# The quality of Omakase was so good, but the price was cheap, so it's a good place to enjoy Omakase because the chef was so kind, so I had a happy time :)
# model result: Positive
# answer: 1
#
# =============================== Input 88 ===============================
# It was nice to be able to eat comfortably and kindly.. Sushi and tsukumami were just right and delicious :). I enjoyed omakase at a reasonable price.
# model result: Positive
# answer: 1
#
# =============================== Input 89 ===============================
# It's a little expensive, but I trusted the ingredients and ate it well.
# model result: Negative
# answer: 0
#
# =============================== Input 90 ===============================
# in a price range. There are many seats and many menus. Mostly delicious
# model result: Positive
# answer: 0
#
# =============================== Input 91 ===============================
# It's good. It's a bit expensive...
# model result: Negative
# answer: 0
#
# =============================== Input 92 ===============================
# It's cost-effective. It's better than an expensive curry place
# model result: Negative
# answer: 1
#
# =============================== Input 93 ===============================
# It is a famous jokbal restaurant, but I don't know about jokbal because I only ate lunch specials.. The lunch bossam set is not good for the cost-effectiveness.. A few slices of bossam came out and it's over.. It needs to be supplemented.
# model result: Negative
# answer: 0
#
# =============================== Input 94 ===============================
# Well, the price range is expensive. Curry is delicious
# model result: Positive
# answer: 0
#
# =============================== Input 95 ===============================
# Pasta, toast, pasta, and coffee are all delicious. Especially, the amount and taste are really good for the price!
# model result: Positive
# answer: 1
#
# =============================== Input 96 ===============================
# It's pricey, but the food is delicious
# model result: Negative
# answer: 0
#
# =============================== Input 97 ===============================
# It's expensive compared to the waffle menu, but the taste seems to be luxurious because it seems to use inexpensive ingredients.  The taste of chocolate is not cheap, it's like a proper chocolate.
# model result: Negative
# answer: 0
#
# =============================== Input 98 ===============================
# The amount is a little small compared to the price, but it's still good, so I'll come back to buy it again! I only ate the famous place in Gangwon-do, but I'm going to clean up the place and the chicken gangjeong is the sweet and sour chicken^^
# model result: Negative
# answer: 0
#
# =============================== Input 99 ===============================
# The price is going up Too much
# model result: Negative
# answer: 0
#
# =============================== Input 100 ===============================
# The cafe atmosphere is good and the price is cheap, so the food is clean and delicious I want to come again next time
# model result: Positive
# answer: 1
#
# test accuracy: 0.8800

# %%
#잘못 분류된 문장의 attention
for sent in NaverWrongResult:
    encoding = preprocessing(sent, tokenizer,50)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: There's a bit of a price range.  The restaurants in this building.. We had a meeting and the atmosphere was good.
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# there ' s a bit of a price range . the restaurants in this building . . we had a meeting and the atmosphere was good .
# highest attention: good atmosphere and was
#
#
#
# 입력 문장: It's not a lot compared to the price, but it's convenient because you can make a reservation for lunch and it's set up right away.. However, the space between the seats is narrow, but it's a single-person crater, so the inside is a little hot because of the steam everywhere.
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it ' s not a lot compared to the price , but it ' s convenient because you can make a reservation for lunch and it ' s set up right away . . however , the space between the seats is narrow , but it ' s
# highest attention: convenient price narrow right
#
#
#
# 입력 문장: I want to eat it often if I live close by. It's my second time eating it. It's so delicious that I want to eat it again.. There's a price range. I want to eat it again when I go to Seoul
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# i want to eat it often if i live close by . it ' s my second time eating it . it ' s so delicious that i want to eat it again . . there ' s a price range . i want to eat it again
# highest attention: delicious range often second
#
#
#
# 입력 문장: Cheese topping is better than chocolate. Isn't the price evil
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# cheese topping is better than chocolate . isn ' t the price evil
# highest attention: ' evil t price
#
#
#
# 입력 문장: It's the best jokbal ever. It's so good. Even makguksu...!! It's a little expensive, but I'm satisfied with the taste!
# 분류: Positive
# MAX_LEN:  45
# ========================= emphasize by attention result==========================
# it ' s the best jo ##k ##bal ever . it ' s so good . even ma ##k ##gu ##ks ##u . . . ! ! it ' s a little expensive , but i ' m satisfied with the taste !
# highest attention: ' so but expensive
#
#
#
# 입력 문장: It's good! And there's too much! The big advantage is that you can choose the low price and spicy level. Fried rice is good, too. He's so kind Thank you for the food!!
# 분류: Negative
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# it ' s good ! and there ' s too much ! the big advantage is that you can choose the low price and spicy level . fried rice is good , too . he ' s so kind thank you for the food ! !
# highest attention: ' too and much
#
#
#
# 입력 문장: The amount is a little small for the price. It doesn't smell bad. Just record it in your mouth!
# 분류: Positive
# MAX_LEN:  26
# ========================= emphasize by attention result==========================
# the amount is a little small for the price . it doesn ' t smell bad . just record it in your mouth !
# highest attention: ! small record price
#
#
#
# 입력 문장: It's an interesting restaurant that you don't go to because it's near the company. Fresh hot waffles are chewy and delicious. It's just that the price has gone up a lot.. 3,900 won is a bit..
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it ' s an interesting restaurant that you don ' t go to because it ' s near the company . fresh hot wa ##ffle ##s are chew ##y and delicious . it ' s just that the price has gone up a lot . . 3 ,
# highest attention: ' delicious chew and
#
#
#
# 입력 문장: in a price range. There are many seats and many menus. Mostly delicious
# 분류: Positive
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# in a price range . there are many seats and many menu ##s . mostly delicious
# highest attention: delicious mostly many many
#
#
#
# 입력 문장: The amount is a little small compared to the price, but it's still good, so I'll come back to buy it again! I only ate the famous place in Gangwon-do, but I'm going to clean up the place and the chicken gangjeong is the sweet and sour chicken^^
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# the amount is a little small compared to the price , but it ' s still good , so i ' ll come back to buy it again ! i only ate the famous place in gang ##won - do , but i ' m going to clean
# highest attention: ' ' but ate

# %%
#잘 분류된 문장의 attention
for sent in NaverRightResult:
    encoding = preprocessing(sent, tokenizer,50)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: It was good to enjoy omakase at a cost-effective price as well as the taste This is the best sushi restaurant in Pyeongtaek><
# 분류: Positive
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# it was good to enjoy om ##aka ##se at a cost - effective price as well as the taste this is the best su ##shi restaurant in p ##ye ##ong ##ta ##ek > <
# highest attention: at a price cost
#
#
#
# 입력 문장: It's cheap and delicious
# 분류: Positive
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# it ' s cheap and delicious
# highest attention: cheap delicious s and
#
#
#
# 입력 문장: It's a little expensive, but... It's delicious. Every time I pass by, I can't just pass by~~
# 분류: Negative
# MAX_LEN:  33
# ========================= emphasize by attention result==========================
# it ' s a little expensive , but . . . it ' s delicious . every time i pass by , i can ' t just pass by ~ ~
# highest attention: expensive but ~ delicious
#
#
#
# 입력 문장: I was looking for what to eat for lunch with my friends, and I made a reservation for the day. The atmosphere was good and delicious with detailed explanations one by one! I'm willing to come back to dinner next time!
# 분류: Positive
# MAX_LEN:  49
# ========================= emphasize by attention result==========================
# i was looking for what to eat for lunch with my friends , and i made a reservation for the day . the atmosphere was good and delicious with detailed explanations one by one ! i ' m willing to come back to dinner next time !
# highest attention: ' delicious good detailed
#
#
#
# 입력 문장: It's been renewed and it's gotten a lot cleaner. Galbi is always cost-effective You can also bring extra meat by yourself and eat snacks at a self-bar, so the cost-effectiveness has improved
# 분류: Positive
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# it ' s been renewed and it ' s gotten a lot cleaner . gal ##bi is always cost - effective you can also bring extra meat by yourself and eat snacks at a self - bar , so the cost - effectiveness has improved
# highest attention: always you meat extra
#
#
#
# 입력 문장: It's delicious but it feels expensive.
# 분류: Negative
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# it ' s delicious but it feels expensive .
# highest attention: expensive feels but it
#
#
#
# 입력 문장: It's not cheap, but it's delicious♡
# 분류: Negative
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# it ' s not cheap , but it ' s [UNK]
# highest attention: not [UNK] cheap s
#
#
#
# 입력 문장: Coffee is cheap
# 분류: Positive
# MAX_LEN:  5
# ========================= emphasize by attention result==========================
# coffee is cheap
# highest attention: cheap is coffee [PAD]
#
#
#
# 입력 문장: Brunch cafe that I came out with my wife after a long time at a reasonable price and the taste is great. I think I'll come often when I think of brunch on the weekend
# 분류: Positive
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# br ##un ##ch cafe that i came out with my wife after a long time at a reasonable price and the taste is great . i think i ' ll come often when i think of br ##un ##ch on the weekend
# highest attention: ' reasonable at a
#
#
#
# 입력 문장: Kind and cost-effective brunch ^^. It's nice to have a brunch cafe like this in the neighborhood. Coffee is sour and strong, so it's good
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# kind and cost - effective br ##un ##ch ^ ^ . it ' s nice to have a br ##un ##ch cafe like this in the neighborhood . coffee is sour and strong , so it ' s good
# highest attention: and kind effective cost
#
#
#
# 입력 문장: In short, rice cake is love. It's cheap and delicious
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# in short , rice cake is love . it ' s cheap and delicious
# highest attention: cheap delicious and s
#
#
#
# 입력 문장: It is one of the few omakase stores in Anseong, Pyeongtaek, but it was a satisfactory visit because of its good quality for the price It looks okay if the beginners of Omakase go there
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it is one of the few om ##aka ##se stores in an ##se ##ong , p ##ye ##ong ##ta ##ek , but it was a satisfactory visit because of its good quality for the price it looks okay if the begin ##ners of om ##aka ##se go there
# highest attention: for good quality because
#
#
#
# 입력 문장: It's good for the price. It's good
# 분류: Positive
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# it ' s good for the price . it ' s good
# highest attention: good s it '
#
#
#
# 입력 문장: It's expensive but delicious!
# 분류: Negative
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# it ' s expensive but delicious !
# highest attention: expensive ! s '
#
#
#
# 입력 문장: Red bean cream cheese bread is really delicious Ice americano is also the best cost-effectiveness. But it's a bit expensive. Every single one of them is excluded. But it reminds me of the taste
# 분류: Negative
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# red bean cream cheese bread is really delicious ice american ##o is also the best cost - effectiveness . but it ' s a bit expensive . every single one of them is excluded . but it reminds me of the taste
# highest attention: expensive bit but excluded
#
#
#
# 입력 문장: It's good. Cost-effective
# 분류: Positive
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# it ' s good . cost - effective
# highest attention: ' good effective s
#
#
#
# 입력 문장: I went to eat omakase for the first time, and it was kind and the sushi was delicious and I was very satisfiedThe price is good and I want to go to dinner next time!
# 분류: Positive
# MAX_LEN:  43
# ========================= emphasize by attention result==========================
# i went to eat om ##aka ##se for the first time , and it was kind and the su ##shi was delicious and i was very satisfied ##the price is good and i want to go to dinner next time !
# highest attention: ##the delicious kind good
#
#
#
# 입력 문장: The price is good and it's so good (Crying)
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# the price is good and it ' s so good ( crying )
# highest attention: ) price good is
#
#
#
# 입력 문장: It was delicious, but the amount is small compared to the price.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# it was delicious , but the amount is small compared to the price .
# highest attention: but small is amount
#
#
#
# 입력 문장: An old waffle restaurant! I think it was so delicious even though it's been a while since I visited. It's expensive, but it reminds me of the taste
# 분류: Negative
# MAX_LEN:  38
# ========================= emphasize by attention result==========================
# an old wa ##ffle restaurant ! i think it was so delicious even though it ' s been a while since i visited . it ' s expensive , but it reminds me of the taste
# highest attention: ' expensive even !
#
#
#
# 입력 문장: It's good. It's a lot more expensive than when we did the limber waffle
# 분류: Negative
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# it ' s good . it ' s a lot more expensive than when we did the limb ##er wa ##ffle
# highest attention: expensive than s lot
#
#
#
# 입력 문장: It's too expensive.
# 분류: Negative
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# it ' s too expensive .
# highest attention: expensive too s '
#
#
#
# 입력 문장: The composition is good for the price. There was a terrace, so I enjoyed the meal in a good weather.. I think it'll be a better brunch restaurant if we improve our customer service.
# 분류: Positive
# MAX_LEN:  45
# ========================= emphasize by attention result==========================
# the composition is good for the price . there was a terrace , so i enjoyed the meal in a good weather . . i think it ' ll be a better br ##un ##ch restaurant if we improve our customer service .
# highest attention: ' good weather is
#
#
#
# 입력 문장: The store is pretty, the staff is kind, and most of all, it's delicious and the amount is large, but it's cheap and good! I ate it deliciously
# 분류: Positive
# MAX_LEN:  40
# ========================= emphasize by attention result==========================
# the store is pretty , the staff is kind , and most of all , it ' s delicious and the amount is large , but it ' s cheap and good ! i ate it delicious ##ly
# highest attention: but delicious ! delicious
#
#
#
# 입력 문장: It's so good. I'm satisfied every time I go, but it's expensive
# 분류: Negative
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# it ' s so good . i ' m satisfied every time i go , but it ' s expensive
# highest attention: ' expensive but it
#
#
#
# 입력 문장: I bought the Stavia (sugar replacement powder) that Dr. Robin uses. I'm satisfied with putting sugar instead of sugar when I cook at home. I believe it's good for my health and eat it. It's a little expensive, but...
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# i bought the st ##avia ( sugar replacement powder ) that dr . robin uses . i ' m satisfied with putting sugar instead of sugar when i cook at home . i believe it ' s good for my health and eat it . it ' s
# highest attention: ) ' ' sugar
#
#
#
# 입력 문장: It's a little expensive for lunch, but the steak set is delicious
# 분류: Negative
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# it ' s a little expensive for lunch , but the steak set is delicious
# highest attention: expensive but little s
#
#
#
# 입력 문장: You were kind even though you were busy. . After going around Deoksugung Palace, it was good to eat on the stone wall.. It's a bit expensive, but I think I'll buy ice cream toppings next time I come near.
# 분류: Negative
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# you were kind even though you were busy . . after going around de ##ok ##su ##gun ##g palace , it was good to eat on the stone wall . . it ' s a bit expensive , but i think i ' ll buy ice cream topping
# highest attention: ' expensive bit after
#
#
#
# 입력 문장: The price goes up and the size goes down
# 분류: Negative
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# the price goes up and the size goes down
# highest attention: up down and the
#
#
#
# 입력 문장: It's good to have brunch reasonable price is reasonable
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# it ' s good to have br ##un ##ch reasonable price is reasonable
# highest attention: ' reasonable reasonable price
#
#
#
# 입력 문장: It's cheap and delicious!
# 분류: Positive
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# it ' s cheap and delicious !
# highest attention: ' cheap delicious !
#
#
#
# 입력 문장: It's not as good as I expected. Rice grains and fish play separately for sushi, and the cost-effectiveness is not good.
# 분류: Negative
# MAX_LEN:  31
# ========================= emphasize by attention result==========================
# it ' s not as good as i expected . rice grains and fish play separately for su ##shi , and the cost - effectiveness is not good .
# highest attention: not not and is
#
#
#
# 입력 문장: Lunch sets are cheap and plentiful! I really enjoyed the meal. They even gave me an apple because it's Indian Chuseok. Thank you.
# 분류: Positive
# MAX_LEN:  35
# ========================= emphasize by attention result==========================
# lunch sets are cheap and pl ##ent ##iful ! i really enjoyed the meal . they even gave me an apple because it ' s indian chu ##se ##ok . thank you .
# highest attention: ! really enjoyed i
#
#
#
# 입력 문장: The food was delicious for the price. I stuttered when I ordered. It seems like a very suitable store at a sensitive time due to COVID-19. Willing to visit again. I think I can order better next time
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# the food was delicious for the price . i stu ##ttered when i ordered . it seems like a very suitable store at a sensitive time due to co ##vid - 19 . willing to visit again . i think i can order better next time
# highest attention: sensitive due to for
#
#
#
# 입력 문장: It's a bit pricey, but it's good
# 분류: Negative
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# it ' s a bit price ##y , but it ' s good
# highest attention: but price ##y bit
#
#
#
# 입력 문장: The taste is okay, but it's too expensive
# 분류: Negative
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# the taste is okay , but it ' s too expensive
# highest attention: expensive too s '
#
#
#
# 입력 문장: The interior is clean and kind, and I really enjoyed the meal. The quality is so good for the price. It's the best sushi restaurant in Pyeongtaek
# 분류: Positive
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# the interior is clean and kind , and i really enjoyed the meal . the quality is so good for the price . it ' s the best su ##shi restaurant in p ##ye ##ong ##ta ##ek
# highest attention: ' clean for quality
#
#
#
# 입력 문장: Considering the brunch, the price was good and the taste was good
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# considering the br ##un ##ch , the price was good and the taste was good
# highest attention: price taste good the
#
#
#
# 입력 문장: It's my first time going to a restaurant, but the food tastes good and the price range is good, so I think it's a good cost-effective restaurant!! Haha
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# it ' s my first time going to a restaurant , but the food tastes good and the price range is good , so i think it ' s a good cost - effective restaurant ! ! ha ##ha
# highest attention: ' but range cost
#
#
#
# 입력 문장: The price is rather high compared to the taste. It's not a special taste
# 분류: Negative
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# the price is rather high compared to the taste . it ' s not a special taste
# highest attention: high rather not price
#
#
#
# 입력 문장: It feels a little expensive, but I sometimes go there because it's delicious
# 분류: Negative
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# it feels a little expensive , but i sometimes go there because it ' s delicious
# highest attention: expensive little feels but
#
#
#
# 입력 문장: It's such a famous place that there are many people. It's expensive, but quality is good
# 분류: Negative
# MAX_LEN:  24
# ========================= emphasize by attention result==========================
# it ' s such a famous place that there are many people . it ' s expensive , but quality is good
# highest attention: expensive but s '
#
#
#
# 입력 문장: It tastes good, but it's expensive
# 분류: Negative
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# it tastes good , but it ' s expensive
# highest attention: expensive but s '
#
#
#
# 입력 문장: It's a bit expensive, but it's delicious
# 분류: Negative
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# it ' s a bit expensive , but it ' s delicious
# highest attention: expensive but bit delicious
#
#
#
# 입력 문장: Both my husband and I felt that it was too salty. It's not soft, but if you try to pick up meat, it gets crushed and the composition is expensive.
# 분류: Negative
# MAX_LEN:  38
# ========================= emphasize by attention result==========================
# both my husband and i felt that it was too salty . it ' s not soft , but if you try to pick up meat , it gets crushed and the composition is expensive .
# highest attention: expensive and too is
#
#
#
# 입력 문장: Pollack roe mayo crab meat sandwich with a good speed and a 500 won discount if you pack it, so I packed it for breakfast the next day! It was just as delicious the next day! Thank you for the delicious meal
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# poll ##ack roe mayo crab meat sandwich with a good speed and a 500 won discount if you pack it , so i packed it for breakfast the next day ! it was just as delicious the next day ! thank you for the delicious meal
# highest attention: speed good delicious a
#
#
#
# 입력 문장: Panini is good. It's good to eat lightly. Personally, I don't think the price/composition is enough
# 분류: Negative
# MAX_LEN:  28
# ========================= emphasize by attention result==========================
# pan ##ini is good . it ' s good to eat lightly . personally , i don ' t think the price / composition is enough
# highest attention: personally t / '
#
#
#
# 입력 문장: They bake it right away, but there are a lot of customers who buy boxes, so you have to wait! I think the ingredients are good, but the waffle dough tastes bland. I think it's expensive for the price.
# 분류: Negative
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# they ba ##ke it right away , but there are a lot of customers who buy boxes , so you have to wait ! i think the ingredients are good , but the wa ##ffle dough tastes bland . i think it ' s expensive for the price
# highest attention: ! expensive bland so
#
#
#
# 입력 문장: It's cheap, but it's high quality and delicious. This is the Omakase restaurant that I'm willing to revisit whenever I go to Pyeongtaek
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# it ' s cheap , but it ' s high quality and delicious . this is the om ##aka ##se restaurant that i ' m willing to rev ##isi ##t whenever i go to p ##ye ##ong ##ta ##ek
# highest attention: ' high but delicious
#
#
#
# 입력 문장: The price goes up and the size of the bread goes down..I'm not coming back
# 분류: Negative
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# the price goes up and the size of the bread goes down . . i ' m not coming back
# highest attention: ' and up size
#
#
#
# 입력 문장: I waited and bought it because I was looking forward to it and bought it. I bought two sets of five, but it tastes good, but it's expensive and tastes better than I expected^^;
# 분류: Negative
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# i waited and bought it because i was looking forward to it and bought it . i bought two sets of five , but it tastes good , but it ' s expensive and tastes better than i expected ^ ^ ;
# highest attention: but expensive ^ and
#
#
#
# 입력 문장: It's good, cheap, and good
# 분류: Positive
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# it ' s good , cheap , and good
# highest attention: cheap and s it
#
#
#
# 입력 문장: French toast is delicious! It's sweet and soft! Affordable and price satisfaction! Thank you for the food
# 분류: Positive
# MAX_LEN:  24
# ========================= emphasize by attention result==========================
# french toast is delicious ! it ' s sweet and soft ! affordable and price satisfaction ! thank you for the food
# highest attention: ' affordable satisfaction sweet
#
#
#
# 입력 문장: It's delicious but expensive
# 분류: Negative
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# it ' s delicious but expensive
# highest attention: expensive but s '
#
#
#
# 입력 문장: Personally, it's not that great for the price It's personal, but the taste is medium or higher, so I think I'll eat something else at a low price If the price is a little cheap, it's not bad for the cost-effectiveness
# 분류: Negative
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# personally , it ' s not that great for the price it ' s personal , but the taste is medium or higher , so i think i ' ll eat something else at a low price if the price is a little cheap , it ' s
# highest attention: ' medium low higher
#
#
#
# 입력 문장: It's salty and delicious. The meat tastes really good. It's really good. The price is cheap and the chocolate you get for dessert is great. This is my second time visiting because you were so kind :)
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# it ' s salty and delicious . the meat tastes really good . it ' s really good . the price is cheap and the chocolate you get for dessert is great . this is my second time visiting because you were so kind : )
# highest attention: cheap great salty is
#
#
#
# 입력 문장: I ate tonkotsu ramen, and the soup was strong, there were a lot of bean sprouts, and it was delicious. Above all, the price was very cheap, so considering that it was 7,000 won, it was a very satisfying meal
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# i ate ton ##kot ##su ram ##en , and the soup was strong , there were a lot of bean sp ##rou ##ts , and it was delicious . above all , the price was very cheap , so considering that it was 7 , 000 won ,
# highest attention: strong delicious cheap very
#
#
#
# 입력 문장: It's very cost-effective. It tastes like tteokbokki that I ate in front of my school.
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# it ' s very cost - effective . it tastes like tt ##eo ##k ##bo ##kki that i ate in front of my school .
# highest attention: very it s tastes
#
#
#
# 입력 문장: Found it while looking for a brunch place near my house to move in! The price is cheap, but both of the menus are so delicious that I often make a reservation. The owner is so kind too~~ :D
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# found it while looking for a br ##un ##ch place near my house to move in ! the price is cheap , but both of the menu ##s are so delicious that i often make a reservation . the owner is so kind too ~ ~ : d
# highest attention: but both delicious !
#
#
#
# 입력 문장: I bought a coupon and ate it cheaper~It's cheap and is easy to eat because it's unlimited refills~
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# i bought a coup ##on and ate it cheaper ~ it ' s cheap and is easy to eat because it ' s unlimited ref ##ill ##s ~
# highest attention: cheaper cheap s and
#
#
#
# 입력 문장: It was a great time to be able to eat this quality food at this price.
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it was a great time to be able to eat this quality food at this price .
# highest attention: price quality great at
#
#
#
# 입력 문장: Overall, the Sharigan was reasonable and was the most delicious among the nearby omakase for the price. I think I will go there often.
# 분류: Positive
# MAX_LEN:  33
# ========================= emphasize by attention result==========================
# overall , the sha ##ri ##gan was reasonable and was the most delicious among the nearby om ##aka ##se for the price . i think i will go there often .
# highest attention: reasonable delicious overall was
#
#
#
# 입력 문장: It's cheap, and it tastes good
# 분류: Positive
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# it ' s cheap , and it tastes good
# highest attention: cheap tastes s and
#
#
#
# 입력 문장: Sukiyaki is a little expensive, but it's delicious
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# su ##ki ##ya ##ki is a little expensive , but it ' s delicious
# highest attention: expensive but little delicious
#
#
#
# 입력 문장: It's a brunch restaurant with good cost-effectiveness
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# it ' s a br ##un ##ch restaurant with good cost - effectiveness
# highest attention: ' good with s
#
#
#
# 입력 문장: Since it's a university street, brunch is cheap and has a cozy atmosphere. I'd love to.
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# since it ' s a university street , br ##un ##ch is cheap and has a cozy atmosphere . i ' d love to .
# highest attention: ' cheap cozy atmosphere
#
#
#
# 입력 문장: It's cheap and delicious
# 분류: Positive
# MAX_LEN:  8
# ========================= emphasize by attention result==========================
# it ' s cheap and delicious
# highest attention: cheap delicious s and
#
#
#
# 입력 문장: The staff is not friendly. The food is a little salty and I don't know about the price…
# 분류: Negative
# MAX_LEN:  24
# ========================= emphasize by attention result==========================
# the staff is not friendly . the food is a little salty and i don ' t know about the price …
# highest attention: not salty is and
#
#
#
# 입력 문장: It's fresh and delicious lol. I'm a woman and I'm not a big eater.. The amount was less. I think men need more. The price is cheap for omakase, so that's why
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it ' s fresh and delicious lo ##l . i ' m a woman and i ' m not a big eater . . the amount was less . i think men need more . the price is cheap for om ##aka ##se , so that ' s
# highest attention: ' ' not delicious
#
#
#
# 입력 문장: Cost-effective sushi omakase. I hope you pay more attention to Shari. I look forward to matching it with wine next time!
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# cost - effective su ##shi om ##aka ##se . i hope you pay more attention to sha ##ri . i look forward to matching it with wine next time !
# highest attention: more hope cost wine
#
#
#
# 입력 문장: It's my first time going to Omakase for the price
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# it ' s my first time going to om ##aka ##se for the price
# highest attention: price for first the
#
#
#
# 입력 문장: The owner was kind, cared about the cleanliness, and the table was wide-spaced, so I could eat comfortably! The food is good for the price They pack and order a lot!
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# the owner was kind , cared about the clean ##liness , and the table was wide - spaced , so i could eat comfortably ! the food is good for the price they pack and order a lot !
# highest attention: ! is ! good
#
#
#
# 입력 문장: It's the best cost-effective!
# 분류: Positive
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# it ' s the best cost - effective !
# highest attention: ' ! it best
#
#
#
# 입력 문장: It's a house I go to often, but it feels expensive.
# 분류: Negative
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# it ' s a house i go to often , but it feels expensive .
# highest attention: expensive feels but it
#
#
#
# 입력 문장: It's a waste of money. When I asked for a bowl, you didn't understand, and when I asked if I was giving you pickled radish, you screamed that it was in the container. I don't know. The tea is thin, unfriendly, and the ramen taste is not good, so I came out while eating it
# 분류: Negative
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it ' s a waste of money . when i asked for a bowl , you didn ' t understand , and when i asked if i was giving you pick ##led ra ##dis ##h , you screamed that it was in the container . i don '
# highest attention: and waste s you
#
#
#
# 입력 문장: It's a good restaurant with good cost-effectiveness^^
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# it ' s a good restaurant with good cost - effectiveness ^ ^
# highest attention: ' good good with
#
#
#
# 입력 문장: It's my first time using Omakase, and they kindly explained it to me. I really enjoyed the foodAnd the price based on omakase is good, so I'm satisfied with many things!!
# 분류: Positive
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# it ' s my first time using om ##aka ##se , and they kindly explained it to me . i really enjoyed the food ##and the price based on om ##aka ##se is good , so i ' m satisfied with many things ! !
# highest attention: ' ##and food they
#
#
#
# 입력 문장: It's good. It's cost effective
# 분류: Positive
# MAX_LEN:  12
# ========================= emphasize by attention result==========================
# it ' s good . it ' s cost effective
# highest attention: effective s ' it
#
#
#
# 입력 문장: The quality of Omakase was so good, but the price was cheap, so it's a good place to enjoy Omakase because the chef was so kind, so I had a happy time :)
# 분류: Positive
# MAX_LEN:  45
# ========================= emphasize by attention result==========================
# the quality of om ##aka ##se was so good , but the price was cheap , so it ' s a good place to enjoy om ##aka ##se because the chef was so kind , so i had a happy time : )
# highest attention: ' but happy kind
#
#
#
# 입력 문장: It was nice to be able to eat comfortably and kindly.. Sushi and tsukumami were just right and delicious :). I enjoyed omakase at a reasonable price.
# 분류: Positive
# MAX_LEN:  40
# ========================= emphasize by attention result==========================
# it was nice to be able to eat comfortably and kindly . . su ##shi and ts ##uk ##uma ##mi were just right and delicious : ) . i enjoyed om ##aka ##se at a reasonable price .
# highest attention: at reasonable a comfortably
#
#
#
# 입력 문장: It's a little expensive, but I trusted the ingredients and ate it well.
# 분류: Negative
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it ' s a little expensive , but i trusted the ingredients and ate it well .
# highest attention: expensive but little well
#
#
#
# 입력 문장: It's good. It's a bit expensive...
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# it ' s good . it ' s a bit expensive . . .
# highest attention: ' expensive bit s
#
#
#
# 입력 문장: It's cost-effective. It's better than an expensive curry place
# 분류: Positive
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# it ' s cost - effective . it ' s better than an expensive curry place
# highest attention: ' s ' it
#
#
#
# 입력 문장: It is a famous jokbal restaurant, but I don't know about jokbal because I only ate lunch specials.. The lunch bossam set is not good for the cost-effectiveness.. A few slices of bossam came out and it's over.. It needs to be supplemented.
# 분류: Negative
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it is a famous jo ##k ##bal restaurant , but i don ' t know about jo ##k ##bal because i only ate lunch specials . . the lunch boss ##am set is not good for the cost - effectiveness . . a few slices of boss ##am
# highest attention: not because is restaurant
#
#
#
# 입력 문장: Well, the price range is expensive. Curry is delicious
# 분류: Negative
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# well , the price range is expensive . curry is delicious
# highest attention: expensive curry well is
#
#
#
# 입력 문장: Pasta, toast, pasta, and coffee are all delicious. Especially, the amount and taste are really good for the price!
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# pasta , toast , pasta , and coffee are all delicious . especially , the amount and taste are really good for the price !
# highest attention: amount taste good !
#
#
#
# 입력 문장: It's pricey, but the food is delicious
# 분류: Negative
# MAX_LEN:  13
# ========================= emphasize by attention result==========================
# it ' s price ##y , but the food is delicious
# highest attention: but delicious price ##y
#
#
#
# 입력 문장: It's expensive compared to the waffle menu, but the taste seems to be luxurious because it seems to use inexpensive ingredients.  The taste of chocolate is not cheap, it's like a proper chocolate.
# 분류: Negative
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# it ' s expensive compared to the wa ##ffle menu , but the taste seems to be luxurious because it seems to use inexpensive ingredients . the taste of chocolate is not cheap , it ' s like a proper chocolate .
# highest attention: not expensive luxurious because
#
#
#
# 입력 문장: The price is going up Too much
# 분류: Negative
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# the price is going up too much
# highest attention: too is the going
#
#
#
# 입력 문장: The cafe atmosphere is good and the price is cheap, so the food is clean and delicious I want to come again next time
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# the cafe atmosphere is good and the price is cheap , so the food is clean and delicious i want to come again next time
# highest attention: price clean cheap delicious

# %%
#NAVER final test data 세팅

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/naver_fin_price_trans.csv'
df = pd.read_csv(test_url,sep=',', header=0)
df.head(5)
# Out:
#    Unnamed: 0   id category  \
# 0           0  184    price
# 1           1  185    price
# 2           2  186    price
# 3           3  187    price
# 4           4  188    price
#
#                                                 text  polarity  \
# 0               가격은 좀 나가지만 식당 내부 깔끔하고 친절하고 무엇보다 맛있어요         0
# 1                            가격이 많이 올랐네요~\n냉면은 그냥그래요         0
# 2  확실히 평양냉면치고는 간이 세다\n이집에서 최애메뉴는 만두다\n좋아하는 만두집중 하...         0
# 3  술 이빠이 먹고 다음날 에어콘바람에 평냉조지다가 나이좀들어서 뜨뜻한국물로 속 가라앉...         0
# 4  어른들이 좋아해요~ 어복쟁반 국물이 살짝 매콤하지만 담백하니 건강한 느낌 ㅎㅎ 옛날...         0
#
#                                           trans_text
# 0  It's a little expensive, but the inside of the...
# 1  The price went up a lot. Naengmyeon is just wh...
# 2  It's definitely salty for Pyongyang naengmyeon...
# 3  If you want to cool down in the air conditione...
# 4  Adults like it Eobok Tray soup is a little spi...

# %%
df_new=df
df_new['length'] = df['trans_text'].apply(len)
df_new.length.describe()
# Out:
# count     21.000000
# mean     234.285714
# std      212.077378
# min       14.000000
# 25%       70.000000
# 50%      155.000000
# 75%      363.000000
# max      784.000000
# Name: length, dtype: float64

# %%
# naver data에 대한 분류 및 accuracy 측정
count=0

negNum=0
posNum=0

test_text = df.trans_text.values
test_labels = df.polarity.values

NaverWrongResult=[]
NaverRightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].trans_text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
        negNum+=1
    else:
        result=1
        posNum+=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        NaverRightResult.append(t)
    else:
        NaverWrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
print("Positive ratio: {:.4f}".format(posNum/len(test_labels)))
print("Negative ratio: {:.4f}".format(negNum/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# It's a little expensive, but the inside of the restaurant is clean and friendly, and above all, it's delicious
# model result: Negative
# answer: 0
#
# =============================== Input 2 ===============================
# The price went up a lot. Naengmyeon is just whatever
# model result: Negative
# answer: 0
#
# =============================== Input 3 ===============================
# It's definitely salty for Pyongyang naengmyeon. My favorite menu in this restaurant is dumplings. One of my favorite dumpling places. Pyeongyang naengmyeon is famous for its low falsetto, but dumplings and fish cakes are also expensive. If it doesn't taste good, it's ruined. It tastes good Parking is inconvenient. Today, a bug came out of a water cup, and another foreign substance came out of the cup that I asked to change. I've never done this before.
# model result: Negative
# answer: 0
#
# =============================== Input 4 ===============================
# If you want to cool down in the air conditioner the next day after drinking alcohol and want to calm down with warm soup as you get older, eat warm rice. I think it would be nice if the price was a little higher..Picture Pyeongnaengmyeon is double serving
# model result: Negative
# answer: 0
#
# =============================== Input 5 ===============================
# Adults like it Eobok Tray soup is a little spicy, but it feels healthy because it's light. The price has risen a lot compared to the past But it's delicious if you eat it sometimes
# model result: Negative
# answer: 0
#
# =============================== Input 6 ===============================
# It's been a long time since I visited with my mom, but I don't like it.. First of all, the price is too high. Prices have risen, but there seems to be no reason for it to be so expensive... The taste is not completely Pyongyang naengmyeon, but the soup is salty, so my mom and I poured water and drank it. The mung bean pancake was too small, so I ordered one more...  There is no kind service.. I don't think I'll revisit.
# model result: Negative
# answer: 0
#
# =============================== Input 7 ===============================
# The unkindness remains, the taste goes away and the price goes up.
# model result: Negative
# answer: 0
#
# =============================== Input 8 ===============================
# I like Pyeongyang naengmyeon and go around looking for good restaurants. Unkind first impression! As soon as I was about to understand, I thought restaurants must be unfriendly, but I ordered mulnaengmyeon + Pyeonyuk. A twist here! If it was unkind but not tasty!! It's not to the point where it's not bad, but below the level!! The broth is very seasoned! There's no deep taste!  Until the fishy smell! Every bowl has traces of a lady's thumb slipping into the broth! The price is more expensive than thunderbolt or Pildongmyeonok!! I'm seriously going to lose my hands!!! The fact that there are so many customers is so strange that I analyzed it and found that there are many places to park on the surrounding streets. The worst restaurant by the first half of 22 is very likely!!!
# model result: Negative
# answer: 0
#
# =============================== Input 9 ===============================
# I went there for Parents' Day, and the kindness and hygiene were not good for the price. They don't keep the waiting order, so they wait for more than 40 minutes and the food is busy, so they tell me to cook it on my own, and the naengmyeon is tasteless.. Dumplings are not that..Bulgogi was delicious. But the employee's unkindness...I don't think I'll go twice.
# model result: Negative
# answer: 0
#
# =============================== Input 10 ===============================
# Parking is so inconvenient and the staff is unfriendly.. I stopped eating because the tableware smelled fishy. It's a waste of money to buy it
# model result: Negative
# answer: 0
#
# =============================== Input 11 ===============================
# Onban is delicious.. Dumplings and fish-shaped trays are also delicious as a popular menu. Evaluation jade is too expensive... and, depending on the branch, manager or employee is unfriendly. I'm sometimes very upset because there are people around me.
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# So so for the price
# model result: Negative
# answer: 1
#
# =============================== Input 13 ===============================
# I ate boiled pork and spicy cold noodles.. The thin boiled pork was soaked in the broth, and it was different and delicious.. . I don't think I'll ever eat mulnaengmyeon again. It's fishy. Beef noodles are edible.. . It was amazing that it was popular because the service was not good and the price was expensive.
# model result: Negative
# answer: 0
#
# =============================== Input 14 ===============================
# It's delicious but expensive
# model result: Negative
# answer: 0
#
# =============================== Input 15 ===============================
# I packed the fish cake tray and ate it, and it was good. My parents enjoyed the meal! It's a bit expensive, but it's taken out. Very nice to eat at home :)
# model result: Negative
# answer: 0
#
# =============================== Input 16 ===============================
# It's expensive
# model result: Negative
# answer: 0
#
# =============================== Input 17 ===============================
# The two of us paid 60,000 won and came out. How could you treat us like this. It's my first time getting an order over a partition. How in the world can a house like this still be in business.. It's really absurd. I asked for more side dishes, but they gave me all the hints, and if I asked for one more time, I would get hit in the back. But when I handed out my disaster support card, they said they couldn't boast about 3 billion won in sales. I need to wake up to the fact that this store is doing well and has 3 billion sales. Eating at a restaurant like this... is such a waste of money. I feel like I'm taking money out of my pocket.
# model result: Negative
# answer: 0
#
# =============================== Input 18 ===============================
# The food is good for the price, but the staff service is the worst. I ordered it, but it went without a reply, and I asked another person for side dishes, but he left before I finished talking. He brought the side dishes without saying anything. I've never felt so embarrassed and dirty while eating with my own money.  Staff service is poor except for those who watch Bundang Evaluation House parking.
# model result: Negative
# answer: 1
#
# =============================== Input 19 ===============================
# Thank you for the delicious meal! It's a bit expensive, so I don't think I can come often Haha
# model result: Negative
# answer: 0
#
# =============================== Input 20 ===============================
# #Green onion pancake. #Beefyukgaejang. It's so good. #It's cheap, too.
# model result: Positive
# answer: 1
#
# =============================== Input 21 ===============================
# The taste of North Korea. It's a little expensive, but it's a lot. Dumplings are full and full enough.
# model result: Negative
# answer: 0
#
# test accuracy: 0.9048
# Positive ratio: 0.0476
# Negative ratio: 0.9524

# %%
#naver3 data 테스트

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/mongryen_price.csv'
df = pd.read_csv(test_url,sep=',', header=0)
df.head(5)
# Out:
#      id category                                               text  \
# 0  1010    price  알바 하시는분 저에게 다가와 웃으면서 2틀밖에 안되었으니 잘모르겠다고 하셨고 마치 ...
# 1  1011    price  룸에서 먹었구 도끼살, 육회, 오겹살, 청어알 볶음밥, 물냉면 벌집꿀 막걸리랑 맥주...
# 2  1012    price                               가격이 오른다신 찬이 추가 됐어요 맛
# 3  1013    price  항상 맛있는 돼지고기. 돈마호크랑 뒷덜미살 강추입니다. 다만 일하는 분들의 서비스가...
# 4  1014    price  가격은 착하지 않습니다.\n다만 고기질이 우수 합니다.\n여기 시그니처 메뉴들은 특...
#
#                                           trans_text
# 0  The part-timer came up to me and smiled and sa...
# 1  I ate it in the room, and the axe meat, beef t...
# 2    Shin Chan added that the price will go up Taste
# 3  Always delicious pork. I strongly recommend Do...
# 4  The price is not good.. However, the meat qual...

# %%
df_new=df
df_new['length'] = df['trans_text'].apply(len)
df_new.length.describe()
# Out:
# count     37.000000
# mean     186.864865
# std      139.514070
# min       21.000000
# 25%      100.000000
# 50%      150.000000
# 75%      211.000000
# max      654.000000
# Name: length, dtype: float64

# %%
# naver data에 대한 분류
count=0

negNum=0
posNum=0

test_text = df.trans_text.values

for i in range(len(test_text)):
    t = df.iloc[i].trans_text
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        negNum+=1
    else:
        posNum+=1

    print("=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction)
    print("")


print("Positive ratio: {:.4f}".format(posNum/len(test_text)))
print("Negative ratio: {:.4f}".format(negNum/len(test_text)))
# Out:
# =============================== Input 1 ===============================
# The part-timer came up to me and smiled and said, "I don't know because it's only been two days, so I don't know, so I felt like you should do it on your own." I could understand that Restaurants, especially meat restaurants, were very disappointing compared to the price of meat. Beef tartare costs 35,000 won. I don't think you should sell it to consumers But I still enjoyed the cold noodles with water and spicy noodles
# model result: Negative
#
# =============================== Input 2 ===============================
# I ate it in the room, and the axe meat, beef tartare, pork belly, herring roe fried rice, mul naengmyeon honey makgeolli, and beer were delicious. On the other hand, bibim naengmyeon is too sweet... The sirloin was just for the price... ★ Corkage 20,000 won & If you don't get a certain amount, you can charge a room!
# model result: Negative
#
# =============================== Input 3 ===============================
# Shin Chan added that the price will go up Taste
# model result: Negative
#
# =============================== Input 4 ===============================
# Always delicious pork. I strongly recommend Don Mahawk and backside. But the service of the workers is so curt and annoying
# model result: Positive
#
# =============================== Input 5 ===============================
# The price is not good.. However, the meat quality is excellent.. The signature menus here are special and delicious. I recommend it.
# model result: Positive
#
# =============================== Input 6 ===============================
# It's a bit pricey, but it's delicious and kind
# model result: Negative
#
# =============================== Input 7 ===============================
# It tastes good, but the amount of meat is too small for the price and the menu is coated with oilㅜ
# model result: Negative
#
# =============================== Input 8 ===============================
# The food is delicious I don't think he's kind because he doesn't grill it even though it's expensive..
# model result: Positive
#
# =============================== Input 9 ===============================
# I was looking forward to it because of the waiting and Naver reviews, but the meat quality was really bad.. It's too tough. It was a waste of money.
# model result: Negative
#
# =============================== Input 10 ===============================
# The ax meat is good!  I think it'll be better if you grill it.. Not everyone is good at grilling meat, but it's hard to grill it well when talking to people, so it's a waste lol
# model result: Negative
#
# =============================== Input 11 ===============================
# a cost-effective restaurant. There are many kinds of side dishes, but I don't want to eat any side dishes...
# model result: Positive
#
# =============================== Input 12 ===============================
# It's expensive, and the meat isn't that... I don't like the cost-effectiveness... Keep that in mind.
# model result: Negative
#
# =============================== Input 13 ===============================
# Only female employees are kind, but the taste is okay, but it's not good for the price. There are many meat restaurants that grill everything for this amount
# model result: Negative
#
# =============================== Input 14 ===============================
# Lunch special cost-effectiveness and delicious! I tried beef brisket soybean paste stew and cold noodles. Both were delicious and side dishes came out neatly, so I was satisfied
# model result: Positive
#
# =============================== Input 15 ===============================
# It's good to have a quick meal with acquaintances. The meat isn't that good, but it's not bad for the price.
# model result: Positive
#
# =============================== Input 16 ===============================
# It's good, but the portion is a bit small for the price
# model result: Negative
#
# =============================== Input 17 ===============================
# I've been here since the opening of Mongryeon The taste is always great and the price is reasonable. It's an impeccable restaurant, but.. The only drawback is.. It's the floor of the restaurant. I don't know how you did your initial interior design.. When a person walks around, the floor vibrates. I'm nervous because the floor is shaking all the time.. Every time I visit, we tell the interior designer if Mongryeon should claim damages..
# model result: Positive
#
# =============================== Input 18 ===============================
# It's delicious~ I can eat various parts and the disappointing thing is that the table was closer than I thought. ????? It was a bit expensive, so I thought they would grill it.
# model result: Negative
#
# =============================== Input 19 ===============================
# The price of meat is not that special The rating is because of the taste... In addition, they gave me a reservation seat by the window at 5 o'clock, but I arrived 15 minutes early (correctly because I called), so I asked the staff to take a break, so I was wondering if the reservation for 5 o'clock should be 2 or 3 minutes late... The part where I told him to come 2 or 3 minutes late was weird I know the break time and it's so cold. I'm asking you to come late next time.. Seongsu is not famous for meat... If you are looking for a good meat restaurant, I think it would be better to go near Wangsimni.. It's my first time giving such a low rating...
# model result: Negative
#
# =============================== Input 20 ===============================
# It's a bit expensive, but I enjoyed the food
# model result: Negative
#
# =============================== Input 21 ===============================
# The price goes up as much as 25 percent. I'm going to lose weight. Vegetables are not fresh. It's really great. I don't think I'll go again. 150g of American ribs is 25,000 won. It's better to go to famous restaurants
# model result: Negative
#
# =============================== Input 22 ===============================
# The lunch sets are so good for the price and the axe meat is so good!! If you order axe meat, it comes out like beef brisket doenjang jjigae. The doenjang jjigae is really good too. Everything I ate was good. There were reviews that the staff were unfriendly, but they weren't as unfriendly as I thought. I think it's an employee's case by case. The man was a bit brusque, but the experienced woman was very kind! It's the best restaurant for the price!!!
# model result: Positive
#
# =============================== Input 23 ===============================
# Meat and side dishes. Cold noodles..The food of soybean paste stew was delicious, but the service was not very..I'm paying a lot of money to eat it... The service was the most disappointing. And since it's break time from 3 to 5, I think I should go a little early for lunch
# model result: Negative
#
# =============================== Input 24 ===============================
# For the price, it's just so-so.. It's not like I'm cooking it for you... I ordered a pig set because the amount of axe set was too small. I was just like that. Fried rice is delicious
# model result: Negative
#
# =============================== Input 25 ===============================
# My friends were very satisfied with Mongryeon's signature menu, Axal.. Good luck with your luxurious and cost-effective Mongryeon BBQ restaurant. I took out half a star because the taste of cold noodles changed!
# model result: Positive
#
# =============================== Input 26 ===============================
# I'm always satisfied, as always. From a cost-effective meat restaurant to delicious and high-quality meat!! It's a meat restaurant, but it's a really good advantage that it doesn't smell!!
# model result: Positive
#
# =============================== Input 27 ===============================
# It was delicious! I had a good time with my friend and wine with the color and a bottle of coke-free!!! The price is also cheap ??????.. I'm touched..
# model result: Positive
#
# =============================== Input 28 ===============================
# There is a bit of a price range, but the service and taste are full of willingness to revisit
# model result: Negative
#
# =============================== Input 29 ===============================
# Unlike other meat restaurants, I was surprised because the interior was so pretty I got drunk on the atmosphere of meat and wine and enjoyed it elegantly ^^
# model result: Positive
#
# =============================== Input 30 ===============================
# The price is not cheap.. It's a good thing I didn't bring a car with a small parking lot.
# model result: Negative
#
# =============================== Input 31 ===============================
# Friendly staff, delicious meat, and smoke-absorbing anger made me enjoy it· A bit expensive for pork, but it's not a waste
# model result: Negative
#
# =============================== Input 32 ===============================
# Garbage for the price
# model result: Negative
#
# =============================== Input 33 ===============================
# It's delicious! It's clean and has a nice atmosphere. The price is good, too!
# model result: Positive
#
# =============================== Input 34 ===============================
# The service and cleanliness for the price is just so-so. The meat tastes good, but it's hard to control the heat because you have to grill it yourself and you're busy grilling it. I need to cut onions or side dishes with green onion pickles to eat, but it's a shame that there's no such serve.
# model result: Negative
#
# =============================== Input 35 ===============================
# The meat itself was delicious, but considering the price, it is better to use another house around Seoul Forest. (EX. Ilmirak, etc.). Most of all, if you order meat or anything, the delay is too long. I'm sure the meat I ordered for the first time won't come out even after I'm done grilling it. The meat that I ordered came out first. I think you need to improve the food. It's good to have separate rooms and good facilities such as vents.
# model result: Negative
#
# =============================== Input 36 ===============================
# The room on the second floor was spacious and nice. It's a bit pricey, but the meat tastes good. It's a clean place to eat on Ttukseom Island.
# model result: Negative
#
# =============================== Input 37 ===============================
# The food came out well for the price and the taste was really good. The atmosphere of the restaurant is so good. I was totally satisfied!! I'm going to go again next time
# model result: Positive
#
# Positive ratio: 0.3784
# Negative ratio: 0.6216
