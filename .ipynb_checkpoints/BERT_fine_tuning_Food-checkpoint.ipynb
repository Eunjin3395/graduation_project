# %%
#tensorflow 버전 확인
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# device list에 GPU있나 확인
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5099371268234668984
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3076812800
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15005895206477730617
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
#라이브러리 설치
# !pip install transformers
# !pip install keras==2.6

# !pip install scikit-learn

#필요한 모듈 불러오기
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification

from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd

from tabulate import tabulate
from tqdm import trange
import random
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')


print("GPU available:",torch.cuda.is_available())
# Out:
# Requirement already satisfied: transformers in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (4.27.3)
# Requirement already satisfied: filelock in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (3.10.7)
# Requirement already satisfied: requests in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (2023.3.23)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: keras==2.6 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.2.0)
# GPU available: True

# %%
# 내 깃허브 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
# Food 속성 리뷰
url='https://raw.githubusercontent.com/Eunjin3395/graduation_project/main/data/food_total.csv'
df = pd.read_csv(url,sep=',', header=0, encoding_errors='ignore')
df.head(5)
# Out:
#      id                                               text category  polarity
# 0  2777  To be completely fair, the only redeeming fact...     food         1
# 1  1634  The food is uniformly exceptional, with a very...     food         1
# 2  2846  Not only was the food outstanding, but the lit...     food         1
# 3  1571          It is very overpriced and not very tasty.     food         0
# 4  1458  Our agreed favorite is the orrechiete with sau...     food         1

# %%
df.dtypes
# Out:
# id          object
# text        object
# category    object
# polarity     int64
# dtype: object

# %%
# review data의 길이 분포 및 통계
df_new=df
df_new['length'] = df['text'].apply(len)

# Create a FacetGrid object with 'Liked' as the column to be used for separating the data
# FacetGrid is a grid of subplots that displays the same relationship between different subsets of your data.
g = sns.FacetGrid(df, col='polarity')

# Use the FacetGrid object to plot a histogram of the 'Length' column for each value of 'Liked'
g.map(plt.hist, 'length');

# %%
count_neg = len(df[df['polarity'] == 0])
count_pos=len(df[df['polarity'] == 1])
print("positive: {}, negative: {}".format(count_pos,count_neg))
# Out:
# positive: 1107, negative: 308

# %%
# review data의 label 분포
sns.set_style('darkgrid')

# Create a count plot of the "Liked" column
sns.countplot(x='polarity', data=df)

# Set the title of the plot
plt.title('Count of Reviews by Liked Status')

# Set the label for the x-axis
plt.xlabel('label')

# Set the label for the y-axis
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
df_new.length.describe()
# Out:
# count    1415.000000
# mean       79.168198
# std        46.640079
# min         6.000000
# 25%        47.500000
# 50%        70.000000
# 75%       102.000000
# max       370.000000
# Name: length, dtype: float64

# %%
text = df.text.values
labels = df.polarity.values

# %%
# 전처리
tokenizer = BertTokenizer.from_pretrained(
    'bert-base-uncased',
    do_lower_case = True
    )

# %%
MAX_LENGTH=150
token_id = []
attention_masks = []

def preprocessing(input_text, tokenizer,max_len_input=MAX_LENGTH):
  '''
  Returns <class transformers.tokenization_utils_base.BatchEncoding> with the following fields:
    - input_ids: list of token ids
    - token_type_ids: list of token type ids
    - attention_mask: list of indices (0,1) specifying which tokens should considered by the model (return_attention_mask = True).
  '''
  return tokenizer.encode_plus(
                        input_text,
                        add_special_tokens = True,
                        max_length = max_len_input,
                        pad_to_max_length = True,
                        return_attention_mask = True,
                        return_tensors = 'pt',
                        truncation=True
                   )


for sample in text:
  encoding_dict = preprocessing(sample, tokenizer)

  # token_id 리스트 추출
  token_id.append(encoding_dict['input_ids']) 
  # attention_mask 리스트 추출
  attention_masks.append(encoding_dict['attention_mask'])


# 리스트를 텐서로
token_id = torch.cat(token_id, dim = 0)
attention_masks = torch.cat(attention_masks, dim = 0)
labels = torch.tensor(labels)

# %%
VAL_RATIO= 0.2
batch_size = 8 # 16 or 32 추천이라고 한다

# Indices of the train and validation splits stratified by labels
train_idx, val_idx = train_test_split(
    np.arange(len(labels)),
    test_size = VAL_RATIO,
    shuffle = True,
    stratify = labels)

# Train and validation sets
train_set = TensorDataset(token_id[train_idx], 
                          attention_masks[train_idx], 
                          labels[train_idx])

val_set = TensorDataset(token_id[val_idx], 
                        attention_masks[val_idx], 
                        labels[val_idx])

# Prepare DataLoader
train_dataloader = DataLoader(
            train_set,
            sampler = RandomSampler(train_set),
            batch_size = batch_size
        )

validation_dataloader = DataLoader(
            val_set,
            sampler = SequentialSampler(val_set),
            batch_size = batch_size
        )


print("train: {}".format(len(train_idx)))
print("validation: {}".format(len(val_idx)))
# Out:
# train: 1132
# validation: 283

# %%
def b_tp(preds, labels):
  '''Returns True Positives (TP): count of correct predictions of actual class 1'''
  return sum([preds == labels and preds == 1 for preds, labels in zip(preds, labels)])

def b_fp(preds, labels):
  '''Returns False Positives (FP): count of wrong predictions of actual class 1'''
  return sum([preds != labels and preds == 1 for preds, labels in zip(preds, labels)])

def b_tn(preds, labels):
  '''Returns True Negatives (TN): count of correct predictions of actual class 0'''
  return sum([preds == labels and preds == 0 for preds, labels in zip(preds, labels)])

def b_fn(preds, labels):
  '''Returns False Negatives (FN): count of wrong predictions of actual class 0'''
  return sum([preds != labels and preds == 0 for preds, labels in zip(preds, labels)])

def b_metrics(preds, labels):
  '''
  Returns the following metrics:
    - accuracy    = (TP + TN) / N
    - precision   = TP / (TP + FP)
    - recall      = TP / (TP + FN)
    - specificity = TN / (TN + FP)
  '''
  preds = np.argmax(preds, axis = 1).flatten()
  labels = labels.flatten()
  tp = b_tp(preds, labels)
  tn = b_tn(preds, labels)
  fp = b_fp(preds, labels)
  fn = b_fn(preds, labels)
  b_accuracy = (tp + tn) / len(labels)
  b_precision = tp / (tp + fp) if (tp + fp) > 0 else 'nan'
  b_recall = tp / (tp + fn) if (tp + fn) > 0 else 'nan'
  b_specificity = tn / (tn + fp) if (tn + fp) > 0 else 'nan'
  return b_accuracy, b_precision, b_recall, b_specificity

# %%
# BERT 모델 불러오기
model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels = 2,
    output_attentions = True,
    output_hidden_states = False,
)


optimizer = torch.optim.AdamW(model.parameters(), 
                              lr = 5e-5, # learning rate 설정
                              eps = 1e-08
                              )

model.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# GPU로 학습하도록 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 학습 횟수 설정
epochs = 15

idx=0
epo_list=[]
train_loss_list=[]
val_accuracy_list=[]

for _ in trange(epochs, desc = 'Epoch'):
    idx+=1
    epo_list.append(idx)

    # ========== Training ==========
    model.train()
    
    # Tracking variables
    tr_loss = 0
    nb_tr_examples, nb_tr_steps = 0, 0

    for step, batch in enumerate(train_dataloader):
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch
        optimizer.zero_grad()
        # Forward pass
        train_output = model(b_input_ids, 
                             token_type_ids = None, 
                             attention_mask = b_input_mask, 
                             labels = b_labels)
        # Backward pass
        train_output.loss.backward()
        optimizer.step()
        # Update tracking variables
        tr_loss += train_output.loss.item()
        nb_tr_examples += b_input_ids.size(0)
        nb_tr_steps += 1

    # ========== Validation ==========
    model.eval()

    # Tracking variables 
    val_accuracy = []
    val_precision = []
    val_recall = []
    val_specificity = []

    for batch in validation_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
          # Forward pass
          eval_output = model(b_input_ids, 
                              token_type_ids = None, 
                              attention_mask = b_input_mask)
        logits = eval_output.logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        # Calculate validation metrics
        b_accuracy, b_precision, b_recall, b_specificity = b_metrics(logits, label_ids)
        val_accuracy.append(b_accuracy)
        # Update precision only when (tp + fp) !=0; ignore nan
        if b_precision != 'nan': val_precision.append(b_precision)
        # Update recall only when (tp + fn) !=0; ignore nan
        if b_recall != 'nan': val_recall.append(b_recall)
        # Update specificity only when (tn + fp) !=0; ignore nan
        if b_specificity != 'nan': val_specificity.append(b_specificity)

    print('\n\t - Train loss: {:.4f}'.format(tr_loss / nb_tr_steps))
    print('\t - Validation Accuracy: {:.4f}'.format(sum(val_accuracy)/len(val_accuracy)))
    val_accuracy_temp=sum(val_accuracy)/len(val_accuracy)
    train_loss_list.append(round(tr_loss / nb_tr_steps,4))
    val_accuracy_list.append(round(val_accuracy_temp,4))
    #print('\t - Validation Precision: {:.4f}'.format(sum(val_precision)/len(val_precision)) if len(val_precision)>0 else '\t - Validation Precision: NaN')
    #print('\t - Validation Recall: {:.4f}'.format(sum(val_recall)/len(val_recall)) if len(val_recall)>0 else '\t - Validation Recall: NaN')
    #print('\t - Validation Specificity: {:.4f}\n'.format(sum(val_specificity)/len(val_specificity)) if len(val_specificity)>0 else '\t - Validation Specificity: NaN')
# Out:
# Epoch:   7%|█████                                                                       | 1/15 [00:12<02:55, 12.55s/it]
# 	 - Train loss: 0.3524
# 	 - Validation Accuracy: 0.9132
# Epoch:  13%|██████████▏                                                                 | 2/15 [00:23<02:28, 11.44s/it]
# 	 - Train loss: 0.1820
# 	 - Validation Accuracy: 0.9062
# Epoch:  20%|███████████████▏                                                            | 3/15 [00:33<02:12, 11.06s/it]
# 	 - Train loss: 0.1157
# 	 - Validation Accuracy: 0.8993
# Epoch:  27%|████████████████████▎                                                       | 4/15 [00:44<01:59, 10.84s/it]
# 	 - Train loss: 0.0817
# 	 - Validation Accuracy: 0.8819
# Epoch:  33%|█████████████████████████▎                                                  | 5/15 [00:54<01:47, 10.72s/it]
# 	 - Train loss: 0.0410
# 	 - Validation Accuracy: 0.9132
# Epoch:  40%|██████████████████████████████▍                                             | 6/15 [01:05<01:35, 10.66s/it]
# 	 - Train loss: 0.0140
# 	 - Validation Accuracy: 0.9062
# Epoch:  47%|███████████████████████████████████▍                                        | 7/15 [01:15<01:24, 10.61s/it]
# 	 - Train loss: 0.0205
# 	 - Validation Accuracy: 0.9132
# Epoch:  53%|████████████████████████████████████████▌                                   | 8/15 [01:26<01:14, 10.58s/it]
# 	 - Train loss: 0.0174
# 	 - Validation Accuracy: 0.9028
# Epoch:  60%|█████████████████████████████████████████████▌                              | 9/15 [01:36<01:03, 10.57s/it]
# 	 - Train loss: 0.0807
# 	 - Validation Accuracy: 0.8924
# Epoch:  67%|██████████████████████████████████████████████████                         | 10/15 [01:47<00:52, 10.56s/it]
# 	 - Train loss: 0.0390
# 	 - Validation Accuracy: 0.9028
# Epoch:  73%|██████████████████████████████████████████████████████▉                    | 11/15 [01:58<00:42, 10.55s/it]
# 	 - Train loss: 0.0067
# 	 - Validation Accuracy: 0.8993
# Epoch:  80%|████████████████████████████████████████████████████████████               | 12/15 [02:08<00:31, 10.55s/it]
# 	 - Train loss: 0.0378
# 	 - Validation Accuracy: 0.8924
# Epoch:  87%|█████████████████████████████████████████████████████████████████          | 13/15 [02:19<00:21, 10.55s/it]
# 	 - Train loss: 0.0195
# 	 - Validation Accuracy: 0.9132
# Epoch:  93%|██████████████████████████████████████████████████████████████████████     | 14/15 [02:29<00:10, 10.55s/it]
# 	 - Train loss: 0.0058
# 	 - Validation Accuracy: 0.9097
# Epoch: 100%|███████████████████████████████████████████████████████████████████████████| 15/15 [02:40<00:00, 10.68s/it]
# 	 - Train loss: 0.0387
# 	 - Validation Accuracy: 0.9062

# %%
# train loss 그래프
plt.plot(epo_list, train_loss_list)
plt.xlabel('epoch')
plt.ylabel('train loss')
plt.show()

# %%
plt.plot(epo_list, val_accuracy_list)
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.axis([1,epochs , 0.75, 1])
plt.show()

# %%
#새로운 리뷰를 분류해보자

def test_sentence(sentence):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []

    # 전처리
    encoding = preprocessing(sentence, tokenizer)
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))

    prediction = 'Positive' if np.argmax(output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    return prediction
    

    
    
new_sentence ='The food was bad, but it was cheap'
# 'It''s good, but the owner is so unkind. Some of the plates didn''t clean properly because there was something on them. But it''s cost-effective.'





print('입력 문장:', new_sentence)
print('분류:', test_sentence(new_sentence))
# Out:
# 입력 문장: The food was bad, but it was cheap
# 분류: Negative

# %%
#test data 세팅

# 내 깃허브 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='https://raw.githubusercontent.com/Eunjin3395/graduation_project/main/data/food_test.csv'
df = pd.read_csv(test_url,sep=',', header=0, encoding_errors='ignore')
df.head(5)
# Out:
#                                        id  \
# 0                                    3440
# 1  en_CatalRestaurant__UvaBar_477861889:4
# 2                                    1242
# 3          en_BlueRibbonSushi_478218345:2
# 4                                     882
#
#                                                 text category  polarity
# 0  Even though its good seafood, the prices are t...       aa         1
# 1  My g/f and I both agreed the food was very med...     food         0
# 2                     But the coconut rice was good.     food         1
# 3        It has great sushi and even better service.     food         1
# 4  While the ambiance and atmosphere were great, ...     food         0

# %%
count_neg = len(df[df['polarity'] == 0])
count_pos=len(df[df['polarity'] == 1])
print("positive: {}, negative: {}".format(count_pos,count_neg))
# Out:
# positive: 46, negative: 34

# %%
count=0

test_text = df.text.values
test_labels = df.polarity.values

wrongResult=[]
rightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
    else:
        result=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        rightResult.append(t)
    else:
        wrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# Even though its good seafood, the prices are too high.
# model result: Positive
# answer: 1
#
# =============================== Input 2 ===============================
# My g/f and I both agreed the food was very mediocre especially considering the price.
# model result: Positive
# answer: 0
#
# =============================== Input 3 ===============================
# But the coconut rice was good.
# model result: Positive
# answer: 1
#
# =============================== Input 4 ===============================
# It has great sushi and even better service.
# model result: Positive
# answer: 1
#
# =============================== Input 5 ===============================
# While the ambiance and atmosphere were great, the food and service could have been a lot better.
# model result: Negative
# answer: 0
#
# =============================== Input 6 ===============================
# The food was lousy -too sweet or too salty and the portions tiny.
# model result: Negative
# answer: 0
#
# =============================== Input 7 ===============================
# On my meal I had to send back my eggs for a simple request of breaking the yokes before cooking, and would have had to send them back again if I hadn't rejected the meal all together.
# model result: Negative
# answer: 0
#
# =============================== Input 8 ===============================
# This is a great place to get a delicious meal.
# model result: Positive
# answer: 1
#
# =============================== Input 9 ===============================
# Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.
# model result: Positive
# answer: 1
#
# =============================== Input 10 ===============================
# And the Tom Kha soup was pathetic.
# model result: Negative
# answer: 0
#
# =============================== Input 11 ===============================
# I rejected it because in the process of attempting to fix the eggs they broke something else in the dish and I was too frustrated to continue.
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# And really large portions.
# model result: Positive
# answer: 1
#
# =============================== Input 13 ===============================
# The Caesar salad I ordered had so much lemon I couldn't eat it.
# model result: Negative
# answer: 0
#
# =============================== Input 14 ===============================
# I have been here, spent tons of money on a chef special dinner and it was a major dissappointment.
# model result: Positive
# answer: 0
#
# =============================== Input 15 ===============================
# The wine list is wonderful and the food reminds me of my recent trip to Italy.
# model result: Positive
# answer: 1
#
# =============================== Input 16 ===============================
# The spicy tuna and salmon are the best we've ever had.
# model result: Positive
# answer: 1
#
# =============================== Input 17 ===============================
# I liked the atmosphere very much but the food was not worth the price.
# model result: Positive
# answer: 0
#
# =============================== Input 18 ===============================
# Nothing really came across as outstanding.
# model result: Positive
# answer: 0
#
# =============================== Input 19 ===============================
# The food is usually good but it certainly isn't a relaxing place to go.
# model result: Positive
# answer: 1
#
# =============================== Input 20 ===============================
# The food options rule.
# model result: Positive
# answer: 1
#
# =============================== Input 21 ===============================
# To be honest, I've had better frozen pizza.
# model result: Negative
# answer: 0
#
# =============================== Input 22 ===============================
# The food is great and reasonably priced.
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# Even my Indian friend couldn't believe how good and tasty everything was.
# model result: Positive
# answer: 1
#
# =============================== Input 24 ===============================
# I know many people have their favorite types of pizza and pizza places, but Mioposto's pizza lacks quality and good taste.
# model result: Negative
# answer: 0
#
# =============================== Input 25 ===============================
# Unfortunately, the food was NOT something to get worked up about.
# model result: Negative
# answer: 0
#
# =============================== Input 26 ===============================
# In fact, this was not a Nicoise salad and was barely eatable.
# model result: Negative
# answer: 0
#
# =============================== Input 27 ===============================
# Poor customer service/poor pizza.
# model result: Negative
# answer: 0
#
# =============================== Input 28 ===============================
# A few tips: skip the turnip cake, roast pork buns and egg custards.
# model result: Negative
# answer: 0
#
# =============================== Input 29 ===============================
# Good spreads, great beverage selections and bagels really tasty.
# model result: Positive
# answer: 1
#
# =============================== Input 30 ===============================
# Serves really good sushi.
# model result: Positive
# answer: 1
#
# =============================== Input 31 ===============================
# Maybe it is good for that one night once in a blue moon when the chefs decide to use fish that's half-way decent.
# model result: Positive
# answer: 0
#
# =============================== Input 32 ===============================
# Green Tea creme brulee is a must!
# model result: Positive
# answer: 1
#
# =============================== Input 33 ===============================
# Fabulous Italian Food!
# model result: Positive
# answer: 1
#
# =============================== Input 34 ===============================
# In addition, the food is very good and the prices are reasonable.
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# – I was highly disappointed in the food at Pagoda.
# model result: Negative
# answer: 0
#
# =============================== Input 36 ===============================
# The food is fresh, delicious, and reasonably priced.
# model result: Positive
# answer: 1
#
# =============================== Input 37 ===============================
# Everything at Sala Thai is tasty and well-portioned.
# model result: Positive
# answer: 1
#
# =============================== Input 38 ===============================
# The food now is inconsistent.
# model result: Negative
# answer: 0
#
# =============================== Input 39 ===============================
# My mouth felt very dry afterwards and I had that signature ?MSG? taste lingering in my throat after I left the restaurant.
# model result: Negative
# answer: 0
#
# =============================== Input 40 ===============================
# – I will never forget the amazing meal, service, and ambiance I experience at this restaurant.
# model result: Positive
# answer: 1
#
# =============================== Input 41 ===============================
# – The food was not great & the waiters were rude.
# model result: Negative
# answer: 0
#
# =============================== Input 42 ===============================
# They are not greasy or anything.
# model result: Positive
# answer: 1
#
# =============================== Input 43 ===============================
# Though, one thing I realized later on was that the restaurant either used MSG or a meat tenderizer on the steak.
# model result: Negative
# answer: 0
#
# =============================== Input 44 ===============================
# the only problem is you really have to warm up the pizza before it's edible, even when you order ahead.
# model result: Negative
# answer: 0
#
# =============================== Input 45 ===============================
# Yum!
# model result: Positive
# answer: 1
#
# =============================== Input 46 ===============================
# The food was great!
# model result: Positive
# answer: 1
#
# =============================== Input 47 ===============================
# The lemon chicken tasted like sticky sweet donuts and the honey walnut prawns, the few they actually give you.....were not good.
# model result: Positive
# answer: 0
#
# =============================== Input 48 ===============================
# I recommend the garlic shrimp, okra (bindi), and anything with lamb.
# model result: Positive
# answer: 1
#
# =============================== Input 49 ===============================
# The food is prepared quickly and efficiently.
# model result: Positive
# answer: 1
#
# =============================== Input 50 ===============================
# The food is not what it once was (potions have seriously seen downsizing) prices have gone up, and the service is the worst I have experienced anywhere (including mainland Europe).
# model result: Negative
# answer: 0
#
# =============================== Input 51 ===============================
# Their calzones are horrific, bad, vomit-inducing, YUCK.
# model result: Positive
# answer: 0
#
# =============================== Input 52 ===============================
# Fancy pieces of exotic fish on a $100 dollar plate and NOT ONE was eatable.
# model result: Positive
# answer: 0
#
# =============================== Input 53 ===============================
# My goodness, everything from the fish to the rice to the seaweed was absolutely amazing.
# model result: Positive
# answer: 1
#
# =============================== Input 54 ===============================
# Consistently good Japanese Tapas.
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# Anyway, the food is good, the price is right and they have a decent wine list.
# model result: Positive
# answer: 1
#
# =============================== Input 56 ===============================
# The bagels are fabulous.
# model result: Positive
# answer: 1
#
# =============================== Input 57 ===============================
# All the appetizers and salads were fabulous, the steak was mouth watering and the pasta was delicious!!!
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# I love the fact that the pizza tastes so good and is so cheap.
# model result: Positive
# answer: 1
#
# =============================== Input 59 ===============================
# The sushi was awful!
# model result: Negative
# answer: 0
#
# =============================== Input 60 ===============================
# I may not be a sushi guru but I can tell you that the food here is just okay and that there is not much else to it.
# model result: Negative
# answer: 0
#
# =============================== Input 61 ===============================
# The food is great and authentic.
# model result: Positive
# answer: 1
#
# =============================== Input 62 ===============================
# The dishes offered were unique, very tasty and fresh from the lamb sausages, sardines with biscuits, large whole shrimp to the amazing pistachio ice cream (the best and freshest I've ever had).
# model result: Positive
# answer: 1
#
# =============================== Input 63 ===============================
# It's *very* reasonably priced, esp for the quality of the food.
# model result: Positive
# answer: 1
#
# =============================== Input 64 ===============================
# We are locals, and get the feeling the only way this place survives with such average food is because most customers are probably one-time customer tourists.
# model result: Positive
# answer: 0
#
# =============================== Input 65 ===============================
# I haven't eat a lamb chop as delicious as that, the salads are really nice dressed with lemon and extra virgnin olive oil.
# model result: Positive
# answer: 1
#
# =============================== Input 66 ===============================
# The food was very good, a great deal, and the place its self was great.
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# I should have thought to bring it up but never expected the food to be that mild.
# model result: Positive
# answer: 0
#
# =============================== Input 68 ===============================
# The wine list is incredible and extensive and diverse, the food is all incredible and the staff was all very nice, good at their jobs and cultured.
# model result: Positive
# answer: 1
#
# =============================== Input 69 ===============================
# The menu was impressive with selections ranging from a burger, to steak, to escargot.
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# The food is terrible and overall, I would have to say avoid at all costs.
# model result: Negative
# answer: 0
#
# =============================== Input 71 ===============================
# Rice is too dry, tuna wasn't so fresh either.
# model result: Negative
# answer: 0
#
# =============================== Input 72 ===============================
# The best thing I tasted were the lambc hops.
# model result: Positive
# answer: 1
#
# =============================== Input 73 ===============================
# Try the crunchy tuna, it is to die for.
# model result: Positive
# answer: 1
# =============================== Input 74 ===============================
# The food was great.
# model result: Positive
# answer: 1
#
# =============================== Input 75 ===============================
# I swore never to return for a warm beer and mediocre meal.
# model result: Negative
# answer: 0
#
# =============================== Input 76 ===============================
# Don't leave the restaurant without it.
# model result: Negative
# answer: 1
#
# =============================== Input 77 ===============================
# The onion rings are great!
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# Good food!
# model result: Positive
# answer: 1
#
# =============================== Input 79 ===============================
# With the theater 2 blocks away we had a delicious meal in a beautiful room.
# model result: Positive
# answer: 1
#
# =============================== Input 80 ===============================
# very good breads as well.
# model result: Positive
# answer: 1
#
# test accuracy: 0.8625

# %%
# 개별 문장의 attention 추출하는 함수
def get_attention(encoding):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        model_output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))
        
    prediction = 'Positive' if np.argmax(model_output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    attention=model_output[-1]
    last_attention=attention[-1]
    tokens=tokenizer.convert_ids_to_tokens(encoding['input_ids'][0])
    
    return attention,last_attention,tokens,prediction

# %%
def get_val_len(ids):
    count=0
    for elem in ids:
        if(elem!=0):
            count+=1
    return count

# %%
# 개별 문장의 attention 추출
from bertviz import head_view

sent="Terrible service, but food was delicious, and cost-effective."

# 전처리
encoding = preprocessing(sent, tokenizer,20)


retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

print('입력 문장:', sent)
print('분류:', prediction)
print()

#head_view(retAtt,retTok)
# Out:
# 입력 문장: Terrible service, but food was delicious, and cost-effective.
# 분류: Positive

# %%
def sort_by_att(attention,tokens):
    '''
        last layer의 attention tensor를 입력 받아 각 token의 attention 값을 head에 대한 평균을 낸 뒤, attention이 높은 token 순으로 idx를 반환하는 함수
    '''
    
    attention=attention[0] # shape: 12,len,len
    
    size=len(tokens)
    
    total_atts_sum=[] # 각 head에 대한 각 토큰의 attention값의 합
    for head in range(0,12):
        att_of_head=attention[head] # 한 head의 attention
        atts_sum_of_head=[0.0]*size # 해당 head 하나의 attention의 합
        for row in att_of_head:
            col=0
            for elem in row:
                value=elem.item()
                atts_sum_of_head[col]+=value # head 하나에 대한 토큰이 가지는 attention 값
                col+=1
        total_atts_sum.append(atts_sum_of_head)
    
    total_sum_value=[0.0]*size
    for elem in total_atts_sum:
        for i in range(0,size):
            total_sum_value[i]+=elem[i]
            

    total_mean=[]
    for elem in total_sum_value:
        total_mean.append(elem/12)
    
    


    idxs=sorted(range(len(total_mean)), key=lambda k: total_mean[k], reverse=True)
    return(idxs)

# %%
# attention 순서대로 텍스트 배경색 주기
color_code=[
    "\033[48;5;243m",
    "\033[48;5;245m",
    "\033[48;5;247m",
    "\033[48;5;249m",
    "\033[48;5;251m",
    "\033[48;5;253m",
    "\033[48;5;255m"
]
def emp_by_att(attIdxs,tokens):   
    valTokens=[]
    for tok in tokens:
        if(tok!='[CLS]' and tok!='[PAD]' and tok!='[SEP]'):
            valTokens.append(tok)
        
    valIdxs=[]
    for idx in attIdxs:
        if len(valIdxs)==7:
            break;
        
        if(idx>0 and idx<=len(valTokens)):
            if(valTokens[idx-1]!=',' and valTokens[idx-1]!='.'):
                valIdxs.append(idx-1)
    
    resultSent=""
    for i in range(len(valTokens)):
        if(i in valIdxs):
            outTok=color_code[valIdxs.index(i)]+valTokens[i]+"\033[0m"
        else:
            outTok=valTokens[i]
        resultSent+=outTok
        resultSent+=' '
    
    print("========================= emphasize by attention result==========================")
    print(resultSent)

# %%
def get_highest_att_tok(idxs,retTok,num):
    count=0
    print("highest attention: ",end="")
    for i in idxs:
        if(i<len(retTok)):
            if(retTok[i]!='[CLS]' and retTok[i]!='[SEP]' and retTok[i]!='.' and retTok[i]!=','):
                if(count<num):
                    print(retTok[i],end=" ")
                    count+=1

# %%
# 개별 문장을 attention이 높은 token 순으로 보여주기
idxs=sort_by_att(retLastAtt,retTok)

emp_by_att(idxs,retTok)

get_highest_att_tok(idxs,retTok,3)
# Out:
# ========================= emphasize by attention result==========================
# terrible service , but food was delicious , and cost - effective .
# highest attention: terrible delicious effective

# %%
#잘못 분류된 문장의 attention
for sent in wrongResult:
    encoding = preprocessing(sent, tokenizer,50)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: While the ambiance and atmosphere were great, the food and service could have been a lot better.
# 분류: Positive
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# while the am ##bian ##ce and atmosphere were great , the food and service could have been a lot better .
# highest attention: food atmosphere service great
#
#
#
# 입력 문장: I have been here, spent tons of money on a chef special dinner and it was a major dissappointment.
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# i have been here , spent tons of money on a chef special dinner and it was a major di ##ssa ##pp ##oint ##ment .
# highest attention: ##pp tons di major
#
#
#
# 입력 문장: I liked the atmosphere very much but the food was not worth the price.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# i liked the atmosphere very much but the food was not worth the price .
# highest attention: atmosphere the liked very
#
#
#
# 입력 문장: Nothing really came across as outstanding.
# 분류: Positive
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# nothing really came across as outstanding .
# highest attention: outstanding as nothing across
#
#
#
# 입력 문장: To be honest, I've had better frozen pizza.
# 분류: Positive
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# to be honest , i ' ve had better frozen pizza .
# highest attention: better pizza frozen ve
#
#
#
# 입력 문장: I know many people have their favorite types of pizza and pizza places, but Mioposto's pizza lacks quality and good taste.
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# i know many people have their favorite types of pizza and pizza places , but mi ##op ##ost ##o ' s pizza lacks quality and good taste .
# highest attention: people many pizza their
#
#
#
# 입력 문장: Maybe it is good for that one night once in a blue moon when the chefs decide to use fish that's half-way decent.
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# maybe it is good for that one night once in a blue moon when the chefs decide to use fish that ' s half - way decent .
# highest attention: decent fish s use
#
#
#
# 입력 문장: They are not greasy or anything.
# 분류: Negative
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# they are not greasy or anything .
# highest attention: not are they anything
#
#
#
# 입력 문장: Fancy pieces of exotic fish on a $100 dollar plate and NOT ONE was eatable.
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# fancy pieces of exotic fish on a $ 100 dollar plate and not one was eat ##able .
# highest attention: exotic fancy fish pieces
#
#
#
# 입력 문장: I may not be a sushi guru but I can tell you that the food here is just okay and that there is not much else to it.
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# i may not be a su ##shi guru but i can tell you that the food here is just okay and that there is not much else to it .
# highest attention: food is and just

# %%
#NAVER test data 세팅

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/naver_food_test.csv'
df = pd.read_csv(test_url,sep=',', header=0,encoding="CP949")
df.head(5)
# Out:
#    Unnamed: 0    id category  \
# 0           0   180     food
# 1           1   580     food
# 2           2   605     food
# 3           3  1696     food
# 4           4  2550     food
#
#                                                 text  polarity  \
# 0  쟁반짜장은 너무 짜고, 면이 불어 있었어요\n탕수육은 비린내가 심하고, 짬뽕은 양파...         0
# 1  매장이 엄청 지저분합니다.\n사이다는 단맛이 하나도 없는 탄산수였습니다.\n직원이 ...         0
# 2                고기 기름이 넘 많네요\n서비스도 조금 부족한듯\n다소 아쉽네요         0
# 3                                  토마호크 비추천.\n고기가 질김         0
# 4  스테이크덮밥이랑 큐브스테이크덮밥을 먹엇는데 개인적으로 다음식 안좋아하는 분은 큐브스...         0
#
#                                           trans_text
# 0  The jajangmyeon on the tray was too salty and ...
# 1  The store is really messy.. Sprite was carbona...
# 2  There's too much meat oil. The service seems t...
# 3  I don't recommend Tomahawk.. the toughness of ...
# 4  I ate rice with steak and rice with cube steak...

# %%
df_new=df
df_new['length'] = df['trans_text'].apply(len)
df_new.length.describe()
# Out:
# count     80.000000
# mean     120.200000
# std       51.804745
# min       30.000000
# 25%       69.750000
# 50%      119.500000
# 75%      163.250000
# max      226.000000
# Name: length, dtype: float64

# %%
# naver data에 대한 분류 및 accuracy 측정
count=0

test_text = df.trans_text.values
test_labels = df.polarity.values

NaverWrongResult=[]
NaverRightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].trans_text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
    else:
        result=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        NaverRightResult.append(t)
    else:
        NaverWrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# model result: Negative
# answer: 0
#
# =============================== Input 2 ===============================
# The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# model result: Negative
# answer: 0
#
# =============================== Input 3 ===============================
# There's too much meat oil. The service seems to be a little lacking. It's a bit disappointing
# model result: Negative
# answer: 0
#
# =============================== Input 4 ===============================
# I don't recommend Tomahawk.. the toughness of the meat
# model result: Negative
# answer: 0
#
# =============================== Input 5 ===============================
# I ate rice with steak and rice with cube steak, but personally, I don't want to recommend cube steak if you don't like all foods. It's too sweet
# model result: Negative
# answer: 0
#
# =============================== Input 6 ===============================
# Braised hairtail is too salty. I can't eat a hairtail because it's too hard and small. Steamed eggs are too bitter. Dozer's throat is sore  I don't think I'll ever go again
# model result: Negative
# answer: 0
#
# =============================== Input 7 ===============================
# The fried chicken was so greasy that it didn't taste good.
# model result: Negative
# answer: 0
#
# =============================== Input 8 ===============================
# I only ate BBQ chicken, but this time it was too saltyPlease reduce the amount of salt~~
# model result: Negative
# answer: 0
#
# =============================== Input 9 ===============================
# I ordered Cheekki at a reasonable price, so it's a bit tough and hard... Let's just order chicken with BBQ
# model result: Negative
# answer: 0
#
# =============================== Input 10 ===============================
# I've never been to such an insincere and unfriendly restaurant. I read the review and came here saying that it's delicious even if it's unfriendly, but it's not delicious;;
# model result: Negative
# answer: 0
#
# =============================== Input 11 ===============================
# It was just so-so. The seasoning was bland, and I was waiting to pay for the package.. Personally, I don't like it
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# model result: Negative
# answer: 0
#
# =============================== Input 13 ===============================
# The noodles are broken and have no elasticity at all because they are weak. The delivery came ahead of schedule.
# model result: Negative
# answer: 0
#
# =============================== Input 14 ===============================
# The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# model result: Negative
# answer: 0
#
# =============================== Input 15 ===============================
# Maybe it's just meat. But I can't eat soybean paste with crab. It's too fishy The bibim sauce for naengmyeon is not that bad, but the broth is... Wow..It's a taste I don't want to eat again
# model result: Positive
# answer: 0
#
# =============================== Input 16 ===============================
# I've tried seasoned raw octopus vinegar and octopus garlic raw fish, but the taste...Actually, I don't know. It's not cheap either
# model result: Negative
# answer: 0
#
# =============================== Input 17 ===============================
# It's not the taste of the past. The meat is almost fat
# model result: Negative
# answer: 0
#
# =============================== Input 18 ===============================
# Far from green onion kimchi, cabbage kimchi has fallen... It's greasy to my taste...  I have no intention of revisiting.
# model result: Positive
# answer: 0
#
# =============================== Input 19 ===============================
# Not until long ago. The owner changed and the taste changed
# model result: Negative
# answer: 0
#
# =============================== Input 20 ===============================
# as if it's not seasoned enough
# model result: Negative
# answer: 0
#
# =============================== Input 21 ===============================
# The food is a bit salty. Rice and curry are refilled
# model result: Negative
# answer: 0
#
# =============================== Input 22 ===============================
# I've been to this place often, and I love that there's a cafe like this in the neighborhood!! The interior is clean, the coffee is delicious, and corn cheese toast is especially delicious!!
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# I thought it was expensive as soon as I entered. But it was the most delicious thing I had this year. I'm going to have a good hangover
# model result: Positive
# answer: 1
#
# =============================== Input 24 ===============================
# It's good. It's been a while, so the price went up
# model result: Positive
# answer: 1
#
# =============================== Input 25 ===============================
# It's so delicious.~~~. However, the employees are not very kind.
# model result: Negative
# answer: 1
#
# =============================== Input 26 ===============================
# I ordered two and shared them with my sister. Both of them were so good I don't know if it's the owner, but the employee is so kind Enjoy your meal
# model result: Positive
# answer: 1
#
# =============================== Input 27 ===============================
# Everyone is kind and the cocktails are so delicious! Thank you for the free shot you gave me as a dart event. It was better because the bathroom was so clean and it didn't smell
# model result: Positive
# answer: 1
#
# =============================== Input 28 ===============================
# Sweet and sour chicken is so delicious.. They cool it down and wrap it up.. The cold gangjeong style...The batter is crispy and it tastes so good.It's real..
# model result: Positive
# answer: 1
#
# =============================== Input 29 ===============================
# Even though it was past lunch time, there was a bit of waiting, but the soup and noodle ingredients were so good as I wanted to come back next time, and it was more delicious with kimchi
# model result: Positive
# answer: 1
#
# =============================== Input 30 ===============================
# The standby system is well-equipped and has a high turnover, so I got in quickly in! I come here regularly because my parents like it! It's good
# model result: Positive
# answer: 1
#
# =============================== Input 31 ===============================
# Although there was a bit of a wait for the weekend. Egg Benedict was so delicious. I want to sit in the outdoor seat on a fine day
# model result: Positive
# answer: 1
#
# =============================== Input 32 ===============================
# I visited because I wanted to eat strawberry dessert. Maybe because it's famous, there are a lot of people even during the day on weekdays. It's expensive, but it tastes good
# model result: Positive
# answer: 1
#
# =============================== Input 33 ===============================
# Even though I waited for 20 minutes and ate alone, they were kind and the food was good without any smell.. It's cost-effective and the radish kimchi is always delicious, so the soup is delicious and a healthy meal is the best
# model result: Positive
# answer: 1
#
# =============================== Input 34 ===============================
# It's so good here... But it's hard to wait, so I'm going to wrap it up now.. I'd like you to change it to a waiting machine! It's so uncomfortable to have to wait in front of the storecrying
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# Even though it was a weekday evening, the atmosphere was amazing.. But Sundaeguk was so delicious that I could endure and wait. I want to eat it with soju next time! I did it again today!
# model result: Positive
# answer: 1
#
# =============================== Input 36 ===============================
# I've been waiting for 40 minutes for lunch on Saturday It wasn't enough But it's not greasy and it's
# model result: Positive
# answer: 1
#
# =============================== Input 37 ===============================
# I broke my promise with my friend to eat something simple Salted pollack pasta is so delicious and lasagna is the best    It makes me think that I'm home Strongly recommended
# model result: Positive
# answer: 1
#
# =============================== Input 38 ===============================
# I really enjoyed breakfast in Seoul! Braised hairtail is good, but the cheonggukjang is really good The free steamed eggs and fried hairtail were also delicious I want to visit again
# model result: Positive
# answer: 1
#
# =============================== Input 39 ===============================
# Braised hairtail in line. It was delicious. I was a little distracted, but the four Chinese family members at the next table right next to me had such a good voice
# model result: Positive
# answer: 1
#
# =============================== Input 40 ===============================
# The taste is soft and very delicious.. They were very kind and gave us a service. I strongly recommend it.
# model result: Positive
# answer: 1
#
# =============================== Input 41 ===============================
# It's a sandwich I often eat for a meal and it's always delicious and filling :) The vegetables are fresh and the bread is delicious. The staff is also kind, so I use it often
# model result: Positive
# answer: 1
# =============================== Input 42 ===============================
# The bread is chewy. It's delicious. It hasn't been long since it opened, so the baker's. I think it's more passionate.. . Warm bread made by warm people. Try it~~^^
# model result: Positive
# answer: 1
#
# =============================== Input 43 ===============================
# The quality of the meat and the tempura are very fresh and delicious.. I can't help but write a review... Thank you!
# model result: Positive
# answer: 1
#
# =============================== Input 44 ===============================
# It's kind and the oil is clean and crispy and delicious The members really liked it The delivery time is a bit long, so I think I need to order it in advance That's the only thing that's unfortunate
# model result: Positive
# answer: 1
#
# =============================== Input 45 ===============================
# The cost-effectiveness is the best and it's so delicious..
# model result: Positive
# answer: 1
#
# =============================== Input 46 ===============================
# It was a little noisy because there were many students and the music was loud, but it was okay because the snacks were delicious and the price was reasonable
# model result: Positive
# answer: 1
#
# =============================== Input 47 ===============================
# Except when there are a lot of people, it's loud enough to make people's ears ring with the sound of music... The food is delicious and inexpensive, and even the thin ice of beer is very good!
# model result: Positive
# answer: 1
#
# =============================== Input 48 ===============================
# They are kind and the drinks are delicious. It would be better if the store was a little bigger
# model result: Positive
# answer: 1
#
# =============================== Input 49 ===============================
# The meat is so goodIt's my first time in Pyeongtaek, and thanks to you, I have a good memory. They grill meat themselves, and they're all so nice and kind
# model result: Positive
# answer: 1
#
# =============================== Input 50 ===============================
# The pork belly was really good, but the pork neck was crazy!!! I'm amazed as soon as I eat it Do you really recommend it!!!! It's so nice that the staff cooked it deliciously. I'll save it as a good restaurant
# model result: Positive
# answer: 1
#
# =============================== Input 51 ===============================
# He was kind and the drink was very delicious! The side tastes good, too
# model result: Positive
# answer: 1
#
# =============================== Input 52 ===============================
# Parking is a little inconvenient, but the atmosphere of the store is so good and all the menus are delicious :)
# model result: Positive
# answer: 1
#
# =============================== Input 53 ===============================
# It was good because there was a lot. They gave me a big piece of high quality meat and the jjajo was really good.
# model result: Positive
# answer: 1
#
# =============================== Input 54 ===============================
# The food is delicious and clean! And he was very kind. Maybe that's why there were a lot of customers
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# It's incredibly unkind. It tastes good. Green onion recommendation
# model result: Positive
# answer: 1
#
# =============================== Input 56 ===============================
# The food is delicious but not kind
# model result: Positive
# answer: 1
#
# =============================== Input 57 ===============================
# The owner is kind, the drinks are good, and the interior of the store is pretty
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# The grain powder taste is good.. But... the two working women are very unkind. You seem to be very dissatisfied with society as to what's upsetting about you.
# model result: Positive
# answer: 1
#
# =============================== Input 59 ===============================
# It's so good. The food is really good and it comes out clean. Above all, the staff are so kind!! There's always a lot of waiting, but it's inevitable that there's a lot of waitingㅠ
# model result: Positive
# answer: 1
#
# =============================== Input 60 ===============================
# Instant tteokbokki is good. I put in the noodles and the last fried rice
# model result: Positive
# answer: 1
#
# =============================== Input 61 ===============================
# The owner is kind and the side dish is very delicious! There's a variety of drinks, so it's fun to choose one every time you go
# model result: Positive
# answer: 1
#
# =============================== Input 62 ===============================
# The atmosphere is good and the taste is good!! However, as the hall was full, it was a little noisy and the air was hot, too. :-( It was too bad
# model result: Positive
# answer: 1
#
# =============================== Input 63 ===============================
# It's delicious and kind. I am happy that there is a bar in the neighborhood where I can drink various traditional liquor. It's a place where you have to wait because it's a place where you have to wait.
# model result: Positive
# answer: 1
#
# =============================== Input 64 ===============================
# It's as delicious as it's rumored. I think it's a bit expensive
# model result: Positive
# answer: 1
#
# =============================== Input 65 ===============================
# The food is really good. I knew why it was so famous. Mackerel sushi is really good, but there are no pictures!It's so good
# model result: Positive
# answer: 1
#
# =============================== Input 66 ===============================
# I really enjoyed the meal! It was the most delicious place I've ever been to. I'll go again later
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# It's good, but the staff members are kind... I understand if it's because you're busy..
# model result: Positive
# answer: 1
#
# =============================== Input 68 ===============================
# It's clean and delicious. It's a shame that the price went up
# model result: Positive
# answer: 1
#
# =============================== Input 69 ===============================
# The food was delicious and the staff were very kind, so I had a nice meal. It's nice to have a seat for Da-Ji!
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# I can't say it's cheap and the waiting is long. A taste I want to go again!! The ingredients are fresh and it tastes healthy and delicious!
# model result: Positive
# answer: 1
#
# =============================== Input 71 ===============================
# It's a bit pricey, but it's good
# model result: Positive
# answer: 1
#
# =============================== Input 72 ===============================
# It's good. It's not that sweet. It's really good
# model result: Positive
# answer: 1
#
# =============================== Input 73 ===============================
# I had a preconceived notion that it was vegan, but it's more delicious than other regular breads!!  The bread is more chewy and delicious, so I'm going to revisit it!!
# model result: Positive
# answer: 1
#
# =============================== Input 74 ===============================
# The owner is so kind and it's a vegan bakery, so it's unique and so delicious!! Especially, tofu brownies are the best!^^^♡
# model result: Positive
# answer: 1
#
# =============================== Input 75 ===============================
# It's cost-effective and the ingredients are fresh and delicious
# model result: Positive
# answer: 1
#
# =============================== Input 76 ===============================
# There's a lot and it'sI hope it's controlled
# model result: Positive
# answer: 1
#
# =============================== Input 77 ===============================
# The staff are so kind. I enjoyed my meal, too!
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# Fresh ingredients. Thank you for the food
# model result: Positive
# answer: 1
#
# =============================== Input 79 ===============================
# The staff is kind and it tastes better with Tabasco sauce that you recommended!!! I went alone, and it's nice to enjoy delicious food and relaxation♥
# model result: Positive
# answer: 1
#
# =============================== Input 80 ===============================
# It's good. But it's small and they didn't give me a fork
# model result: Positive
# answer: 1
#
# test accuracy: 0.9625

# %%
#잘못 분류된 문장의 attention
for sent in NaverWrongResult:
    encoding = preprocessing(sent, tokenizer,70)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: Maybe it's just meat. But I can't eat soybean paste with crab. It's too fishy The bibim sauce for naengmyeon is not that bad, but the broth is... Wow..It's a taste I don't want to eat again
# 분류: Positive
# MAX_LEN:  67
# ========================= emphasize by attention result==========================
# maybe it ' s just meat . but i can ' t eat soy ##be ##an paste with crab . it ' s too fish ##y the bi ##bi ##m sauce for na ##eng ##my ##eon is not that bad , but the bro ##th is . . . wow . . it ' s a taste i don ' t want to eat again
# highest attention: ' ' bi ##bi
#
#
#
# 입력 문장: Far from green onion kimchi, cabbage kimchi has fallen... It's greasy to my taste...  I have no intention of revisiting.
# 분류: Positive
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# far from green onion kim ##chi , cabbage kim ##chi has fallen . . . it ' s greasy to my taste . . . i have no intention of rev ##isi ##ting .
# highest attention: kim kim ##chi green
#
#
#
# 입력 문장: It's so delicious.~~~. However, the employees are not very kind.
# 분류: Negative
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# it ' s so delicious . ~ ~ ~ . however , the employees are not very kind .
# highest attention: however the are not

# %%
#잘 분류된 문장의 attention
for sent in NaverRightResult:
    encoding = preprocessing(sent, tokenizer,70)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# 분류: Negative
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# the ja ##jan ##gm ##ye ##on on the tray was too salty and the noodles were swollen . tang ##su ##yu ##k had a bad fish ##y smell , jj ##amp ##pon ##g had a lot of onions , and squid had only 3 pieces
# highest attention: and and pieces were
#
#
#
# 입력 문장: The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# 분류: Negative
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# the store is really messy . . sp ##rite was carbonate ##d water without any sweetness . . there seemed to be a shortage of staff .
# highest attention: seemed to there be
#
#
#
# 입력 문장: There's too much meat oil. The service seems to be a little lacking. It's a bit disappointing
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# there ' s too much meat oil . the service seems to be a little lacking . it ' s a bit disappointing
# highest attention: to bit seems a
#
#
#
# 입력 문장: I don't recommend Tomahawk.. the toughness of the meat
# 분류: Negative
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# i don ' t recommend tom ##aha ##wk . . the tough ##ness of the meat
# highest attention: ' t tom i
#
#
#
# 입력 문장: I ate rice with steak and rice with cube steak, but personally, I don't want to recommend cube steak if you don't like all foods. It's too sweet
# 분류: Negative
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# i ate rice with steak and rice with cube steak , but personally , i don ' t want to recommend cube steak if you don ' t like all foods . it ' s too sweet
# highest attention: ' ' if personally
#
#
#
# 입력 문장: Braised hairtail is too salty. I can't eat a hairtail because it's too hard and small. Steamed eggs are too bitter. Dozer's throat is sore  I don't think I'll ever go again
# 분류: Negative
# MAX_LEN:  51
# ========================= emphasize by attention result==========================
# bra ##ised hair ##tail is too salty . i can ' t eat a hair ##tail because it ' s too hard and small . steamed eggs are too bitter . do ##zer ' s throat is sore i don ' t think i ' ll ever go again
# highest attention: ' ' ' i
#
#
#
# 입력 문장: The fried chicken was so greasy that it didn't taste good.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the fried chicken was so greasy that it didn ' t taste good .
# highest attention: ' that it was
#
#
#
# 입력 문장: I only ate BBQ chicken, but this time it was too saltyPlease reduce the amount of salt~~
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# i only ate bb ##q chicken , but this time it was too salty ##ple ##ase reduce the amount of salt ~ ~
# highest attention: ~ ~ but of
#
#
#
# 입력 문장: I ordered Cheekki at a reasonable price, so it's a bit tough and hard... Let's just order chicken with BBQ
# 분류: Negative
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# i ordered cheek ##ki at a reasonable price , so it ' s a bit tough and hard . . . let ' s just order chicken with bb ##q
# highest attention: ' so and ##q
#
#
#
# 입력 문장: I've never been to such an insincere and unfriendly restaurant. I read the review and came here saying that it's delicious even if it's unfriendly, but it's not delicious;;
# 분류: Negative
# MAX_LEN:  52
# ========================= emphasize by attention result==========================
# i ' ve never been to such an ins ##in ##cer ##e and un ##fr ##ien ##dly restaurant . i read the review and came here saying that it ' s delicious even if it ' s un ##fr ##ien ##dly , but it ' s not delicious ; ;
# highest attention: and ; ; but
#
#
#
# 입력 문장: It was just so-so. The seasoning was bland, and I was waiting to pay for the package.. Personally, I don't like it
# 분류: Negative
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# it was just so - so . the season ##ing was bland , and i was waiting to pay for the package . . personally , i don ' t like it
# highest attention: ' it and personally
#
#
#
# 입력 문장: The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# 분류: Negative
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# the ja ##jan ##gm ##ye ##on on the tray was too salty and the noodles were swollen . tang ##su ##yu ##k had a bad fish ##y smell , jj ##amp ##pon ##g had a lot of onions , and squid had only 3 pieces
# highest attention: and and pieces were
#
#
#
# 입력 문장: The noodles are broken and have no elasticity at all because they are weak. The delivery came ahead of schedule.
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# the noodles are broken and have no elastic ##ity at all because they are weak . the delivery came ahead of schedule .
# highest attention: because and are schedule
#
#
#
# 입력 문장: The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# 분류: Negative
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# the store is really messy . . sp ##rite was carbonate ##d water without any sweetness . . there seemed to be a shortage of staff .
# highest attention: seemed to there be
#
#
#
# 입력 문장: I've tried seasoned raw octopus vinegar and octopus garlic raw fish, but the taste...Actually, I don't know. It's not cheap either
# 분류: Negative
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# i ' ve tried seasoned raw octopus vinegar and octopus garlic raw fish , but the taste . . . actually , i don ' t know . it ' s not cheap either
# highest attention: ' either know cheap
#
#
#
# 입력 문장: It's not the taste of the past. The meat is almost fat
# 분류: Negative
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# it ' s not the taste of the past . the meat is almost fat
# highest attention: of the almost the
#
#
#
# 입력 문장: Not until long ago. The owner changed and the taste changed
# 분류: Negative
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# not until long ago . the owner changed and the taste changed
# highest attention: and ago changed changed
#
#
#
# 입력 문장: as if it's not seasoned enough
# 분류: Negative
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# as if it ' s not seasoned enough
# highest attention: as enough if not
#
#
#
# 입력 문장: The food is a bit salty. Rice and curry are refilled
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the food is a bit salty . rice and curry are ref ##ille ##d
# highest attention: ##d a the are
#
#
#
# 입력 문장: I've been to this place often, and I love that there's a cafe like this in the neighborhood!! The interior is clean, the coffee is delicious, and corn cheese toast is especially delicious!!
# 분류: Positive
# MAX_LEN:  46
# ========================= emphasize by attention result==========================
# i ' ve been to this place often , and i love that there ' s a cafe like this in the neighborhood ! ! the interior is clean , the coffee is delicious , and corn cheese toast is especially delicious ! !
# highest attention: ' clean is delicious
#
#
#
# 입력 문장: I thought it was expensive as soon as I entered. But it was the most delicious thing I had this year. I'm going to have a good hangover
# 분류: Positive
# MAX_LEN:  35
# ========================= emphasize by attention result==========================
# i thought it was expensive as soon as i entered . but it was the most delicious thing i had this year . i ' m going to have a good hang ##over
# highest attention: ' delicious expensive most
#
#
#
# 입력 문장: It's good. It's been a while, so the price went up
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it ' s good . it ' s been a while , so the price went up
# highest attention: s good price '
#
#
#
# 입력 문장: I ordered two and shared them with my sister. Both of them were so good I don't know if it's the owner, but the employee is so kind Enjoy your meal
# 분류: Positive
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# i ordered two and shared them with my sister . both of them were so good i don ' t know if it ' s the owner , but the employee is so kind enjoy your meal
# highest attention: ' both good employee
#
#
#
# 입력 문장: Everyone is kind and the cocktails are so delicious! Thank you for the free shot you gave me as a dart event. It was better because the bathroom was so clean and it didn't smell
# 분류: Positive
# MAX_LEN:  42
# ========================= emphasize by attention result==========================
# everyone is kind and the cocktail ##s are so delicious ! thank you for the free shot you gave me as a dart event . it was better because the bathroom was so clean and it didn ' t smell
# highest attention: ' clean smell delicious
#
#
#
# 입력 문장: Sweet and sour chicken is so delicious.. They cool it down and wrap it up.. The cold gangjeong style...The batter is crispy and it tastes so good.It's real..
# 분류: Positive
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# sweet and sour chicken is so delicious . . they cool it down and wrap it up . . the cold gang ##je ##ong style . . . the batter is crisp ##y and it tastes so good . it ' s real . .
# highest attention: tastes they crisp and
#
#
#
# 입력 문장: Even though it was past lunch time, there was a bit of waiting, but the soup and noodle ingredients were so good as I wanted to come back next time, and it was more delicious with kimchi
# 분류: Positive
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# even though it was past lunch time , there was a bit of waiting , but the soup and no ##odle ingredients were so good as i wanted to come back next time , and it was more delicious with kim ##chi
# highest attention: and more good ingredients
#
#
#
# 입력 문장: The standby system is well-equipped and has a high turnover, so I got in quickly in! I come here regularly because my parents like it! It's good
# 분류: Positive
# MAX_LEN:  37
# ========================= emphasize by attention result==========================
# the stand ##by system is well - equipped and has a high turnover , so i got in quickly in ! i come here regularly because my parents like it ! it ' s good
# highest attention: is turnover high well
#
#
#
# 입력 문장: Although there was a bit of a wait for the weekend. Egg Benedict was so delicious. I want to sit in the outdoor seat on a fine day
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# although there was a bit of a wait for the weekend . egg benedict was so delicious . i want to sit in the outdoor seat on a fine day
# highest attention: delicious was want so
#
#
#
# 입력 문장: I visited because I wanted to eat strawberry dessert. Maybe because it's famous, there are a lot of people even during the day on weekdays. It's expensive, but it tastes good
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# i visited because i wanted to eat strawberry dessert . maybe because it ' s famous , there are a lot of people even during the day on weekdays . it ' s expensive , but it tastes good
# highest attention: tastes good s expensive
#
#
#
# 입력 문장: Even though I waited for 20 minutes and ate alone, they were kind and the food was good without any smell.. It's cost-effective and the radish kimchi is always delicious, so the soup is delicious and a healthy meal is the best
# 분류: Positive
# MAX_LEN:  55
# ========================= emphasize by attention result==========================
# even though i waited for 20 minutes and ate alone , they were kind and the food was good without any smell . . it ' s cost - effective and the ra ##dis ##h kim ##chi is always delicious , so the soup is delicious and a healthy meal is the best
# highest attention: good delicious was s
#
#
#
# 입력 문장: It's so good here... But it's hard to wait, so I'm going to wrap it up now.. I'd like you to change it to a waiting machine! It's so uncomfortable to have to wait in front of the storecrying
# 분류: Positive
# MAX_LEN:  60
# ========================= emphasize by attention result==========================
# it ' s so good here . . . but it ' s hard to wait , so i ' m going to wrap it up now . . i ' d like you to change it to a waiting machine ! it ' s so uncomfortable to have to wait in front of the store ##cr ##ying
# highest attention: ' ' but s
#
#
#
# 입력 문장: Even though it was a weekday evening, the atmosphere was amazing.. But Sundaeguk was so delicious that I could endure and wait. I want to eat it with soju next time! I did it again today!
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# even though it was a weekday evening , the atmosphere was amazing . . but sun ##dae ##gu ##k was so delicious that i could endure and wait . i want to eat it with so ##ju next time ! i did it again today !
# highest attention: atmosphere it was amazing
#
#
#
# 입력 문장: I've been waiting for 40 minutes for lunch on Saturday It wasn't enough But it's not greasy and it's
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# i ' ve been waiting for 40 minutes for lunch on saturday it wasn ' t enough but it ' s not greasy and it ' s
# highest attention: ' waiting but 40
#
#
#
# 입력 문장: I broke my promise with my friend to eat something simple Salted pollack pasta is so delicious and lasagna is the best    It makes me think that I'm home Strongly recommended
# 분류: Positive
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# i broke my promise with my friend to eat something simple salt ##ed poll ##ack pasta is so delicious and las ##ag ##na is the best it makes me think that i ' m home strongly recommended
# highest attention: is is delicious and
#
#
#
# 입력 문장: I really enjoyed breakfast in Seoul! Braised hairtail is good, but the cheonggukjang is really good The free steamed eggs and fried hairtail were also delicious I want to visit again
# 분류: Positive
# MAX_LEN:  43
# ========================= emphasize by attention result==========================
# i really enjoyed breakfast in seoul ! bra ##ised hair ##tail is good , but the che ##ong ##gu ##k ##jan ##g is really good the free steamed eggs and fried hair ##tail were also delicious i want to visit again
# highest attention: is is good and
#
#
#
# 입력 문장: Braised hairtail in line. It was delicious. I was a little distracted, but the four Chinese family members at the next table right next to me had such a good voice
# 분류: Positive
# MAX_LEN:  38
# ========================= emphasize by attention result==========================
# bra ##ised hair ##tail in line . it was delicious . i was a little distracted , but the four chinese family members at the next table right next to me had such a good voice
# highest attention: chinese delicious good was
#
#
#
# 입력 문장: The taste is soft and very delicious.. They were very kind and gave us a service. I strongly recommend it.
# 분류: Positive
# MAX_LEN:  26
# ========================= emphasize by attention result==========================
# the taste is soft and very delicious . . they were very kind and gave us a service . i strongly recommend it .
# highest attention: delicious taste soft is
#
#
#
# 입력 문장: It's a sandwich I often eat for a meal and it's always delicious and filling :) The vegetables are fresh and the bread is delicious. The staff is also kind, so I use it often
# 분류: Positive
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# it ' s a sandwich i often eat for a meal and it ' s always delicious and filling : ) the vegetables are fresh and the bread is delicious . the staff is also kind , so i use it often
# highest attention: fresh delicious are delicious
#
#
#
# 입력 문장: The bread is chewy. It's delicious. It hasn't been long since it opened, so the baker's. I think it's more passionate.. . Warm bread made by warm people. Try it~~^^
# 분류: Positive
# MAX_LEN:  52
# ========================= emphasize by attention result==========================
# the bread is chew ##y . it ' s delicious . it hasn ' t been long since it opened , so the baker ' s . i think it ' s more passionate . . . warm bread made by warm people . try it ~ ~ ^ ^
# highest attention: ' delicious ^ s
#
#
#
# 입력 문장: The quality of the meat and the tempura are very fresh and delicious.. I can't help but write a review... Thank you!
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# the quality of the meat and the te ##mp ##ura are very fresh and delicious . . i can ' t help but write a review . . . thank you !
# highest attention: ' meat fresh and
#
#
#
# 입력 문장: It's kind and the oil is clean and crispy and delicious The members really liked it The delivery time is a bit long, so I think I need to order it in advance That's the only thing that's unfortunate
# 분류: Positive
# MAX_LEN:  49
# ========================= emphasize by attention result==========================
# it ' s kind and the oil is clean and crisp ##y and delicious the members really liked it the delivery time is a bit long , so i think i need to order it in advance that ' s the only thing that ' s unfortunate
# highest attention: clean members oil crisp
#
#
#
# 입력 문장: The cost-effectiveness is the best and it's so delicious..
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the cost - effectiveness is the best and it ' s so delicious . .
# highest attention: cost effectiveness delicious s
#
#
#
# 입력 문장: It was a little noisy because there were many students and the music was loud, but it was okay because the snacks were delicious and the price was reasonable
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# it was a little noisy because there were many students and the music was loud , but it was okay because the snacks were delicious and the price was reasonable
# highest attention: price delicious snacks were
#
#
#
# 입력 문장: Except when there are a lot of people, it's loud enough to make people's ears ring with the sound of music... The food is delicious and inexpensive, and even the thin ice of beer is very good!
# 분류: Positive
# MAX_LEN:  49
# ========================= emphasize by attention result==========================
# except when there are a lot of people , it ' s loud enough to make people ' s ears ring with the sound of music . . . the food is delicious and inexpensive , and even the thin ice of beer is very good !
# highest attention: food loud is inexpensive
#
#
#
# 입력 문장: They are kind and the drinks are delicious. It would be better if the store was a little bigger
# 분류: Positive
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# they are kind and the drinks are delicious . it would be better if the store was a little bigger
# highest attention: delicious drinks kind are
#
#
#
# 입력 문장: The meat is so goodIt's my first time in Pyeongtaek, and thanks to you, I have a good memory. They grill meat themselves, and they're all so nice and kind
# 분류: Positive
# MAX_LEN:  45
# ========================= emphasize by attention result==========================
# the meat is so good ##it ' s my first time in p ##ye ##ong ##ta ##ek , and thanks to you , i have a good memory . they grill meat themselves , and they ' re all so nice and kind
# highest attention: ' is they themselves
#
#
#
# 입력 문장: The pork belly was really good, but the pork neck was crazy!!! I'm amazed as soon as I eat it Do you really recommend it!!!! It's so nice that the staff cooked it deliciously. I'll save it as a good restaurant
# 분류: Positive
# MAX_LEN:  59
# ========================= emphasize by attention result==========================
# the pork belly was really good , but the pork neck was crazy ! ! ! i ' m amazed as soon as i eat it do you really recommend it ! ! ! ! it ' s so nice that the staff cooked it delicious ##ly . i ' ll save it as a good restaurant
# highest attention: ' ' staff was
#
#
#
# 입력 문장: He was kind and the drink was very delicious! The side tastes good, too
# 분류: Positive
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# he was kind and the drink was very delicious ! the side tastes good , too
# highest attention: side tastes delicious good
#
#
#
# 입력 문장: Parking is a little inconvenient, but the atmosphere of the store is so good and all the menus are delicious :)
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# parking is a little inc ##on ##ven ##ient , but the atmosphere of the store is so good and all the menu ##s are delicious : )
# highest attention: atmosphere store is good
#
#
#
# 입력 문장: It was good because there was a lot. They gave me a big piece of high quality meat and the jjajo was really good.
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# it was good because there was a lot . they gave me a big piece of high quality meat and the jj ##aj ##o was really good .
# highest attention: they quality was good
#
#
#
# 입력 문장: The food is delicious and clean! And he was very kind. Maybe that's why there were a lot of customers
# 분류: Positive
# MAX_LEN:  26
# ========================= emphasize by attention result==========================
# the food is delicious and clean ! and he was very kind . maybe that ' s why there were a lot of customers
# highest attention: clean is delicious he
#
#
#
# 입력 문장: It's incredibly unkind. It tastes good. Green onion recommendation
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# it ' s incredibly un ##kind . it tastes good . green onion recommendation
# highest attention: tastes un good it
#
#
#
# 입력 문장: The food is delicious but not kind
# 분류: Positive
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# the food is delicious but not kind
# highest attention: is food delicious but
#
#
#
# 입력 문장: The owner is kind, the drinks are good, and the interior of the store is pretty
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# the owner is kind , the drinks are good , and the interior of the store is pretty
# highest attention: interior store kind is
#
#
#
# 입력 문장: The grain powder taste is good.. But... the two working women are very unkind. You seem to be very dissatisfied with society as to what's upsetting about you.
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# the grain powder taste is good . . but . . . the two working women are very un ##kind . you seem to be very dissatisfied with society as to what ' s upset ##ting about you .
# highest attention: two grain women working
#
#
#
# 입력 문장: It's so good. The food is really good and it comes out clean. Above all, the staff are so kind!! There's always a lot of waiting, but it's inevitable that there's a lot of waitingㅠ
# 분류: Positive
# MAX_LEN:  51
# ========================= emphasize by attention result==========================
# it ' s so good . the food is really good and it comes out clean . above all , the staff are so kind ! ! there ' s always a lot of waiting , but it ' s inevitable that there ' s a lot of [UNK]
# highest attention: out clean good comes
#
#
#
# 입력 문장: Instant tteokbokki is good. I put in the noodles and the last fried rice
# 분류: Positive
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# instant tt ##eo ##k ##bo ##kki is good . i put in the noodles and the last fried rice
# highest attention: i is good instant
#
#
#
# 입력 문장: The owner is kind and the side dish is very delicious! There's a variety of drinks, so it's fun to choose one every time you go
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# the owner is kind and the side dish is very delicious ! there ' s a variety of drinks , so it ' s fun to choose one every time you go
# highest attention: variety delicious is is
#
#
#
# 입력 문장: The atmosphere is good and the taste is good!! However, as the hall was full, it was a little noisy and the air was hot, too. :-( It was too bad
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# the atmosphere is good and the taste is good ! ! however , as the hall was full , it was a little noisy and the air was hot , too . : - ( it was too bad
# highest attention: ( : hot bad
#
#
#
# 입력 문장: It's delicious and kind. I am happy that there is a bar in the neighborhood where I can drink various traditional liquor. It's a place where you have to wait because it's a place where you have to wait.
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it ' s delicious and kind . i am happy that there is a bar in the neighborhood where i can drink various traditional liquor . it ' s a place where you have to wait because it ' s a place where you have to wait .
# highest attention: delicious s and '
#
#
#
# 입력 문장: It's as delicious as it's rumored. I think it's a bit expensive
# 분류: Positive
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# it ' s as delicious as it ' s rumored . i think it ' s a bit expensive
# highest attention: it it s delicious
#
#
#
# 입력 문장: The food is really good. I knew why it was so famous. Mackerel sushi is really good, but there are no pictures!It's so good
# 분류: Positive
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# the food is really good . i knew why it was so famous . mack ##ere ##l su ##shi is really good , but there are no pictures ! it ' s so good
# highest attention: is but is s
#
#
#
# 입력 문장: I really enjoyed the meal! It was the most delicious place I've ever been to. I'll go again later
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# i really enjoyed the meal ! it was the most delicious place i ' ve ever been to . i ' ll go again later
# highest attention: ' ' enjoyed delicious
#
#
#
# 입력 문장: It's good, but the staff members are kind... I understand if it's because you're busy..
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# it ' s good , but the staff members are kind . . . i understand if it ' s because you ' re busy . .
# highest attention: ' s good but
#
#
#
# 입력 문장: It's clean and delicious. It's a shame that the price went up
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it ' s clean and delicious . it ' s a shame that the price went up
# highest attention: clean delicious s and
#
#
#
# 입력 문장: The food was delicious and the staff were very kind, so I had a nice meal. It's nice to have a seat for Da-Ji!
# 분류: Positive
# MAX_LEN:  33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 13
#      10 print('분류:', prediction)
#      11 print('MAX_LEN: ',MAX_LEN_IN)
# ---> 13 idxs=sort_by_att(retLastAtt,retTok)
#      15 emp_by_att(idxs,retTok)
#      17 get_highest_att_tok(idxs,retTok,4)
#
# Cell In[24], line 16, in sort_by_att(attention, tokens)
#      14 for row in att_of_head:
#      15     col=0
# ---> 16     for elem in row:
#      17         value=elem.item()
#      18         atts_sum_of_head[col]+=value # head 하나에 대한 토큰이 가지는 attention 값
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\torch\_tensor.py:940, in Tensor.__iter__(self)
#     931 if torch._C._get_tracing_state():
#     932     warnings.warn(
#     933         "Iterating over a tensor might cause the trace to be incorrect. "
#     934         "Passing a tensor of different shape won't change the number of "
#    (...)
#     938         stacklevel=2,
#     939     )
# --> 940 return iter(self.unbind(0))
#
# KeyboardInterrupt:

# %%
#NAVER final test data 세팅

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/naver_fin_food_trans.csv'
df = pd.read_csv(test_url,sep=',', header=0)
df.head(5)
# Out:
#    Unnamed: 0  id category                                               text  \
# 0           0   0    taste  요즘 평양냉면 제대로 하는집이 많지 않은데 여긴 찐입니다???? 자극적이지 않은데 ...
# 1           1   2    taste  평양냉면 맛도 잘 모르고 갔다가 맛보고 헉~했어요 너무 밍밍했거든요\n건강한 맛인거...
# 2           2   3    taste  평양냉면이 정말 맛있어요…????평양냉면, 온반 하나씩 시켜서 먹었는데 온반은 삼삼...
# 3           3   4    taste            맛있어요~\n근데 오랜만에 갔더니 녹두전 사이즈가 줄어서 놀랐어요 ㅠㅠ
# 4           4   5    taste                          맛있게 먹었습니다\n부담없는 맛과 국물이에요
#
#    polarity                                         trans_text
# 0         1  There aren't many restaurants that make Pyeong...
# 1         1  I didn't even know the taste of Pyeongyang nae...
# 2         1  Pyeongyang naengmyeon is really delicious...I ...
# 3         1  It's good. But I was surprised that the size o...
# 4         1     I enjoyed my meal. It's easy to taste and soup

# %%
df_new=df
df_new['length'] = df['trans_text'].apply(len)
df_new.length.describe()
# Out:
# count    156.00000
# mean      99.00641
# std      140.91180
# min        9.00000
# 25%       17.00000
# 50%       45.00000
# 75%      110.50000
# max      784.00000
# Name: length, dtype: float64

# %%
# naver data에 대한 분류 및 accuracy 측정
count=0

negNum=0
posNum=0

test_text = df.trans_text.values
test_labels = df.polarity.values

NaverWrongResult=[]
NaverRightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].trans_text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
        negNum+=1
    else:
        result=1
        posNum+=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        NaverRightResult.append(t)
    else:
        NaverWrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
print("Positive ratio: {:.4f}".format(posNum/len(test_labels)))
print("Negative ratio: {:.4f}".format(negNum/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# There aren't many restaurants that make Pyeongyang naengmyeon properly these days, but this place is real??? It's not stimulating, but it has a deep taste. I'm so full, but I ate it until the end?? It seemed like she was making all the side dishes herself!! The store is spacious and clean, so I think it'll be good for group gatherings!! It's my first time seeing a restaurant with a spacious and clean bathroom like Evaluationok. The hygiene and taste are the best???
# model result: Positive
# answer: 1
#
# =============================== Input 2 ===============================
# I didn't even know the taste of Pyeongyang naengmyeon, so I tasted it and gasped It was too bland. I think it's a healthy taste, but it wasn't good for my taste The mung bean pancake was too small and thin for the price
# model result: Negative
# answer: 1
#
# =============================== Input 3 ===============================
# Pyeongyang naengmyeon is really delicious...I ordered Pyeongyang naengmyeon and an on-ban, but the on-ban was so hot that my stomach was too-comfortable????Will the two be a good combination? I did it, but each one was so good that I ate it well?? The staff are so kind, so I recommend it!!
# model result: Positive
# answer: 1
#
# =============================== Input 4 ===============================
# It's good. But I was surprised that the size of mung bean pancake got smaller crying
# model result: Positive
# answer: 1
#
# =============================== Input 5 ===============================
# I enjoyed my meal. It's easy to taste and soup
# model result: Positive
# answer: 1
#
# =============================== Input 6 ===============================
# I watched Pyeongyang naengmyeon on YouTube and I suddenly craved it, so I ate it! I waited until my friend came and ordered it, but it was good that it was processed so that it could come out on time.. . And I sold mung bean pancake and dumplings individually, so I ordered just enough and ate them allThe staff were kind and the food was delicious, but the sad thing was that the distance between the tables was too close and the drunk men were noisy, so my ears hurt(Crying) (Crying) But the staff restrained me a little bit. Thank you for your hard work~~. I'm willing to revisit, and I think I'll come again when I think of Pyeongyang naengmyeon!
# model result: Positive
# answer: 1
#
# =============================== Input 7 ===============================
# Pyeongyang naengmyeon is getting better. 15,000 per bowl is an amazing price. The food and side dishes are clean
# model result: Positive
# answer: 1
#
# =============================== Input 8 ===============================
# It's a little expensive, but the inside of the restaurant is clean and friendly, and above all, it's delicious
# model result: Positive
# answer: 1
#
# =============================== Input 9 ===============================
# The soup was delicious, so I was busy eating and took a picture. It's so delicious.~~
# model result: Positive
# answer: 1
#
# =============================== Input 10 ===============================
# I had Pyeongyang naengmyeon and Onban It tasted good. The hot food was warm and the ingredients were rich and the soup was good. Pyeongnaeng has two pieces of chicken beef and one piece of pork slices, and more broth, please.
# model result: Positive
# answer: 1
#
# =============================== Input 11 ===============================
# Onban is good.
# model result: Positive
# answer: 1
#
# =============================== Input 12 ===============================
# I couldn't take a picture 약간단체 It's a bit of an open space and there are many groups, so it's a bit chaotic! I haven't seen a fish tray anywhere else and of course I haven't tried it, but it felt new! It's malatang, but the base is fish cake soup? It has pancakes in it?The visual was not very pretty, but it was delicious. And the amount was surprisingly small, so I went there with two of us and ate fish tray and bulgogi..At first, I said I couldn't eat it, so I postponed it, and eventually ordered it, so I ate it all..Big eater, please refer to it [Laughing]
# model result: Positive
# answer: 1
#
# =============================== Input 13 ===============================
# On a cold day, I ate the fish-bok tray warm and self-made Personally, I think noodles are better than cold noodles
# model result: Positive
# answer: 1
#
# =============================== Input 14 ===============================
# I packed the cold noodles and ate them right away... The real noodles spread out.. It was a bit salty and cold~~ My mom and I ate two strawberries and threw them away... I wanted to eat cold noodles, so I wrapped it up... It's a real failure. It's different for each of us
# model result: Negative
# answer: 0
#
# =============================== Input 15 ===============================
# It tastes like hot on-ban
# model result: Positive
# answer: 1
#
# =============================== Input 16 ===============================
# The food tastes good
# model result: Positive
# answer: 1
#
# =============================== Input 17 ===============================
# Beef on top. A warm and healthy bowl. Good
# model result: Positive
# answer: 1
#
# =============================== Input 18 ===============================
# A delicious restaurant where you always trust and eat
# model result: Positive
# answer: 1
#
# =============================== Input 19 ===============================
# Eobuk Tray Dumpling Hot Pot. They're all good
# model result: Positive
# answer: 1
#
# =============================== Input 20 ===============================
# I like plain naengmyeon, but it's a bit salty and salty The dumplings were really good
# model result: Positive
# answer: 1
#
# =============================== Input 21 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 22 ===============================
# Pyeongyang naengmyeon onban is delicious
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# Pyeongyang naengmyeon (water) and a plate of dumplings. Dumplings taste like old grandma used to make. Crushed tofu, meat and chewy dumpling skin. The soy sauce is also delicious because it's delicious. Naengmyeon is not the soup that tastes bad. It's definitely a strong. Delicious taste when approached by beginners. Pyeongyang naengmyeon is delicious if you drink the soup in the morning at a store with the air conditioner on and wrap it with dongchimi kimchi while drinking alcohol the day before eating. If you eat it three times in the middle of summer, you become a maniac. Therefore, the evaluation jade is good. (Not good for a real flat mania) And it was kind?
# model result: Positive
# answer: 1
#
# =============================== Input 24 ===============================
# It's Pyeongyang naengmyeon and it's delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 25 ===============================
# It's a famous dumpling hot pot. The soup isn't salty. You can add kalguksu later
# model result: Positive
# answer: 1
#
# =============================== Input 26 ===============================
# a clean and healthy taste. Parking is inconvenient. Not kind enough
# model result: Positive
# answer: 1
#
# =============================== Input 27 ===============================
# Recommendations for good restaurants
# model result: Positive
# answer: 1
#
# =============================== Input 28 ===============================
# The food in the evaluation room is clean.. It's not salty and a warm bowl of Onban is good
# model result: Positive
# answer: 1
#
# =============================== Input 29 ===============================
# Eobok Tray is good
# model result: Positive
# answer: 1
#
# =============================== Input 30 ===============================
# I really enjoyed the food
# model result: Positive
# answer: 1
#
# =============================== Input 31 ===============================
# Cold noodles are delicious
# model result: Positive
# answer: 1
#
# =============================== Input 32 ===============================
# I ordered beef on-ban, cold noodles, 4 dumplings, and 1 mung bean pancake. We were full It's a bit strong, but it's good The mung bean pancake dumplings were delicious and the soup was full of ingredients, so I ate it well!
# model result: Positive
# answer: 1
#
# =============================== Input 33 ===============================
# Adults like it, so I go there regularly. It's always delicious. I eat dumpling hot pot and flat naengmyeon alternately.
# model result: Positive
# answer: 1
#
# =============================== Input 34 ===============================
# Pyeongyang naengmyeon is so so so.. Boiled pork is delicious
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# Adults like it Eobok Tray soup is a little spicy, but it feels healthy because it's light. The price has risen a lot compared to the past But it's delicious if you eat it sometimes
# model result: Positive
# answer: 1
#
# =============================== Input 36 ===============================
# An old Pyongyang naengmyeon restaurant in Bundang. We have a lot of dinners and there are a lot of people. There are likes and dislikes because the taste of Pyeongyang naengmyeon is boring. It's very close. For those who eat Pyeongyang naengmyeon for the first time, there's no objection. Next time, I'll have to try the fish cake tray. If you're eating Pyeongyang naengmyeon for the first time, you can enjoy it
# model result: Negative
# answer: 1
#
# =============================== Input 37 ===============================
# Pyeongyang naengmyeon is good
# model result: Positive
# answer: 1
#
# =============================== Input 38 ===============================
# It's been a while since I've been here. Eobok Tray is delicious
# model result: Positive
# answer: 1
#
# =============================== Input 39 ===============================
# It's good with fresh ingredients
# model result: Positive
# answer: 1
#
# =============================== Input 40 ===============================
# Evaluation ok onban is good
# model result: Positive
# answer: 1
#
# =============================== Input 41 ===============================
# It's been a long time since I visited with my mom, but I don't like it.. First of all, the price is too high. Prices have risen, but there seems to be no reason for it to be so expensive... The taste is not completely Pyongyang naengmyeon, but the soup is salty, so my mom and I poured water and drank it. The mung bean pancake was too small, so I ordered one more...  There is no kind service.. I don't think I'll revisit.
# model result: Negative
# answer: 0
#
# =============================== Input 42 ===============================
# I remember eating the Eobok tray deliciously, so I ate dumpling hot pot this time, and the soup is spicy and delicious!! It's perfect without being salty. Pyeongyang naengmyeon! It's my first time eating it.. Should I try more!
# model result: Positive
# answer: 1
#
# =============================== Input 43 ===============================
# I called in advance and picked up the package. Thank you for preparing it on time and responding kindly. Dumplings are expensive but delicious!
# model result: Positive
# answer: 1
#
# =============================== Input 44 ===============================
# It tastes weird as time goes by for a few years ago.. At some point, the smell of pork got worse, and after a few years, I came back and ordered Onban, and the smell of pork was severe from dumplings. As far as I remember, you said you would receive delivery from the dumpling factory, but you should change the factory or anything. Maybe I'm unlucky, but every time I go, something comes out of the food. Bindaetteok and a piece of wood?I'm so curious why you have itcrying
# model result: Negative
# answer: 0
#
# =============================== Input 45 ===============================
# I like the deep taste
# model result: Positive
# answer: 1
#
# =============================== Input 46 ===============================
# Dumpling hot pot and fish cake tray are all good
# model result: Positive
# answer: 1
#
# =============================== Input 47 ===============================
# Neat and light tasteA place I want to visit again
# model result: Positive
# answer: 1
#
# =============================== Input 48 ===============================
# I like Pyeongyang naengmyeon and go around looking for good restaurants. Unkind first impression! As soon as I was about to understand, I thought restaurants must be unfriendly, but I ordered mulnaengmyeon + Pyeonyuk. A twist here! If it was unkind but not tasty!! It's not to the point where it's not bad, but below the level!! The broth is very seasoned! There's no deep taste!  Until the fishy smell! Every bowl has traces of a lady's thumb slipping into the broth! The price is more expensive than thunderbolt or Pildongmyeonok!! I'm seriously going to lose my hands!!! The fact that there are so many customers is so strange that I analyzed it and found that there are many places to park on the surrounding streets. The worst restaurant by the first half of 22 is very likely!!!
# model result: Negative
# answer: 0
#
# =============================== Input 49 ===============================
# I really enjoyed the meal.
# model result: Positive
# answer: 1
#
# =============================== Input 50 ===============================
# taste good
# model result: Positive
# answer: 1
# =============================== Input 51 ===============================
# It's good. It's good for adults to children
# model result: Positive
# answer: 1
#
# =============================== Input 52 ===============================
# I went there for Parents' Day, and the kindness and hygiene were not good for the price. They don't keep the waiting order, so they wait for more than 40 minutes and the food is busy, so they tell me to cook it on my own, and the naengmyeon is tasteless.. Dumplings are not that..Bulgogi was delicious. But the employee's unkindness...I don't think I'll go twice.
# model result: Positive
# answer: 0
#
# =============================== Input 53 ===============================
# It's a bit salty
# model result: Negative
# answer: 0
#
# =============================== Input 54 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# Pyeongyang naengmyeon restaurant
# model result: Positive
# answer: 1
#
# =============================== Input 56 ===============================
# It is delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 57 ===============================
# Onban is delicious!
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# It's so good!
# model result: Positive
# answer: 1
#
# =============================== Input 59 ===============================
# It's fresh and delicious. Nengmyun sari is 9,000 won... I ordered it without looking at the price, but it's too expensive
# model result: Positive
# answer: 1
#
# =============================== Input 60 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 61 ===============================
# It's good.
# model result: Positive
# answer: 1
#
# =============================== Input 62 ===============================
# The taste is not so bad, but the staff's unkindness is making it really bad  I wonder if you're aware of the unkindness of the staff here
# model result: Negative
# answer: 1
#
# =============================== Input 63 ===============================
# The price is definitely expensive, but it's still delicious.Bibim naengmyeon is very strong
# model result: Positive
# answer: 1
#
# =============================== Input 64 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 65 ===============================
# It's not good. Don't go. Dumpling, bibim, and nengmyun are all bad! Go to Neungrado! I threw away my appetite. That doesn't mean he's kind
# model result: Negative
# answer: 0
#
# =============================== Input 66 ===============================
# It's delicious
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# Pyeongyang naengmyeon is delicious
# model result: Positive
# answer: 1
#
# =============================== Input 68 ===============================
# It's so delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 69 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# It's a place where I always eat deliciously and feel bad because of the unkindness of the kindness
# model result: Negative
# answer: 1
#
# =============================== Input 71 ===============================
# Cold noodles are good
# model result: Positive
# answer: 1
#
# =============================== Input 72 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 73 ===============================
# It's good.
# model result: Positive
# answer: 1
#
# =============================== Input 74 ===============================
# Onban is delicious.. Dumplings and fish-shaped trays are also delicious as a popular menu. Evaluation jade is too expensive... and, depending on the branch, manager or employee is unfriendly. I'm sometimes very upset because there are people around me.
# model result: Positive
# answer: 1
#
# =============================== Input 75 ===============================
# A piece of bulgogi is so delicious with Pyeongyang naengmyeon!  It tastes better if you put kimchi soup in Pyeongyang naengmyeon soup
# model result: Positive
# answer: 1
#
# =============================== Input 76 ===============================
# It tastes like spicy cold noodles
# model result: Positive
# answer: 1
#
# =============================== Input 77 ===============================
# It's delicious
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 79 ===============================
# Is it good????
# model result: Positive
# answer: 1
#
# =============================== Input 80 ===============================
# Dumplings are delicious
# model result: Positive
# answer: 1
#
# =============================== Input 81 ===============================
# The taste of Pyongyang naengmyeon broth was strong, but it was better than too bland. The bibim naengmyeon was not spicy and delicious. Beef boiled pork seems to smell a little bit of yellow, but it tasted good. If I have a chance to go to Bundang, I'd like to visit again.
# model result: Positive
# answer: 1
#
# =============================== Input 82 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 83 ===============================
# The food is delicious, but the staff is very unfriendly.
# model result: Positive
# answer: 1
#
# =============================== Input 84 ===============================
# It's so delicious
# model result: Positive
# answer: 1
#
# =============================== Input 85 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 86 ===============================
# Overall, it's a bit vague, but you end up eating it all... It's not a stimulating taste, but it's a taste that I crave. Onban's native chicken is chewy and the soup is delicious. I felt like I was eating it at a reasonable price. Personally, I think Pyeongyang naengmyeon is a bit expensive. I wanted to eat Eobok Tray, but maybe it's because it's been so long. Maybe my memory is wrong, but it's gotten a lot more expensive. I don't think I'll be able to revisit
# model result: Positive
# answer: 1
#
# =============================== Input 87 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 88 ===============================
# Onban is good
# model result: Positive
# answer: 1
#
# =============================== Input 89 ===============================
# I think it's a local restaurant. There are so many people during lunch time... I ate it on-board and it was delicious. There's a lot. Dumplings, meat, glass noodles, vegetables, and mushrooms
# model result: Positive
# answer: 1
#
# =============================== Input 90 ===============================
# It's delicious ^^. There's always a lot of people^^
# model result: Positive
# answer: 1
#
# =============================== Input 91 ===============================
# Eobok Tray is good
# model result: Positive
# answer: 1
#
# =============================== Input 92 ===============================
# It's always good
# model result: Positive
# answer: 1
#
# =============================== Input 93 ===============================
# There's a big difference in taste. Cold noodles were too salty today. And the basic service is not good.
# model result: Negative
# answer: 0
#
# =============================== Input 94 ===============================
# It's good. But it's not the Pyeongyang naengmyeon that we know. It's also salty
# model result: Positive
# answer: 1
#
# =============================== Input 95 ===============================
# It's delicious
# model result: Positive
# answer: 1
#
# =============================== Input 96 ===============================
# Bulgogi Cold Noodles with Mung Bean Pancake is delicious But between seats. The spacing and table are too narrow and small. I ate it uncomfortable compared to the expensive house. I don't think it's a comfortable atmosphere to eat
# model result: Positive
# answer: 1
#
# =============================== Input 97 ===============================
# It's so delicious
# model result: Positive
# answer: 1
#
# =============================== Input 98 ===============================
# I ate Pyeongyang naengmyeon, and the broth was too salty and the garnish was dry. Gangnam is so bad compared to Pyeongnaengmyeon
# model result: Negative
# answer: 0
#
# =============================== Input 99 ===============================
# Eobok Tray, good!! Naengmyeon-sari is good, too!!
# model result: Positive
# answer: 1
#
# =============================== Input 100 ===============================
# I really enjoyed the food. Do valet, too. But the person serving is the worst. Which one is double serving? When I asked, the serving staff said, "I'll know when I see it!" I feel terrible because I went to eat cold noodles for lunch on the weekend. I really like Pyeongnaengmyeon, but I don't revisit it no matter how good it is.
# model result: Positive
# answer: 1
#
# =============================== Input 101 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 102 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 103 ===============================
# I packed the fish cake tray and ate it, and it was good. My parents enjoyed the meal! It's a bit expensive, but it's taken out. Very nice to eat at home :)
# model result: Positive
# answer: 1
#
# =============================== Input 104 ===============================
# It's good!
# model result: Positive
# answer: 1
#
# =============================== Input 105 ===============================
# Pyeongyang naengmyeon is delicious
# model result: Positive
# answer: 1
#
# =============================== Input 106 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 107 ===============================
# A steamed bun restaurant. Eobok Tray is so good
# model result: Positive
# answer: 1
#
# =============================== Input 108 ===============================
# It's delicious, but the price has gone up
# model result: Positive
# answer: 1
#
# =============================== Input 109 ===============================
# Eobok Tray's soup is clean and delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 110 ===============================
# I ate mulnaengmyeon and binaengmyeon, but mulnaengmyeon tastes better.. The kimchi is clean and the kimchi soup and pickles are delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 111 ===============================
# It's delicious, kimchi is made in Korea^^
# model result: Positive
# answer: 1
#
# =============================== Input 112 ===============================
# I go there often because it's good. It's good
# model result: Positive
# answer: 1
#
# =============================== Input 113 ===============================
# Pyeongyang-style cold noodles, Eobok tray, dumpling hot pot, bulgogi, mung bean paste stew are a little expensive, but they are all delicious.
# model result: Positive
# answer: 1
# =============================== Input 114 ===============================
# Three times in a weekThere's a lot of onban and it's so good My family doesn't have a lot, so if you buy one, your family will eat it Hahaha
# model result: Positive
# answer: 1
#
# =============================== Input 115 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 116 ===============================
# The restaurant that always eats deliciously
# model result: Positive
# answer: 1
#
# =============================== Input 117 ===============================
# Dumpling hot pot, fish cake tray, and cold noodles
# model result: Positive
# answer: 1
#
# =============================== Input 118 ===============================
# I went to eat dumpling hot pot and it was really good.. The three of us ordered two servings of hot pot and mung bean pancake, but the amount of hot pot was large, so we ate it full.. I think the meat in dumpling hot pot is good and the soup is clean, so I think I'll go eat it often
# model result: Positive
# answer: 1
#
# =============================== Input 119 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 120 ===============================
# I like the taste of beef on the taste. It's better than Yeouido evaluation house
# model result: Positive
# answer: 1
#
# =============================== Input 121 ===============================
# It is delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 122 ===============================
# It's more delicious because it's the main store
# model result: Positive
# answer: 1
#
# =============================== Input 123 ===============================
# The taste that comes to mind when it rains! I like it more because I'm hesitant. There are two kinds of beef and native chicken, but I only eat native chicken every time. Is it delicious because the chicken is chewy? A bowl of hot rice contains one dumpling, one pancake, chicken, mushrooms, vegetables, and glass noodles. If there are two adult men here, I think you need to order mung bean pancake to get full.. There are a lot of regulars and usually a lot of people come, so the difficulty of eating alone is a little high. (But it's
# model result: Positive
# answer: 1
#
# =============================== Input 124 ===============================
# It's really good! It's been a while since I visited, but it still tastes the same as before :)
# model result: Positive
# answer: 1
#
# =============================== Input 125 ===============================
# Thank you for the Pyeongyang Cold Noodles
# model result: Positive
# answer: 1
#
# =============================== Input 126 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 127 ===============================
# I ate Pyeongyang naengmyeon, dumpling hot pot, and Pyeonyuk. It is delicious.
# model result: Positive
# answer: 1
#
# =============================== Input 128 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 129 ===============================
# A restaurant that never changes with its taste
# model result: Positive
# answer: 1
#
# =============================== Input 130 ===============================
# Eobok Tray is good
# model result: Positive
# answer: 1
#
# =============================== Input 131 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 132 ===============================
# It's a bit salty, but it's okay to eat
# model result: Negative
# answer: 1
#
# =============================== Input 133 ===============================
# The boss was really annoyed and took the order, paid, and responded, so I took my parents with me. The food was delicious, but the service couldn't keep up with the quality Go when a friend you don't like buys you food LOL
# model result: Positive
# answer: 1
#
# =============================== Input 134 ===============================
# Pyeongyang naengmyeon mung bean pancake is the best
# model result: Positive
# answer: 1
#
# =============================== Input 135 ===============================
# It's good. It's good
# model result: Positive
# answer: 1
#
# =============================== Input 136 ===============================
# It's good.
# model result: Positive
# answer: 1
#
# =============================== Input 137 ===============================
# It's good! It's soft and nice
# model result: Positive
# answer: 1
#
# =============================== Input 138 ===============================
# Delicious and clean
# model result: Positive
# answer: 1
#
# =============================== Input 139 ===============================
# Pyeongnaengmyeon is the best here!!It's a great deal, too! This place tastes better than other places!
# model result: Positive
# answer: 1
#
# =============================== Input 140 ===============================
# Pyeongyang naengmyeon is so good^^
# model result: Positive
# answer: 1
#
# =============================== Input 141 ===============================
# Thank you for the delicious meal! It's a bit expensive, so I don't think I can come often Haha
# model result: Positive
# answer: 1
#
# =============================== Input 142 ===============================
# Pyeongyang naengmyeon doesn't seem to suit my taste.ㅠ
# model result: Negative
# answer: 0
#
# =============================== Input 143 ===============================
# It's delicious. Thank you for the food
# model result: Positive
# answer: 1
#
# =============================== Input 144 ===============================
# #Green onion pancake. #Beefyukgaejang. It's so good. #It's cheap, too.
# model result: Positive
# answer: 1
#
# =============================== Input 145 ===============================
# It was my first time eating Pyeongyang naengmyeon, and it was really good to my taste!! There's also mung bean pancake. It's really big and deliciousI want to go eat againDragon
# model result: Positive
# answer: 1
#
# =============================== Input 146 ===============================
# The food here is good
# model result: Positive
# answer: 1
#
# =============================== Input 147 ===============================
# The taste of North Korea. It's a little expensive, but it's a lot. Dumplings are full and full enough.
# model result: Positive
# answer: 1
#
# =============================== Input 148 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 149 ===============================
# It's delicious. Pyeongyang naengmyeon is the best
# model result: Positive
# answer: 1
#
# =============================== Input 150 ===============================
# It's delicious
# model result: Positive
# answer: 1
#
# =============================== Input 151 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 152 ===============================
# It's good
# model result: Positive
# answer: 1
#
# =============================== Input 153 ===============================
# A restaurant that makes you fall in love with Pyeongyang naengmyeon
# model result: Positive
# answer: 1
#
# =============================== Input 154 ===============================
# I was disappointed with Pyeongyang naengmyeon was disappointing ㅜ
# model result: Negative
# answer: 0
#
# =============================== Input 155 ===============================
# The light taste is excellent. I enjoyed eating with my family. I strongly recommend it
# model result: Positive
# answer: 1
#
# =============================== Input 156 ===============================
# It's good, but the price is too much
# model result: Positive
# answer: 1
#
# test accuracy: 0.9615
# Positive ratio: 0.9038
# Negative ratio: 0.0962

# %%
#naver3 data 테스트

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/mongryen_food.csv'
df = pd.read_csv(test_url,sep=',', header=0)
df.head(5)
# Out:
#    id category                                               text  \
# 0   0    taste  특수부위 아주 맛있어요! 보기에는 고기가 두툼해서 질길것 같은데 정말 부드럽고 살살...
# 1   1    taste  두번째 방문이예요 여전히 부드럽고 맛있는고기 만족입니다 :) 치즈듬뿍올린 볶음밥도 ...
# 2   2    taste  고기 찌개 밥 다 맛있었던 성수 맛집 몽련 !! \n가게도 깔끔하고 넓어서 회식이나...
# 3   3    taste  도끼살 진짜 맛있어요!!! 통벌집맥주 달달하니 계속 들어가요ㅜㅠ 특별한날 가기도 좋...
# 4   4    taste                        정갈한 반찬과 깨끗한 매장… 고기맛도 좋아요~~!
#
#                                           trans_text
# 0  Special parts are very delicious! The meat loo...
# 1  This is my second visit I'm still satisfied wi...
# 2  Mongryeon, a restaurant in Seongsu that had de...
# 3  The ax meat is really good!!! It's so sweet th...
# 4  Neat side dishes and clean stores... I like th...

# %%
df_new=df
df_new['length'] = df['trans_text'].apply(len)
df_new.length.describe()
# Out:
# count    769.000000
# mean     142.699610
# std      156.812145
# min        9.000000
# 25%       46.000000
# 50%       96.000000
# 75%      176.000000
# max      964.000000
# Name: length, dtype: float64

# %%
# naver data에 대한 분류
count=0

negNum=0
posNum=0

test_text = df.trans_text.values

for i in range(len(test_text)):
    t = df.iloc[i].trans_text
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        negNum+=1
    else:
        posNum+=1

    print("=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction)
    print("")


print("Positive ratio: {:.4f}".format(posNum/len(test_text)))
print("Negative ratio: {:.4f}".format(negNum/len(test_text)))
# Out:
# =============================== Input 1 ===============================
# Special parts are very delicious! The meat looks thick and tough, but it melts really soft and softly A total twist!! Doenjang jjigae is really good and there's no need for words if you wrap it with seasoned scallions and kimchi! The smoke escapes easily, so you can enjoy the meat without any inconvenience! Good
# model result: Positive
#
# =============================== Input 2 ===============================
# This is my second visit I'm still satisfied with the soft and delicious meat :) I also enjoyed the fried rice with a lot of cheese!
# model result: Positive
#
# =============================== Input 3 ===============================
# Mongryeon, a restaurant in Seongsu that had delicious meat stew and rice! The restaurant is clean and spacious, so it's good for company dinners and gatherings ??
# model result: Positive
#
# =============================== Input 4 ===============================
# The ax meat is really good!!! It's so sweet that it keeps going inI think it would be good to go on a special day or have a company dinnerI, I
# model result: Positive
#
# =============================== Input 5 ===============================
# Neat side dishes and clean stores... I like the taste of meat, too!
# model result: Positive
#
# =============================== Input 6 ===============================
# The meat tasted good and the doenjang-jjigae was good
# model result: Positive
#
# =============================== Input 7 ===============================
# Taste the meat and admire the charcoal smell. The side dishes are clean and luxurious!
# model result: Positive
#
# =============================== Input 8 ===============================
# I made a reservation and it was so delicious because they gave me a lot of food. I can feel the quality of the meat! It was so good I think I'll go to Da again for a team dinner!
# model result: Positive
#
# =============================== Input 9 ===============================
# Let me tell you the results first, but I was so unpleasant that I didn't want to go again, maybe because I had high expectations. From the time I inquired on the wire, the lady's chilly attitude was enough to be unpleasant, but after arriving, she did not accept the order for a long time, saying that she was busy responding to the table. But I thought everything would be offset if the food was delicious, but he was also mistaken. The taste of the food was okay, and the response of the server was not good.. If you're this busy, shouldn't you at least limit the number of customers or hire more servers.. Even if you leave a review like this, you will go, but I leave a review in the hope that you will think about it at least once when someone tries to visit this place.
# model result: Negative
#
# =============================== Input 10 ===============================
# The part-timer came up to me and smiled and said, "I don't know because it's only been two days, so I don't know, so I felt like you should do it on your own." I could understand that Restaurants, especially meat restaurants, were very disappointing compared to the price of meat. Beef tartare costs 35,000 won. I don't think you should sell it to consumers But I still enjoyed the cold noodles with water and spicy noodles
# model result: Positive
#
# =============================== Input 11 ===============================
# I made a reservation and it was good because they prepared it well. The basic dishes as well as the taste of the meat were very satisfying and delicious It's not in the picture, but the naengmyeon is really goodㅜㅠㅠ
# model result: Positive
#
# =============================== Input 12 ===============================
# I ordered Jeju pork set, but it was just whatever... There were a lot of fat... I'm not sure if it's a good restaurant. Beef brisket doenjang-jjigae is spicy and delicious
# model result: Positive
#
# =============================== Input 13 ===============================
# The meat tasted good and the atmosphere was good ?. I'm satisfied except that the seat next to me was noisy ?
# model result: Positive
#
# =============================== Input 14 ===============================
# I was worried because the ax meat was limited, but I ate it deliciously. Makgeolli and fried rice were so good.
# model result: Positive
#
# =============================== Input 15 ===============================
# He's kind and the meat is good too
# model result: Positive
#
# =============================== Input 16 ===============================
# I made a reservation for 9 people in the evening and 8 people visited. I said I wouldn't use one seat because one person didn't come due to the 3/3/3 digit setting. A female employee who is the owner of the room said, "If you eat 450,000 won worth of room reservations or fail to make it, you will get 50,000 won." I said yes. When the group inquired about the bowl, they said they were sorry for the blunt answer that it was set over there. But on Naver, if you eat less than 300,000 won, you charge 30,000 won.. What's so frustrating that you're asking for a higher price and being so blunt  I ate more than 400,000 won. I guess this is how a famous restaurant with delicious meat treats customers. The meat was delicious and kind, so I visited it sometimes, but it doesn't seem like it anymore. I don't know about the next visit.
# model result: Negative
#
# =============================== Input 17 ===============================
# The meat is good. It's a good place to eat while talking :)
# model result: Positive
#
# =============================== Input 18 ===============================
# I enjoyed a meal with pork rice and pork rice soup.
# model result: Positive
#
# =============================== Input 19 ===============================
# As a famous restaurant in Seongdong-gu, the ax meat, also called Don Mahawk, is so good. The atmosphere is good for drinking and red ginseng draft beer is so good. It's Mongryeon to eat a lot in Seongsu-dong.
# model result: Positive
#
# =============================== Input 20 ===============================
# I ate it in the room, and the axe meat, beef tartare, pork belly, herring roe fried rice, mul naengmyeon honey makgeolli, and beer were delicious. On the other hand, bibim naengmyeon is too sweet... The sirloin was just for the price... ★ Corkage 20,000 won & If you don't get a certain amount, you can charge a room!
# model result: Positive
#
# =============================== Input 21 ===============================
# The store is clean, the staff is kind, and the meat is delicious. It is especially good for women because the smell does not remain on their clothes.
# model result: Positive
#
# =============================== Input 22 ===============================
# It's a lot and high quality. I ordered ax meat and lamb. We were so full. Personally, the lamb was so good Haha. The servers are all kind and the side dishes and side dishes are of good quality.. Willing to visit again when Seongsu comes!!
# model result: Positive
#
# =============================== Input 23 ===============================
# The meat is fresh and delicious! It takes some time because it's pre-baked. I'm satisfied except for the coldness of the store!
# model result: Positive
#
# =============================== Input 24 ===============================
# I really enjoyed the meal. And the employees were so kind!
# model result: Positive
#
# =============================== Input 25 ===============================
# The meat is really good I took my friends, but I like Manu. It's good to make a reservation and eat without waiting
# model result: Positive
#
# =============================== Input 26 ===============================
# The meat is good.
# model result: Positive
#
# =============================== Input 27 ===============================
# It was delicious and there was a room on the 2nd floor
# model result: Positive
#
# =============================== Input 28 ===============================
# I think I go there often because it's delicious
# model result: Positive
#
# =============================== Input 29 ===============================
# Pork belly is so delicious I'm happy to see a lot of Chan
# model result: Positive
#
# =============================== Input 30 ===============================
# It was really delicious:). I had a 4-piece set and aged axe meat, and I want to go again next time!!!!!!!!
# model result: Positive
#
# =============================== Input 31 ===============================
# Thanks to you, I enjoyed the meal
# model result: Positive
#
# =============================== Input 32 ===============================
# Mongryeon axe is just love.. The moment you take a bite, you just smile.. The charcoal-flavored meat is a sincere thumbs-up.
# model result: Positive
#
# =============================== Input 33 ===============================
# You use really good meat ??. Of course, beef tastes savory and savory. It's amazing. Beef tartare is included in the beef set. Wow, it's a delicacy. It's with poached herring roe fried rice and soybean paste stew. It's good. Parking is available in the order of arrival. On the second floor, there's a space for company dinners and family dinners. It's okay. The female employee is really kind. They took good care of me
# model result: Positive
#
# =============================== Input 34 ===============================
# It tastes good, but the worker was so kind that I ate it happily! Thank you. Seongsu meat restaurant is definitely Mongryeon!!
# model result: Positive
#
# =============================== Input 35 ===============================
# We enjoyed the meal and had a great get-together!
# model result: Positive
#
# =============================== Input 36 ===============================
# The combination of ax meat and Yeontae Kaoliang liquor is really good. Mongryeon's other meat is delicious, but I come here to eat axe meat and Yeontae Kaoliang liquor. Of course, the amount of ax meat is small, but it's not an easy part to taste elsewhere, so make sure to!!Eat ax meat and add other meat. The beef brisket doenjang jjigae, raw vegetables, and fried rice are all delicious!!! Lamb is also on the menu, and the lamb is really soft, odorless, and delicious!! Lamb meat is also highly recommended!!
# model result: Positive
#
# =============================== Input 37 ===============================
# The interior is pretty and the meat is fresh and delicious! Especially, fried rice is the best, so you have to order it! Beef brisket doenjang jjigae is also delicious with lots of meat.. Last time I came here, I ate axe meat, but the axe meat and pork set are also delicious?????
# model result: Positive
#
# =============================== Input 38 ===============================
# I chose Mongryeon as a group of four couples. I'm satisfied.. I enjoyed the meat, ribs, and raw beef! I felt that the person who served was also very kind. ?.
# model result: Positive
#
# =============================== Input 39 ===============================
# Seongsu's Mongryeon selling really delicious pork. It's a really good restaurant. There's always a reason why it's a hot place. Axsal, a daily limited menu, is worth a signature. It looks thick and fatless like steak, but it boasts an incredibly soft texture. Perhaps the shoulder rack is such a delicious part, but the fat attached to some pieces is also one of the charms of axe meat. I don't know why the free stew is so delicious. There's meat in it, so I wonder if I can eat this for free. Another strength of Mongryeon is dessert. Binaeng is 7,000 won, which feels a little expensive for dessert, but if you take a bite of it, you can eat it happily, let alone think of money. The herring roe fried rice was enough to decorate with a finale. It won't be easy to find a place to have a more perfect dinner.
# model result: Positive
#
# =============================== Input 40 ===============================
# Tteokbokki place
# model result: Positive
#
# =============================== Input 41 ===============================
# The food is delicious and the staff are kind. We had a great meeting.
# model result: Positive
# =============================== Input 42 ===============================
# It's a limited sale of 20 ax meat a day, but I was lucky to taste it! It was delicious ???. The beef brisket doenjang jjigae was also good for free! And make sure to eat herring roe fried rice~~~? So delicious
# model result: Positive
#
# =============================== Input 43 ===============================
# I enjoyed the meal. I'll go again next time
# model result: Positive
#
# =============================== Input 44 ===============================
# I'm not that kind, but it's delicious and okay
# model result: Positive
#
# =============================== Input 45 ===============================
# I went to a company dinner because it's a good lunch restaurant, and I'm satisfied with the
# model result: Positive
#
# =============================== Input 46 ===============================
# Delicious and kind. Lunch menu recommendation!
# model result: Positive
#
# =============================== Input 47 ===============================
# The meat was delicious. You don't have to worry about that part even if you go past 6 o'clock because there's ax meat. But the seats for three to four people on the second floor are not rooms, so it's very cold. You must have eaten only meat and couldn't eat.. So if you have less than 4 people, make a reservation on the first floor even if it's noisy and you're worried about Corona.
# model result: Positive
#
# =============================== Input 48 ===============================
# Delicious beef brisket doenjang, good
# model result: Positive
#
# =============================== Input 49 ===============================
# - I made a reservation for my family's birthday party in advance and visited! I couldn't get a room because there were 3 people, and I ate at the table on the 2nd floor, but there weren't many seats, so it was good because it wasn't noisy.. - We ordered Mongryeon axe + pork belly + tofu pork belly + herring roe fried rice, and the overall review is that pork belly and pork neck are more delicious than Mongryeon axe. I ate ax meat first and ordered pork belly meat later, but I regretted ordering this from the beginningExcept that the ax meat is unique, there are some tough parts, and the amount was too small, so it was less than I expected. If you take out the weight of the bone, the amount is too small. And I strongly recommend the herring roe fried rice! I can't explain what it tastes like, but it was my first time eating it, and 6,000 won was a bit expensive for fried rice, but it was very luxurious. Beef brisket doenjang jjigae is also good
# model result: Negative
#
# =============================== Input 50 ===============================
# The taste of the meat is easy, but the service is too unfriendly. I have to tell him how many times to bring me food and when he asks for a refill, he glares at me in a bad mood. I asked for some sauce, but he didn't say anything and left.
# model result: Negative
#
# =============================== Input 51 ===============================
# It was so good!! The meat was soft and two side dishes were delicious!
# model result: Positive
#
# =============================== Input 52 ===============================
# Pork belly, pork neck, and ax meat are good Beer is unique because it has honeycomb, and there are many types of alcohol, so it's good for a company dinner
# model result: Positive
#
# =============================== Input 53 ===============================
# The shoulder fat was special. a neat and trendy restaurant.
# model result: Positive
#
# =============================== Input 54 ===============================
# The meat is good, but it's too loud. It's not like I'm going to stay for a long time, but I just ate
# model result: Positive
#
# =============================== Input 55 ===============================
# I'm eating, so I don't have any pictures of meat It's good because wine cologie is free and the meat is delicious. It's a shame that I have to grill the meat myself and I can't park
# model result: Positive
#
# =============================== Input 56 ===============================
# Each and every menu was delicious?? But I don't think we need to order beer and makgeolli at a beehive
# model result: Positive
#
# =============================== Input 57 ===============================
# You can use it comfortably because you made a reservation. There were various side dishes and I enjoyed the meal.
# model result: Positive
#
# =============================== Input 58 ===============================
# It's really good here.. I waited a little bit at 6 o'clock and went in, and it tasted like charcoal and.. I'll just pass on the meat with Yeontae.. Beef brisket doenjang jjigae makes you want to eat rice, salted squid, and cold noodles
# model result: Positive
#
# =============================== Input 59 ===============================
# You ate deliciously with special people on a special day
# model result: Positive
#
# =============================== Input 60 ===============================
# I think stews are delicious in this restaurant!
# model result: Positive
#
# =============================== Input 61 ===============================
# It's good. The atmosphere is good, too
# model result: Positive
#
# =============================== Input 62 ===============================
# Always delicious pork. I strongly recommend Don Mahawk and backside. But the service of the workers is so curt and annoying
# model result: Positive
#
# =============================== Input 63 ===============================
# The atmosphere was good and the food was delicious! I highly recommend Mongryeon where you could taste Jeju meat!
# model result: Positive
#
# =============================== Input 64 ===============================
# Jeju pork belly was so good! The owner is kind and the meat is fresh and delicious!
# model result: Positive
#
# =============================== Input 65 ===============================
# I always wanted to go there, but I ate well for the company dinner.. It was unfortunate that the business hours were short, but everything was delicious.
# model result: Positive
#
# =============================== Input 66 ===============================
# It's really delicious and there's no shortage of gatherings. The staff is very kind
# model result: Positive
#
# =============================== Input 67 ===============================
# I ate lamb and pork neck, and it's delicious! Next time, I want to make a reservation in advance and eat Mongryeon Axe! ??
# model result: Positive
#
# =============================== Input 68 ===============================
# I made a reservation in advance. I enjoyed the meal
# model result: Positive
#
# =============================== Input 69 ===============================
# The meat is delicious
# model result: Positive
#
# =============================== Input 70 ===============================
# Thank you for the food
# model result: Positive
#
# =============================== Input 71 ===============================
# I think it was delicious. I think the performance was fun because they prepared the big meat in front of me
# model result: Positive
#
# =============================== Input 72 ===============================
# The price is not good.. However, the meat quality is excellent.. The signature menus here are special and delicious. I recommend it.
# model result: Positive
#
# =============================== Input 73 ===============================
# Meat is good, but fried rice and soybean paste are really good, too
# model result: Positive
#
# =============================== Input 74 ===============================
# I keep coming because it's delicious. I like the lunch menu
# model result: Positive
#
# =============================== Input 75 ===============================
# Doenjang-jjigae recommendation
# model result: Positive
#
# =============================== Input 76 ===============================
# I went to the meeting, and it was kind and delicious! Go for the ax meat ?
# model result: Positive
#
# =============================== Input 77 ===============================
# You have to eat ax meat from a meat restaurant
# model result: Negative
#
# =============================== Input 78 ===============================
# It's still good even though it's been a while since I went
# model result: Positive
#
# =============================== Input 79 ===============================
# Rice with pork is spicy and spicy
# model result: Positive
#
# =============================== Input 80 ===============================
# I think it was the most delicious pork I've ever had! I want to go again next time!
# model result: Positive
#
# =============================== Input 81 ===============================
# The meat is good
# model result: Positive
#
# =============================== Input 82 ===============================
# The atmosphere is good and it's delicious
# model result: Positive
#
# =============================== Input 83 ===============================
# Thank you for your kindness in changing to a better place than the reserved room. The kindness of the staff was also so good that the satisfaction of the companions was the best. However, raw beef seems to be a little less delicious. Thank you so much
# model result: Positive
#
# =============================== Input 84 ===============================
# It's so delicious
# model result: Positive
#
# =============================== Input 85 ===============================
# I agree that it's a good restaurant. Awesome. But the amount is evil
# model result: Positive
#
# =============================== Input 86 ===============================
# I made a reservation because I wanted to buy delicious meat for the staff. The group seats were separated from the hall, so it was private and the service was excellent. Axe meat and pork belly are both popular, so I ate a lot^^*. Beef tartare was also delicious, so I emptied four plates. They also cut the meat sashimi. Fresh meat slaughtered on the day was the best! I think I'll come to Mongryeon again at the next get-together!
# model result: Positive
#
# =============================== Input 87 ===============================
# Honestly, the food is good and the staff is kind! Make sure to eat doenjang jjigae and fried rice twice. But if it's this much, other restaurants can cook it for you... It's uncomfortable to grill and eat..crying.
# model result: Positive
#
# =============================== Input 88 ===============================
# It's delicious :)
# model result: Positive
#
# =============================== Input 89 ===============================
# It's delicious!
# model result: Positive
#
# =============================== Input 90 ===============================
# The meat is really good, too
# model result: Positive
#
# =============================== Input 91 ===============================
# I recommend it as a lunch restaurant for office workers. There is a lot of beef brisket doenjang and it's delicious, and it's easy to eat because it's served as a table for each person. Plus, the store is big, so it rotates well
# model result: Positive
#
# =============================== Input 92 ===============================
# It's good
# model result: Positive
#
# =============================== Input 93 ===============================
# Axe meat was really good and the pork neck was also good.
# model result: Positive
#
# =============================== Input 94 ===============================
# Corky free. Kindness, side dishes, meat, and fried rice are all delicious?
# model result: Positive
#
# =============================== Input 95 ===============================
# The ax meat is really good. Pork belly is also delicious because it's from Jeju. I like it because it's neat and the window seat on the second floor is quiet. Your parents like it, too.
# model result: Positive
#
# =============================== Input 96 ===============================
# It's a place I go often because the meat tastes good. Axsal, the signature menu, is also delicious, and it is a good restaurant for lamb ribs..
# model result: Positive
#
# =============================== Input 97 ===============================
# I made a reservation on the second floor at 5 p.m. and arrived at around 5:05.. When I arrived, they confirmed me to go up, and when I went up, a man with an apron is lying in the middle of the table on the second floor with a floor mat.. He just got up and seemed to be clearing up, and he told us to wait a minute.. It's past break time, but it didn't look very good.. The taste of the meat was good, but the overall atmosphere and environment were not good.
# model result: Negative
#
# =============================== Input 98 ===============================
# It's delicious!!!
# model result: Positive
#
# =============================== Input 99 ===============================
# At first, I thought they wouldn't grill meat at this price, but after eating a piece of meat, um!! It's delicious ??????? It's full and delicious even though it's a doenjang stew service. Fried rice with herring roe is also delicious. But soju is 5,000 won and beer is 6,000 won. It's expensive, but if I go around because it's delicious, I'm thinking about going there
# model result: Positive
#
# =============================== Input 100 ===============================
# It's good
# model result: Positive
#
# =============================== Input 101 ===============================
# The serving staff were kind, the menu was delicious, and it was a pleasant dinner :)
# model result: Positive
#
# =============================== Input 102 ===============================
# Bad service! The food came out after the colleagues who went to eat with us finished eating. You said it's because there are so many people who ordered cold noodles today without showing any signs of apology.. I tried to understand, but I couldn't We're going to eat the 3rd table, and the people who came afterwards are eating naengmyeon... Was it because there were so many people who ordered naengmyeon. And how many times did I say that our food hasn't come out yet.. I was impressed by the brazenness of not remembering what food I ordered and lying that it was coming out soon and not saying sorry for coming out late. It was cold, but it was lukewarm.. I really want to decline unkindness
# model result: Negative
#
# =============================== Input 103 ===============================
# The ax meat is so good. The stew is good, too!! I'm willing to revisit next time and the side dishes are also very delicious. However, I was sorry that the server in charge was a little unfriendly because he was too busy.
# model result: Positive
#
# =============================== Input 104 ===============================
# The store is large and the food is so delicious :)
# model result: Positive
#
# =============================== Input 105 ===============================
# It's good
# model result: Positive
#
# =============================== Input 106 ===============================
# It's delicious!!! ^_^
# model result: Positive
#
# =============================== Input 107 ===============================
# It's a bit pricey, but it's delicious and kind
# model result: Positive
#
# =============================== Input 108 ===============================
# Fire is the life of meat, but charcoal was too weak... No matter how many times I asked you again, nothing much changed. That's too bad.
# model result: Negative
#
# =============================== Input 109 ===============================
# Fried rice was delicious
# model result: Positive
# =============================== Input 110 ===============================
# I enjoyed the signature ax meat! The cost-effectiveness was a bit burdensome to say it was good, and I hope you can proportionalize the order for the Cozy Free.. However, I reserved a seat for three to four people on the second floor, but there was no explanation why they gave me a seat on the first floor! It was a bit disappointing even though I made a reservation a long time ago.
# model result: Positive
#
# =============================== Input 111 ===============================
# Pork is so furry I thought it was hair at first, but it looked like pig hair because it came out more than five or six.. But it wasn't a pleasant experience It's been a while since I went there, but the taste has changed a lot In particular, naengmyeon used to be an excellent taste among those eaten in Seoul, but now it comes out as just a red chili-pepper paste sauce.. I was looking forward to the taste of the past, but it's a shame that it became a completely different menu (to the point where I wonder if the boss has changed)..
# model result: Negative
#
# =============================== Input 112 ===============================
# It was good not to wait because I made a reservation and visited. The meat tasted really good, but the fire was weak, so it took a little longer to ask for more charcoal... Even if I told you about the side dishes, you kept forgetting and didn't come, so the taste and cleanliness were good
# model result: Negative
#
# =============================== Input 113 ===============================
# The food is delicious. As soon as I opened the door, he said he would call me if I went out without asking. So I said I made a reservation, and they told me to come in.. It's so chaotic that he doesn't come even if I ring the bell several times. I had to wait for more than 10 minutes for the additional food, and it was too hot even considering that the seats were not good or there was a fire..
# model result: Negative
#
# =============================== Input 114 ===============================
# Two of us ate a 4-piece set, but there was no left[Laughing]I thought it would be a lot, but it wasn't as much as I thought. I don't think there's much because it's delicious. I really drank meat and fried rice. Good, good
# model result: Positive
#
# =============================== Input 115 ===============================
# Not only is it delicious, but the staff are also very kind!!
# model result: Positive
#
# =============================== Input 116 ===============================
# The food is delicious, but the kindness is insufficient, and the service is poor.. For example, when I asked for some tzuran, they said they would give me lamb only if I ordered it. I understand if Tzuran is expensive, but I don't know if it's a lack of understanding of the service... And, it's too loud to be a quiet place to eat
# model result: Negative
#
# =============================== Input 117 ===============================
# The meat tasted good, but it was too hot on the second floor…
# model result: Positive
#
# =============================== Input 118 ===============================
# Honey makgeolli is delicious.
# model result: Positive
#
# =============================== Input 119 ===============================
# The boss is unkind and I suspect cleanliness. It's just water, but it's the same even if a piece of tissue floats in the water and changes it. The meat tasted good, but it wasn't a pleasant meal
# model result: Negative
#
# =============================== Input 120 ===============================
# It's a restaurant that satisfies the atmosphere, location, and taste! . It's been a long time since I found a house that I liked! . The staff is very kind, too!
# model result: Positive
#
# =============================== Input 121 ===============================
# I really enjoyed the meal.
# model result: Positive
#
# =============================== Input 122 ===============================
# Make sure to eat the ax meat pork belly. The guide or the female employee is not kind. Sometimes, it's a good thing. Pork goes to this place
# model result: Positive
#
# =============================== Input 123 ===============================
# Axsal, the signature menu here, is delicious. It's perfect for taking pictures and uploading them. I think I'll go there often
# model result: Positive
#
# =============================== Input 124 ===============================
# It's good
# model result: Positive
#
# =============================== Input 125 ===============================
# Lunch menu is good The cost-effectiveness is also good. I ate meat for dinner. The meat is good, too ~ .
# model result: Positive
#
# =============================== Input 126 ===============================
# I really enjoyed the meat. I made a reservation for nine people for lunch and even received a confirmation message, but it was uncomfortable to have a meal with one person in the middle of the two tables saying there was no reservation on the day, and I don't think it was a pleasant meal because there was no apology for the omission.
# model result: Positive
#
# =============================== Input 127 ===============================
# Thank you for the meat! I'll come back next time~~ The atmosphere is nice. However, if it was a part-time job or a female employee, I wish she was a little nicer
# model result: Positive
#
# =============================== Input 128 ===============================
# Meat is delicious, honey beer, and herring roe fried rice are unique and delicious!
# model result: Positive
#
# =============================== Input 129 ===============================
# The meat is fresh and delicious like hot place..
# model result: Positive
#
# =============================== Input 130 ===============================
# The food was delicious. The staff seemed to be busy even during lunchtime on weekdays.. It was my first visit, so I ordered it based on the amount shown on the menu, but I was embarrassed because they noticed that it was a small amount. If it's not enough, it's natural to order additional, but from the perspective of an employee who knows the amount well, I know I want to tell you, but it's my first time seeing it. I felt a little less if the signature menu included bone weight
# model result: Positive
#
# =============================== Input 131 ===============================
# I think it's one of the few meat restaurants with good atmosphere and parking in Seongsu. However, I felt that the table was a little small. Meat is good. I also like flying fish roe bibimbap
# model result: Positive
#
# =============================== Input 132 ===============================
# The atmosphere is good and the meat is good. Side dishes are good, too
# model result: Positive
#
# =============================== Input 133 ===============================
# It's delicious :)
# model result: Positive
#
# =============================== Input 134 ===============================
# I went to eat alone late lunch at around 2 o'clock, and they told me to sit alone among the customers who eat meat without any sense..  When I asked for water, they asked me to drink water from the water bottle that the customer was drinking. I was like, "I'll never come back again". Why is the kimchi stew so good.. -.- . It's cost-effective and delicious!
# model result: Positive
#
# =============================== Input 135 ===============================
# I visited on Saturday. It's been a while since I met my acquaintances, so I recommended it and went to Mongryeon, but I heard that it was delicious but the service was not good. It was a busy time on Saturday, but the clerk was only there for two minutes. I understand you're busy, but.. The serving woman spilled cold noodle broth and asked if it splattered on her clothes without apologizing.. It's a pity that a restaurant with a good impression has become a restaurant with a bad impression for me due to its service.
# model result: Positive
#
# =============================== Input 136 ===============================
# I had a family gathering for my father's birthday and it was very nice.. I made a reservation for a room and ate comfortably.  The meat is also very delicious.
# model result: Positive
#
# =============================== Input 137 ===============================
# It's good.
# model result: Positive
#
# =============================== Input 138 ===============================
# It's good. Thank you for the food^^
# model result: Positive
#
# =============================== Input 139 ===============================
# I went to entertain guests, but the waiter was so ticklish that they couldn't communicate with each other even if they ordered more meat, and someone else came and told me to order more. But the taste of meat isn't good. The advantage is that the space is big.
# model result: Negative
#
# =============================== Input 140 ===============================
# It's good!
# model result: Positive
#
# =============================== Input 141 ===============================
# The food is very neat, delicious, and the staff is very kind.. However, the room on the second floor is right in front of the bathroom, there is no entrance, and there is no heating, but it was the first time that it was cold while grilling meat over charcoal. But the quality of the food was good, so I was generally satisfied.
# model result: Positive
#
# =============================== Input 142 ===============================
# It's delicious
# model result: Positive
# =============================== Input 143 ===============================
# It's my first time going there, so I made a reservation and ate comfortably. The store was busy, but the staff was kind, so it was good.. I enjoyed both beef and porkHah!
# model result: Positive
#
# =============================== Input 144 ===============================
# It's delicious and kind. It's spacious, so it's not crowded. It's comfortable
# model result: Positive
#
# =============================== Input 145 ===============================
# It's neat and delicious!
# model result: Positive
#
# =============================== Input 146 ===============================
# Each type of meat is unique and delicious??
# model result: Positive
#
# =============================== Input 147 ===============================
# a clean and refreshing taste
# model result: Positive
#
# =============================== Input 148 ===============================
# It was delicious! It's good for a group gathering!
# model result: Positive
#
# =============================== Input 149 ===============================
# It was so good. I'll come back next time^^
# model result: Positive
#
# =============================== Input 150 ===============================
# I ordered a set, but the meat is good. It has a lot of meat and it's delicious to call it a free stew.. I ordered poached egg fried rice, but fried rice is also delicious.. The disappointing thing is that the staff is blunt. I poured water into the water bottle and there were three red pepper flakes in the water Other than that, I'm satisfied. You can park, and the bathroom is clean
# model result: Positive
#
# =============================== Input 151 ===============================
# The rice was wet because the eggs were raw But the meat is still good
# model result: Positive
#
# =============================== Input 152 ===============================
# They kindly explain the menu. Above all, the meat is really good. Please try the signature menu
# model result: Positive
#
# =============================== Input 153 ===============================
# It tastes good and the service is so good. I'm willing to revisit it
# model result: Positive
#
# =============================== Input 154 ===============================
# It's been a while since I had delicious meat^^
# model result: Positive
#
# =============================== Input 155 ===============================
# It's clean and the meat is so delicious and nice. The staff is a little unfriendly~~;; The chair was shaking. Even if a customer sits down and breaks the chair. The employee looked at me once and didn't take any action. In the end, the customer just changed the chair...
# model result: Positive
#
# =============================== Input 156 ===============================
# I enjoyed the food and the female employee on the 2nd floor was so kind Except for the cold weather, it was good. It was cold even though the heater was on
# model result: Positive
#
# =============================== Input 157 ===============================
# It tastes good, but the amount of meat is too small for the price and the menu is coated with oilㅜ
# model result: Negative
#
# =============================== Input 158 ===============================
# It's good
# model result: Positive
#
# =============================== Input 159 ===============================
# It's good
# model result: Positive
#
# =============================== Input 160 ===============================
# Grilled pork belly on charcoal is so delicious. The doenjang-jjigae that they give as a free meal is the best!
# model result: Positive
#
# =============================== Input 161 ===============================
# From meat to naengmyeon to fried rice, everything was delicious! When I go to a meat restaurant, I always make stew, but it's served on the house, so it's more wet The taste of meat, cheddar, and at the end, my boyfriend is opening the meat, but I want to visit again and eat it with beer or highball!
# model result: Positive
#
# =============================== Input 162 ===============================
# It's delicious and kind
# model result: Positive
#
# =============================== Input 163 ===============================
# We ate pork belly fried rice with ax meat. It was delicious because it was soft and tender Laughing!)!
# model result: Positive
#
# =============================== Input 164 ===============================
# It's my first time eating meat on the weekend after lunch. I don't recommend you to go in the winter.. It's very, very cold.. My feet are cold and my hands are cold.. If the heater breaks down, you can buy one.. There are many places that grill pork in Seongsu-dong. It's not even that here.. Even on weekends, there are almost no servers.. They didn't call the staff because they thought there would be no customers. Then, I recommend that you receive as many customers as the number of employees.. Side dishes are okay. The meat was just so.. I live in Seongsu-dong, but I don't think I'll revisit
# model result: Negative
#
# =============================== Input 165 ===============================
# The food was delicious and the service was good
# model result: Positive
#
# =============================== Input 166 ===============================
# First of all, the staff seemed to be busy because there were many customers. So!! The service is not good!! . Pork neck was more delicious than axe meat.. It's worth eating once, but I don't think it's enough to find it and want to eat it. Personally, I recommend pork neck.. Doenjang stew and fried rice were delicious, so I ordered doenjang stew twice. The seasoning was just right
# model result: Positive
#
# =============================== Input 167 ===============================
# I love the meat
# model result: Positive
#
# =============================== Input 168 ===============================
# I really enjoyed the meal.
# model result: Positive
#
# =============================== Input 169 ===============================
# I asked if I could make a reservation at 1 o'clock, but there was no answer, so I made a reservation at 2 o'clock and visited, but there were many seats. The store was colder than I thought, and they told me that I had to go out for break time from 3 o'clock, so I think I ate meat because I ate it too fast... It was uncomfortable. The meat was okay, but the beef brisket soybean paste was better than the meat, and the signature honey beer was uncomfortable to drink because it had foreign substances.
# model result: Negative
#
# =============================== Input 170 ===============================
# It's a place I go often. As expected, it's nice. Thank you for the food
# model result: Positive
#
# =============================== Input 171 ===============================
# Staff members were so kind and friendly like soldiers[Laughing] Thanks to you, we had a great time. Thank you
# model result: Positive
#
# =============================== Input 172 ===============================
# I haven't had an appetite lately, but it's a taste I want to let everyone know about. Thank you for the delicious food today, and always prosper!
# model result: Positive
#
# =============================== Input 173 ===============================
# It's good! The store is clean
# model result: Positive
#
# =============================== Input 174 ===============================
# It's kind and delicious, and it's good to finish coffee in a hot place. It's pork belly, which is meat, but it's delicious with a unique texture of axe meat!!! And yukhoe is a must.. Please give me a bottle of Coca Cola service next time. ♡
# model result: Positive
#
# =============================== Input 175 ===============================
# He ate the temple deliciously Axe meat is good It tastes so good with anchovy sauce
# model result: Positive
#
# =============================== Input 176 ===============================
# I strongly recommend the menu. Every time I go, I eat axe meat, lamb chops, and fried rice. It's very delicious. The staff are very kind, too-ㅡ
# model result: Positive
#
# =============================== Input 177 ===============================
# Wow, Jeju's ax meat is really good. It's relieving my stress!! . I've never had meat more delicious than Don Mahawk!! . The atmosphere is so nice that it would be perfect for a Seoul Forest date course. Make a reservation and visit. Definitely ax meat! The draft beer at the beehive is unique and delicious
# model result: Positive
#
# =============================== Input 178 ===============================
# The perfect meal for koshi soup! It's clean and not irritating. I'm relieved that it's a fresh ingredient. It was so deliciousThere's a lot
# model result: Positive
#
# =============================== Input 179 ===============================
# I ate fried rice with a small set and it was delicious
# model result: Positive
#
# =============================== Input 180 ===============================
# It's so good. I'll come back next time
# model result: Positive
#
# =============================== Input 181 ===============================
# They sell wine and special beer. I think it would be good to visit on a special day.. If you visit, please try it The meat is so soft Haha
# model result: Positive
#
# =============================== Input 182 ===============================
# Even though I made a reservation with my friends, I waited for about 3 minutes, and it was delicious and friendly because I went there before. I ate meat deliciously and ordered fried rice at the end, but my friend and I asked if I could add more rice. I ordered fried rice because I wanted to eat rice again, but I said it was salty enough to need a spoonful of rice, but I didn't know you would respond like that..It was ridiculous. It's not because I don't have money, but the customers' tastes may be wrong, but the fried rice I ordered is salty and I asked for more rice, but I couldn't get cut off. I looked at other customers with that expression. It was so embarrassing. It felt dirty in the sky while eating happily  I don't think I'll ever go again
# model result: Positive
#
# =============================== Input 183 ===============================
# It's very delicious because the meat is well aged well. There are a variety of alcohols. Honey beer is good lol I went to a year-end party in broad daylight with my close brothers and I was satisfied. Oh, the lady serving was sensible.
# model result: Positive
#
# =============================== Input 184 ===============================
# Tomahawk is delicious.. Side dishes are generally fine.
# model result: Positive
#
# =============================== Input 185 ===============================
# It's a great place to meet! Lamb chops are good, too~~
# model result: Positive
#
# =============================== Input 186 ===============================
# Axsal is really delicious like a signature menu! The meat is in good condition and the service is so kind, so please enjoy it Steamed regulars!!
# model result: Positive
#
# =============================== Input 187 ===============================
# The meat is good. It's a shame that the ax meat is sold out even though it's 6 o'clock. There are so many customers, but there are two employees in the hall, so it takes a long time to request something. I was sad that he didn't have axe fat, but he came in in the middle, but he didn't tell me either... I ordered extra meat. I'd like more people in the hall.
# ...
# model result: Positive
#
# =============================== Input 701 ===============================
# The atmosphere is good. The quality of the meat is good. Beef tartare and Jeju pork belly are good. The price includes some atmospheric value. Thank you for the beef brisket jangjigae ^^ I had a great time with my friends ~
# model result: Positive
#
# =============================== Input 702 ===============================
# It is delicious.
# model result: Positive
#
# =============================== Input 703 ===============================
# It was inconvenient because there was a lot of smoke in the corner, but they gave us more meat. It was delicious.
# model result: Positive
#
# =============================== Input 704 ===============================
# I was able to have a company dinner in a comfortable atmosphere.. The meat was delicious, the beer was delicious, and the fried rice was delicious. It was even better because the restaurant was clean and well ventilated. Thank you.
# model result: Positive
#
# =============================== Input 705 ===============================
# The meat is really good. The atmosphere was so nice because it didn't feel like a meat restaurant.
# model result: Positive
#
# =============================== Input 706 ===============================
# The atmosphere and taste were good.
# model result: Positive
#
# =============================== Input 707 ===============================
# The meat is so delicious. It was a get-together for 12 people..Room... It was quiet. It was good
# model result: Positive
#
# =============================== Input 708 ===============================
# Service. It was delicious :)
# model result: Positive
#
# =============================== Input 709 ===============================
# The atmosphere is good and the meat is so good!!! I'm willing to revisit!
# model result: Positive
#
# =============================== Input 710 ===============================
# It's delicious!!!
# model result: Positive
#
# =============================== Input 711 ===============================
# I came for a company dinner The ax meat was rumored to be delicious, so I ordered ax meat as soon as I sat down, and the separate seats were fine. When I ordered the second time, I asked to change the grill, and I spilled fish sauce on the grill in the middle, but he just left without saying sorry... Later, the person on the second floor got an apology, but throughout the company dinner, I felt like it came out too late if I ordered meat I don't know why.. The quality and taste of the meat were so good, but the expressions of the workers...Even when side dishes are placed on the table, it's set up within reach, so we just set it up and ate it...
# model result: Positive
#
# =============================== Input 712 ===============================
# The service was good and the food was delicious.
# model result: Positive
#
# =============================== Input 713 ===============================
# The signature menu was delicious.. I'll go again next time.
# model result: Positive
#
# =============================== Input 714 ===============================
# The best service guide, the best meat, everything is the best!! . The meat is basically all delicious, and soybean paste stew is for JMT
# model result: Positive
#
# =============================== Input 715 ===============================
# Axe meat tastes good. The pork set is small. It tastes like stew
# model result: Negative
#
# =============================== Input 716 ===============================
# It was delicious and the atmosphere was nice and kind... But I couldn't eat grilled cheese because I forgot that I was a reservation customer for NaverHe gave me a soda to say sorry instead..Haha
# model result: Positive
#
# =============================== Input 717 ===============================
# The atmosphere was good and the meat was delicious.. I just put the meat on top and don't grill it, so I have to grill it well on my own.. The table structure is too uncomfortable to share side dishes together. It's hard for the person sitting inside to eat because there's no choice but to put side dishes on one side.. Kindness is just so so so so. Serving people are kind, but the person who takes care of the first floor is not friendly. The guide is so unfriendly when I first go in and when I eat, so I won't go twice even if the meat is delicious.
# model result: Positive
#
# =============================== Input 718 ===============================
# Staff members are kind and the food tastes good b
# model result: Positive
#
# =============================== Input 719 ===============================
# I went to lunch and it was a little hard because of the bright sunlight, but the rest of the food was delicious and good.
# model result: Positive
#
# =============================== Input 720 ===============================
# It was really good. All the meat was exclaimed.
# model result: Positive
#
# =============================== Input 721 ===============================
# The customer service and signature menu were delicious.
# model result: Positive
# =============================== Input 722 ===============================
# It is neat and delicious.. I thought the view from the second floor would be good. It was a little disappointing that it was full of equipment and only the alley was visible.
# model result: Positive
#
# =============================== Input 723 ===============================
# The taste is the best. The atmosphere is the best
# model result: Positive
#
# =============================== Input 724 ===============================
# I booked a room 2 on the second floor, but it was good because there were two air conditioners and good ventilation. The reviews don't ventilate very well I was worried, but when I put up the air conditioner on the wall, it was good for ventilation. I ordered Mongryeon Doksal, Jeju-do pork belly, and fried rice, and it was very delicious.. It was bad that the order was skipped during the busy time, but the food was so delicious that I even forgot about it. Thank you for the delicious food!!
# model result: Positive
#
# =============================== Input 725 ===============================
# Beef brisket doenjang jjigae, not to mention meat, is so good!! It's a restaurant with the best atmosphere^^ I made another reservation for the Damju family gathering!!
# model result: Positive
#
# =============================== Input 726 ===============================
# The room on the second floor was spacious and nice. It's a bit pricey, but the meat tastes good. It's a clean place to eat on Ttukseom Island.
# model result: Positive
#
# =============================== Input 727 ===============================
# It was as neat as a restaurant.. I'm willing to revisit.. Overall, everything was delicious.
# model result: Positive
#
# =============================== Input 728 ===============================
# I enjoyed my meal. Hah!
# model result: Positive
#
# =============================== Input 729 ===============================
# The meat quality and atmosphere service were all the best. We went to the company team dinner, and everyone was satisfied.. I've tried all kinds of beef, including ax meat and pork belly. It's really good but I strongly recommended. But it was too bad that we only sell one per table. I will definitely visit again next time!!
# model result: Positive
#
# =============================== Input 730 ===============================
# How can it be this delicious when it's meat!  . The wine you reserved on Naver is good with meat, and Seongsu beer is good too^
# model result: Positive
#
# =============================== Input 731 ===============================
# The meat tasted good and the atmosphere was good  It takes a while for the smoke from the next table to come over, but I understand because it's a meat restaurant. I'm willing to revisit~~
# model result: Positive
#
# =============================== Input 732 ===============================
# I think the taste was normal. The atmosphere is personal
# model result: Positive
#
# =============================== Input 733 ===============================
# The taste of the meat, the atmosphere, and the staff were all great. After finishing the meat, I ate fried rice with herring roe. I like fried rice. I'm 200% willing to come back^^
# model result: Positive
#
# =============================== Input 734 ===============================
# Delicious and good service. It was a bit loud
# model result: Positive
#
# =============================== Input 735 ===============================
# I ate deliciously with my friends.
# model result: Positive
#
# =============================== Input 736 ===============================
# Very delicious. Very delicious
# model result: Positive
#
# =============================== Input 737 ===============================
# It's delicious. I'm 100% willing to revisit
# model result: Positive
#
# =============================== Input 738 ===============================
# The meat was good and the atmosphere was great
# model result: Positive
#
# =============================== Input 739 ===============================
# It's so delicious. I made a reservation and they prepared a window seat on their own. The beer was good, too. The interior of the store was very clean. The staff are kind, too. We're going to go again next time
# model result: Positive
#
# =============================== Input 740 ===============================
# Good. The meat is so good.
# model result: Positive
#
# =============================== Input 741 ===============================
# It was clean and delicious, but the table charcoal in the middle of the restaurant was so smoky that the inside of the store was covered with smoke. I'm so busy that I don't even know if I ring the bell...But the meat tasted good The atmosphere is good, too
# model result: Positive
#
# =============================== Input 742 ===============================
# I drank too much. Maybe it's because it's a meat restaurant, but there's nothing I can do about the meat oil on the table I ate it while wiping it But I drank meat and the atmosphere was amazing. I enjoyed the deodeok that you gave me for free
# model result: Positive
#
# =============================== Input 743 ===============================
# The meat tastes good, the food is good, and the atmosphere is good
# model result: Positive
#
# =============================== Input 744 ===============================
# The service was good, but the taste of meat and quarter was really good^^. It feels like you've thought of side dishes and handmade beer is really^^ I wish you all the best in the future.
# model result: Positive
#
# =============================== Input 745 ===============================
# It tasted good and it was kind
# model result: Positive
#
# =============================== Input 746 ===============================
# Kudzu naengmyeon. It was so good!
# model result: Positive
#
# =============================== Input 747 ===============================
# The meat was delicious and the atmosphere was good. I highly recommend it as a place for entertainment.
# model result: Positive
#
# =============================== Input 748 ===============================
# The staff's service is the best. The taste is the best. The people at the company are asking me to go again^^
# model result: Positive
#
# =============================== Input 749 ===============================
# It is good to visit with my family.. Above all, soybean paste stew is delicious.
# model result: Positive
#
# =============================== Input 750 ===============================
# a delicious and atmospheric restaurant
# model result: Positive
#
# =============================== Input 751 ===============================
# It's good
# model result: Positive
#
# =============================== Input 752 ===============================
# The atmosphere is good and the staff are so kind! The meat is so good, too!!Hah!
# model result: Positive
#
# =============================== Input 753 ===============================
# The atmosphere is good and the price of beef is not very expensive and delicious!!!!!!?
# model result: Positive
#
# =============================== Input 754 ===============================
# It was my first visit to my family for dinner and it was so nice.. The meat in each part was very delicious and the interior was very good. The best thing was the service mind of the workers was professional.. Whenever I went somewhere, I was embarrassed because of my parents' fast and mischievous way of speaking. The staff members are so soft and professional. I think the meat tasted better... Thank you for making a pleasant family dinner time.
# model result: Positive
#
# =============================== Input 755 ===============================
# The food came out well for the price and the taste was really good. The atmosphere of the restaurant is so good. I was totally satisfied!! I'm going to go again next time
# model result: Positive
#
# =============================== Input 756 ===============================
# The staff (serving staff) was kind and the meat taste and atmosphere were all goodHaha
# model result: Positive
#
# =============================== Input 757 ===============================
# The food was good and the atmosphere was good
# model result: Positive
#
# =============================== Input 758 ===============================
# It was delicious.
# model result: Positive
#
# =============================== Input 759 ===============================
# The atmosphere and taste were all good!
# model result: Positive
#
# =============================== Input 760 ===============================
# The meat is soft and delicious, but BINCHAN doesn't match the whole, so I cut a star
# model result: Positive
#
# =============================== Input 761 ===============================
# The atmosphere was good and the meat was delicious. But there are so many mosquitoes I think it would be nice if you could do something about mosquitoes!
# model result: Positive
#
# =============================== Input 762 ===============================
# The interior is clean and the service is easy. The surrounding side dishes and sauce are very delicious. I was going to eat a pork set, but there were no parts, so I only ate pork belly, but it's delicious, but it's a little fatty. There was a lot of smoke from the charcoal fire, so even though the fan was well-ventilated, there was a lot of smoke
# model result: Positive
#
# =============================== Input 763 ===============================
# The meat was delicious and kind!!!!
# model result: Positive
#
# =============================== Input 764 ===============================
# The meat is good and the staff are very kind. One thing I regret is that it takes a long time to order meat, and there was a lot of smoke because the charcoal fire ran out of oil. Anyway, it's a house I want to go back to.^^
# model result: Positive
#
# =============================== Input 765 ===============================
# It was a family gathering, so the atmosphere was good and the taste was good
# model result: Positive
#
# =============================== Input 766 ===============================
# The atmosphere was clean and the meat was delicious!!
# model result: Positive
#
# =============================== Input 767 ===============================
# It's a good restaurant
# model result: Positive
#
# =============================== Input 768 ===============================
# The meat tasted very good. But maybe it's because the staff is busy.. I had to order it several times before they brought it to me ㅠ
# model result: Positive
#
# =============================== Input 769 ===============================
# The room was changed, so the people sitting in our room went to another room and we sat...I was embarrassed for no reason. The meat came out after a long time, so I ate all the smoke. The meat was delicious...Fried rice, too. It tastes good, but the staff is so clumsy...
# model result: Positive
#
# Positive ratio: 0.9285
# Negative ratio: 0.0715
