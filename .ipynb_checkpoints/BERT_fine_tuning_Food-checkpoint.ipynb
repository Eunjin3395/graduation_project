# %%
#tensorflow 버전 확인
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# device list에 GPU있나 확인
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11428464104364186303
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7799308288
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6700370518961364793
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
#라이브러리 설치
# !pip install transformers
# !pip install keras==2.6

# !pip install scikit-learn

#필요한 모듈 불러오기
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification

from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd

from tabulate import tabulate
from tqdm import trange
import random
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')


print("GPU available:",torch.cuda.is_available())
# Out:
# Requirement already satisfied: transformers in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (4.27.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (2023.3.23)
# Requirement already satisfied: numpy>=1.17 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: filelock in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (3.10.7)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: requests in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: keras==2.6 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kgsa20\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn) (3.1.0)
# GPU available: True

# %%
# 내 깃허브 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
# Food 속성 리뷰
url='https://raw.githubusercontent.com/Eunjin3395/graduation_project/main/data/food_total.csv'
df = pd.read_csv(url,sep=',', header=0, encoding_errors='ignore')
df.head(5)
# Out:
#      id                                               text category  polarity
# 0  2777  To be completely fair, the only redeeming fact...     food         1
# 1  1634  The food is uniformly exceptional, with a very...     food         1
# 2  2846  Not only was the food outstanding, but the lit...     food         1
# 3  1571          It is very overpriced and not very tasty.     food         0
# 4  1458  Our agreed favorite is the orrechiete with sau...     food         1

# %%
df.dtypes
# Out:
# id          object
# text        object
# category    object
# polarity     int64
# dtype: object

# %%
# review data의 길이 분포 및 통계
df_new=df
df_new['length'] = df['text'].apply(len)

# Create a FacetGrid object with 'Liked' as the column to be used for separating the data
# FacetGrid is a grid of subplots that displays the same relationship between different subsets of your data.
g = sns.FacetGrid(df, col='polarity')

# Use the FacetGrid object to plot a histogram of the 'Length' column for each value of 'Liked'
g.map(plt.hist, 'length');

# %%
count_neg = len(df[df['polarity'] == 0])
count_pos=len(df[df['polarity'] == 1])
print("positive: {}, negative: {}".format(count_pos,count_neg))
# Out:
# positive: 1107, negative: 308

# %%
# review data의 label 분포
sns.set_style('darkgrid')

# Create a count plot of the "Liked" column
sns.countplot(x='polarity', data=df)

# Set the title of the plot
plt.title('Count of Reviews by Liked Status')

# Set the label for the x-axis
plt.xlabel('label')

# Set the label for the y-axis
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
df_new.length.describe()
# Out:
# count    1415.000000
# mean       79.168198
# std        46.640079
# min         6.000000
# 25%        47.500000
# 50%        70.000000
# 75%       102.000000
# max       370.000000
# Name: length, dtype: float64

# %%
text = df.text.values
labels = df.polarity.values

# %%
# 전처리
tokenizer = BertTokenizer.from_pretrained(
    'bert-base-uncased',
    do_lower_case = True
    )

# %%
MAX_LENGTH=150
token_id = []
attention_masks = []

def preprocessing(input_text, tokenizer,max_len_input=MAX_LENGTH):
  '''
  Returns <class transformers.tokenization_utils_base.BatchEncoding> with the following fields:
    - input_ids: list of token ids
    - token_type_ids: list of token type ids
    - attention_mask: list of indices (0,1) specifying which tokens should considered by the model (return_attention_mask = True).
  '''
  return tokenizer.encode_plus(
                        input_text,
                        add_special_tokens = True,
                        max_length = max_len_input,
                        pad_to_max_length = True,
                        return_attention_mask = True,
                        return_tensors = 'pt',
                        truncation=True
                   )


for sample in text:
  encoding_dict = preprocessing(sample, tokenizer)

  # token_id 리스트 추출
  token_id.append(encoding_dict['input_ids']) 
  # attention_mask 리스트 추출
  attention_masks.append(encoding_dict['attention_mask'])


# 리스트를 텐서로
token_id = torch.cat(token_id, dim = 0)
attention_masks = torch.cat(attention_masks, dim = 0)
labels = torch.tensor(labels)

# %%
VAL_RATIO= 0.2
batch_size = 8 # 16 or 32 추천이라고 한다

# Indices of the train and validation splits stratified by labels
train_idx, val_idx = train_test_split(
    np.arange(len(labels)),
    test_size = VAL_RATIO,
    shuffle = True,
    stratify = labels)

# Train and validation sets
train_set = TensorDataset(token_id[train_idx], 
                          attention_masks[train_idx], 
                          labels[train_idx])

val_set = TensorDataset(token_id[val_idx], 
                        attention_masks[val_idx], 
                        labels[val_idx])

# Prepare DataLoader
train_dataloader = DataLoader(
            train_set,
            sampler = RandomSampler(train_set),
            batch_size = batch_size
        )

validation_dataloader = DataLoader(
            val_set,
            sampler = SequentialSampler(val_set),
            batch_size = batch_size
        )


print("train: {}".format(len(train_idx)))
print("validation: {}".format(len(val_idx)))
# Out:
# train: 1132
# validation: 283

# %%
def b_tp(preds, labels):
  '''Returns True Positives (TP): count of correct predictions of actual class 1'''
  return sum([preds == labels and preds == 1 for preds, labels in zip(preds, labels)])

def b_fp(preds, labels):
  '''Returns False Positives (FP): count of wrong predictions of actual class 1'''
  return sum([preds != labels and preds == 1 for preds, labels in zip(preds, labels)])

def b_tn(preds, labels):
  '''Returns True Negatives (TN): count of correct predictions of actual class 0'''
  return sum([preds == labels and preds == 0 for preds, labels in zip(preds, labels)])

def b_fn(preds, labels):
  '''Returns False Negatives (FN): count of wrong predictions of actual class 0'''
  return sum([preds != labels and preds == 0 for preds, labels in zip(preds, labels)])

def b_metrics(preds, labels):
  '''
  Returns the following metrics:
    - accuracy    = (TP + TN) / N
    - precision   = TP / (TP + FP)
    - recall      = TP / (TP + FN)
    - specificity = TN / (TN + FP)
  '''
  preds = np.argmax(preds, axis = 1).flatten()
  labels = labels.flatten()
  tp = b_tp(preds, labels)
  tn = b_tn(preds, labels)
  fp = b_fp(preds, labels)
  fn = b_fn(preds, labels)
  b_accuracy = (tp + tn) / len(labels)
  b_precision = tp / (tp + fp) if (tp + fp) > 0 else 'nan'
  b_recall = tp / (tp + fn) if (tp + fn) > 0 else 'nan'
  b_specificity = tn / (tn + fp) if (tn + fp) > 0 else 'nan'
  return b_accuracy, b_precision, b_recall, b_specificity

# %%
# BERT 모델 불러오기
model = BertForSequenceClassification.from_pretrained(
    'bert-base-uncased',
    num_labels = 2,
    output_attentions = True,
    output_hidden_states = False,
)


optimizer = torch.optim.AdamW(model.parameters(), 
                              lr = 5e-5, # learning rate 설정
                              eps = 1e-08
                              )

model.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# GPU로 학습하도록 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 학습 횟수 설정
epochs = 15

idx=0
epo_list=[]
train_loss_list=[]
val_accuracy_list=[]

for _ in trange(epochs, desc = 'Epoch'):
    idx+=1
    epo_list.append(idx)

    # ========== Training ==========
    model.train()
    
    # Tracking variables
    tr_loss = 0
    nb_tr_examples, nb_tr_steps = 0, 0

    for step, batch in enumerate(train_dataloader):
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch
        optimizer.zero_grad()
        # Forward pass
        train_output = model(b_input_ids, 
                             token_type_ids = None, 
                             attention_mask = b_input_mask, 
                             labels = b_labels)
        # Backward pass
        train_output.loss.backward()
        optimizer.step()
        # Update tracking variables
        tr_loss += train_output.loss.item()
        nb_tr_examples += b_input_ids.size(0)
        nb_tr_steps += 1

    # ========== Validation ==========
    model.eval()

    # Tracking variables 
    val_accuracy = []
    val_precision = []
    val_recall = []
    val_specificity = []

    for batch in validation_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
          # Forward pass
          eval_output = model(b_input_ids, 
                              token_type_ids = None, 
                              attention_mask = b_input_mask)
        logits = eval_output.logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        # Calculate validation metrics
        b_accuracy, b_precision, b_recall, b_specificity = b_metrics(logits, label_ids)
        val_accuracy.append(b_accuracy)
        # Update precision only when (tp + fp) !=0; ignore nan
        if b_precision != 'nan': val_precision.append(b_precision)
        # Update recall only when (tp + fn) !=0; ignore nan
        if b_recall != 'nan': val_recall.append(b_recall)
        # Update specificity only when (tn + fp) !=0; ignore nan
        if b_specificity != 'nan': val_specificity.append(b_specificity)

    print('\n\t - Train loss: {:.4f}'.format(tr_loss / nb_tr_steps))
    print('\t - Validation Accuracy: {:.4f}'.format(sum(val_accuracy)/len(val_accuracy)))
    val_accuracy_temp=sum(val_accuracy)/len(val_accuracy)
    train_loss_list.append(round(tr_loss / nb_tr_steps,4))
    val_accuracy_list.append(round(val_accuracy_temp,4))
    #print('\t - Validation Precision: {:.4f}'.format(sum(val_precision)/len(val_precision)) if len(val_precision)>0 else '\t - Validation Precision: NaN')
    #print('\t - Validation Recall: {:.4f}'.format(sum(val_recall)/len(val_recall)) if len(val_recall)>0 else '\t - Validation Recall: NaN')
    #print('\t - Validation Specificity: {:.4f}\n'.format(sum(val_specificity)/len(val_specificity)) if len(val_specificity)>0 else '\t - Validation Specificity: NaN')
# Out:
# Epoch:   7%|█████                                                                       | 1/15 [00:11<02:43, 11.71s/it]
# 	 - Train loss: 0.3756
# 	 - Validation Accuracy: 0.8750
# Epoch:  13%|██████████▏                                                                 | 2/15 [00:22<02:22, 10.95s/it]
# 	 - Train loss: 0.1686
# 	 - Validation Accuracy: 0.8866
# Epoch:  20%|███████████████▏                                                            | 3/15 [00:32<02:08, 10.70s/it]
# 	 - Train loss: 0.0805
# 	 - Validation Accuracy: 0.8924
# Epoch:  27%|████████████████████▎                                                       | 4/15 [00:42<01:56, 10.60s/it]
# 	 - Train loss: 0.0367
# 	 - Validation Accuracy: 0.8715
# Epoch:  33%|█████████████████████████▎                                                  | 5/15 [00:53<01:45, 10.55s/it]
# 	 - Train loss: 0.0688
# 	 - Validation Accuracy: 0.8889
# Epoch:  40%|██████████████████████████████▍                                             | 6/15 [01:03<01:34, 10.52s/it]
# 	 - Train loss: 0.0414
# 	 - Validation Accuracy: 0.8785
# Epoch:  47%|███████████████████████████████████▍                                        | 7/15 [01:14<01:24, 10.51s/it]
# 	 - Train loss: 0.1142
# 	 - Validation Accuracy: 0.8796
# Epoch:  53%|████████████████████████████████████████▌                                   | 8/15 [01:24<01:13, 10.50s/it]
# 	 - Train loss: 0.0203
# 	 - Validation Accuracy: 0.9028
# Epoch:  60%|█████████████████████████████████████████████▌                              | 9/15 [01:35<01:03, 10.52s/it]
# 	 - Train loss: 0.0513
# 	 - Validation Accuracy: 0.8889
# Epoch:  67%|██████████████████████████████████████████████████                         | 10/15 [01:45<00:52, 10.52s/it]
# 	 - Train loss: 0.0201
# 	 - Validation Accuracy: 0.8854
# Epoch:  73%|██████████████████████████████████████████████████████▉                    | 11/15 [01:56<00:42, 10.52s/it]
# 	 - Train loss: 0.0094
# 	 - Validation Accuracy: 0.8854
# Epoch:  80%|████████████████████████████████████████████████████████████               | 12/15 [02:06<00:31, 10.52s/it]
# 	 - Train loss: 0.0225
# 	 - Validation Accuracy: 0.8646
# Epoch:  87%|█████████████████████████████████████████████████████████████████          | 13/15 [02:17<00:21, 10.52s/it]
# 	 - Train loss: 0.0240
# 	 - Validation Accuracy: 0.8785
# Epoch:  93%|██████████████████████████████████████████████████████████████████████     | 14/15 [02:28<00:10, 10.54s/it]
# 	 - Train loss: 0.0023
# 	 - Validation Accuracy: 0.8785
# Epoch: 100%|███████████████████████████████████████████████████████████████████████████| 15/15 [02:38<00:00, 10.58s/it]
# 	 - Train loss: 0.0003
# 	 - Validation Accuracy: 0.8785

# %%
# train loss 그래프
plt.plot(epo_list, train_loss_list)
plt.xlabel('epoch')
plt.ylabel('train loss')
plt.show()

# %%
plt.plot(epo_list, val_accuracy_list)
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.axis([1,epochs , 0.75, 1])
plt.show()

# %%
#새로운 리뷰를 분류해보자

def test_sentence(sentence):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []

    # 전처리
    encoding = preprocessing(sentence, tokenizer)
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))

    prediction = 'Positive' if np.argmax(output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    return prediction
    

    
    
new_sentence ='The food was bad, but it was cheap'
# 'It''s good, but the owner is so unkind. Some of the plates didn''t clean properly because there was something on them. But it''s cost-effective.'





print('입력 문장:', new_sentence)
print('분류:', test_sentence(new_sentence))
# Out:
# 입력 문장: The food was bad, but it was cheap
# 분류: Negative

# %%
#test data 세팅

# 내 깃허브 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='https://raw.githubusercontent.com/Eunjin3395/graduation_project/main/data/food_test.csv'
df = pd.read_csv(test_url,sep=',', header=0, encoding_errors='ignore')
df.head(5)
# Out:
#                                        id  \
# 0                                    3440
# 1  en_CatalRestaurant__UvaBar_477861889:4
# 2                                    1242
# 3          en_BlueRibbonSushi_478218345:2
# 4                                     882
#
#                                                 text category  polarity
# 0  Even though its good seafood, the prices are t...       aa         1
# 1  My g/f and I both agreed the food was very med...     food         0
# 2                     But the coconut rice was good.     food         1
# 3        It has great sushi and even better service.     food         1
# 4  While the ambiance and atmosphere were great, ...     food         0

# %%
count_neg = len(df[df['polarity'] == 0])
count_pos=len(df[df['polarity'] == 1])
print("positive: {}, negative: {}".format(count_pos,count_neg))
# Out:
# positive: 46, negative: 34

# %%
count=0

test_text = df.text.values
test_labels = df.polarity.values

wrongResult=[]
rightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
    else:
        result=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        rightResult.append(t)
    else:
        wrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# Even though its good seafood, the prices are too high.
# model result: Positive
# answer: 1
#
# =============================== Input 2 ===============================
# My g/f and I both agreed the food was very mediocre especially considering the price.
# model result: Negative
# answer: 0
#
# =============================== Input 3 ===============================
# But the coconut rice was good.
# model result: Positive
# answer: 1
#
# =============================== Input 4 ===============================
# It has great sushi and even better service.
# model result: Positive
# answer: 1
#
# =============================== Input 5 ===============================
# While the ambiance and atmosphere were great, the food and service could have been a lot better.
# model result: Positive
# answer: 0
#
# =============================== Input 6 ===============================
# The food was lousy -too sweet or too salty and the portions tiny.
# model result: Negative
# answer: 0
#
# =============================== Input 7 ===============================
# On my meal I had to send back my eggs for a simple request of breaking the yokes before cooking, and would have had to send them back again if I hadn't rejected the meal all together.
# model result: Negative
# answer: 0
#
# =============================== Input 8 ===============================
# This is a great place to get a delicious meal.
# model result: Positive
# answer: 1
#
# =============================== Input 9 ===============================
# Add to that great service and great food at a reasonable price and you have yourself the beginning of a great evening.
# model result: Positive
# answer: 1
#
# =============================== Input 10 ===============================
# And the Tom Kha soup was pathetic.
# model result: Negative
# answer: 0
#
# =============================== Input 11 ===============================
# I rejected it because in the process of attempting to fix the eggs they broke something else in the dish and I was too frustrated to continue.
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# And really large portions.
# model result: Positive
# answer: 1
#
# =============================== Input 13 ===============================
# The Caesar salad I ordered had so much lemon I couldn't eat it.
# model result: Negative
# answer: 0
#
# =============================== Input 14 ===============================
# I have been here, spent tons of money on a chef special dinner and it was a major dissappointment.
# model result: Negative
# answer: 0
#
# =============================== Input 15 ===============================
# The wine list is wonderful and the food reminds me of my recent trip to Italy.
# model result: Positive
# answer: 1
#
# =============================== Input 16 ===============================
# The spicy tuna and salmon are the best we've ever had.
# model result: Positive
# answer: 1
#
# =============================== Input 17 ===============================
# I liked the atmosphere very much but the food was not worth the price.
# model result: Positive
# answer: 0
#
# =============================== Input 18 ===============================
# Nothing really came across as outstanding.
# model result: Negative
# answer: 0
#
# =============================== Input 19 ===============================
# The food is usually good but it certainly isn't a relaxing place to go.
# model result: Positive
# answer: 1
#
# =============================== Input 20 ===============================
# The food options rule.
# model result: Positive
# answer: 1
#
# =============================== Input 21 ===============================
# To be honest, I've had better frozen pizza.
# model result: Positive
# answer: 0
#
# =============================== Input 22 ===============================
# The food is great and reasonably priced.
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# Even my Indian friend couldn't believe how good and tasty everything was.
# model result: Positive
# answer: 1
#
# =============================== Input 24 ===============================
# I know many people have their favorite types of pizza and pizza places, but Mioposto's pizza lacks quality and good taste.
# model result: Negative
# answer: 0
#
# =============================== Input 25 ===============================
# Unfortunately, the food was NOT something to get worked up about.
# model result: Negative
# answer: 0
#
# =============================== Input 26 ===============================
# In fact, this was not a Nicoise salad and was barely eatable.
# model result: Negative
# answer: 0
#
# =============================== Input 27 ===============================
# Poor customer service/poor pizza.
# model result: Negative
# answer: 0
#
# =============================== Input 28 ===============================
# A few tips: skip the turnip cake, roast pork buns and egg custards.
# model result: Negative
# answer: 0
#
# =============================== Input 29 ===============================
# Good spreads, great beverage selections and bagels really tasty.
# model result: Positive
# answer: 1
#
# =============================== Input 30 ===============================
# Serves really good sushi.
# model result: Positive
# answer: 1
#
# =============================== Input 31 ===============================
# Maybe it is good for that one night once in a blue moon when the chefs decide to use fish that's half-way decent.
# model result: Positive
# answer: 0
#
# =============================== Input 32 ===============================
# Green Tea creme brulee is a must!
# model result: Positive
# answer: 1
#
# =============================== Input 33 ===============================
# Fabulous Italian Food!
# model result: Positive
# answer: 1
#
# =============================== Input 34 ===============================
# In addition, the food is very good and the prices are reasonable.
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# – I was highly disappointed in the food at Pagoda.
# model result: Negative
# answer: 0
#
# =============================== Input 36 ===============================
# The food is fresh, delicious, and reasonably priced.
# model result: Positive
# answer: 1
#
# =============================== Input 37 ===============================
# Everything at Sala Thai is tasty and well-portioned.
# model result: Positive
# answer: 1
#
# =============================== Input 38 ===============================
# The food now is inconsistent.
# model result: Negative
# answer: 0
#
# =============================== Input 39 ===============================
# My mouth felt very dry afterwards and I had that signature ?MSG? taste lingering in my throat after I left the restaurant.
# model result: Negative
# answer: 0
#
# =============================== Input 40 ===============================
# – I will never forget the amazing meal, service, and ambiance I experience at this restaurant.
# model result: Positive
# answer: 1
#
# =============================== Input 41 ===============================
# – The food was not great & the waiters were rude.
# model result: Positive
# answer: 0
#
# =============================== Input 42 ===============================
# They are not greasy or anything.
# model result: Negative
# answer: 1
#
# =============================== Input 43 ===============================
# Though, one thing I realized later on was that the restaurant either used MSG or a meat tenderizer on the steak.
# model result: Negative
# answer: 0
#
# =============================== Input 44 ===============================
# the only problem is you really have to warm up the pizza before it's edible, even when you order ahead.
# model result: Negative
# answer: 0
#
# =============================== Input 45 ===============================
# Yum!
# model result: Positive
# answer: 1
#
# =============================== Input 46 ===============================
# The food was great!
# model result: Positive
# answer: 1
#
# =============================== Input 47 ===============================
# The lemon chicken tasted like sticky sweet donuts and the honey walnut prawns, the few they actually give you.....were not good.
# model result: Negative
# answer: 0
#
# =============================== Input 48 ===============================
# I recommend the garlic shrimp, okra (bindi), and anything with lamb.
# model result: Positive
# answer: 1
#
# =============================== Input 49 ===============================
# The food is prepared quickly and efficiently.
# model result: Positive
# answer: 1
#
# =============================== Input 50 ===============================
# The food is not what it once was (potions have seriously seen downsizing) prices have gone up, and the service is the worst I have experienced anywhere (including mainland Europe).
# model result: Negative
# answer: 0
#
# =============================== Input 51 ===============================
# Their calzones are horrific, bad, vomit-inducing, YUCK.
# model result: Positive
# answer: 0
#
# =============================== Input 52 ===============================
# Fancy pieces of exotic fish on a $100 dollar plate and NOT ONE was eatable.
# model result: Negative
# answer: 0
#
# =============================== Input 53 ===============================
# My goodness, everything from the fish to the rice to the seaweed was absolutely amazing.
# model result: Positive
# answer: 1
#
# =============================== Input 54 ===============================
# Consistently good Japanese Tapas.
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# Anyway, the food is good, the price is right and they have a decent wine list.
# model result: Positive
# answer: 1
#
# =============================== Input 56 ===============================
# The bagels are fabulous.
# model result: Positive
# answer: 1
#
# =============================== Input 57 ===============================
# All the appetizers and salads were fabulous, the steak was mouth watering and the pasta was delicious!!!
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# I love the fact that the pizza tastes so good and is so cheap.
# model result: Positive
# answer: 1
#
# =============================== Input 59 ===============================
# The sushi was awful!
# model result: Negative
# answer: 0
#
# =============================== Input 60 ===============================
# I may not be a sushi guru but I can tell you that the food here is just okay and that there is not much else to it.
# model result: Negative
# answer: 0
#
# =============================== Input 61 ===============================
# The food is great and authentic.
# model result: Positive
# answer: 1
#
# =============================== Input 62 ===============================
# The dishes offered were unique, very tasty and fresh from the lamb sausages, sardines with biscuits, large whole shrimp to the amazing pistachio ice cream (the best and freshest I've ever had).
# model result: Positive
# answer: 1
#
# =============================== Input 63 ===============================
# It's *very* reasonably priced, esp for the quality of the food.
# model result: Positive
# answer: 1
#
# =============================== Input 64 ===============================
# We are locals, and get the feeling the only way this place survives with such average food is because most customers are probably one-time customer tourists.
# model result: Negative
# answer: 0
#
# =============================== Input 65 ===============================
# I haven't eat a lamb chop as delicious as that, the salads are really nice dressed with lemon and extra virgnin olive oil.
# model result: Positive
# answer: 1
#
# =============================== Input 66 ===============================
# The food was very good, a great deal, and the place its self was great.
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# I should have thought to bring it up but never expected the food to be that mild.
# model result: Positive
# answer: 0
#
# =============================== Input 68 ===============================
# The wine list is incredible and extensive and diverse, the food is all incredible and the staff was all very nice, good at their jobs and cultured.
# model result: Positive
# answer: 1
# =============================== Input 69 ===============================
# The menu was impressive with selections ranging from a burger, to steak, to escargot.
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# The food is terrible and overall, I would have to say avoid at all costs.
# model result: Negative
# answer: 0
#
# =============================== Input 71 ===============================
# Rice is too dry, tuna wasn't so fresh either.
# model result: Negative
# answer: 0
#
# =============================== Input 72 ===============================
# The best thing I tasted were the lambc hops.
# model result: Positive
# answer: 1
#
# =============================== Input 73 ===============================
# Try the crunchy tuna, it is to die for.
# model result: Positive
# answer: 1
#
# =============================== Input 74 ===============================
# The food was great.
# model result: Positive
# answer: 1
#
# =============================== Input 75 ===============================
# I swore never to return for a warm beer and mediocre meal.
# model result: Negative
# answer: 0
#
# =============================== Input 76 ===============================
# Don't leave the restaurant without it.
# model result: Negative
# answer: 1
#
# =============================== Input 77 ===============================
# The onion rings are great!
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# Good food!
# model result: Positive
# answer: 1
#
# =============================== Input 79 ===============================
# With the theater 2 blocks away we had a delicious meal in a beautiful room.
# model result: Positive
# answer: 1
#
# =============================== Input 80 ===============================
# very good breads as well.
# model result: Positive
# answer: 1
#
# test accuracy: 0.8875

# %%
# 개별 문장의 attention 추출하는 함수
def get_attention(encoding):
    # 토큰 ID와 attention mask를 위한 리스트
    test_ids = []
    test_attention_mask = []
    test_ids.append(encoding['input_ids'])
    test_attention_mask.append(encoding['attention_mask'])
    test_ids = torch.cat(test_ids, dim = 0)
    test_attention_mask = torch.cat(test_attention_mask, dim = 0)
    
    
    # Forward pass, calculate logit predictions
    with torch.no_grad():
        model_output = model(test_ids.to(device), token_type_ids = None, attention_mask = test_attention_mask.to(device))
        
    prediction = 'Positive' if np.argmax(model_output.logits.cpu().numpy()).flatten().item() == 1 else 'Negative'
    attention=model_output[-1]
    last_attention=attention[-1]
    tokens=tokenizer.convert_ids_to_tokens(encoding['input_ids'][0])
    
    return attention,last_attention,tokens,prediction

# %%
def get_val_len(ids):
    count=0
    for elem in ids:
        if(elem!=0):
            count+=1
    return count

# %%
# 개별 문장의 attention 추출
from bertviz import head_view

sent="Terrible service, but delicious food."

# 전처리
encoding = preprocessing(sent, tokenizer,10)


retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

print('입력 문장:', sent)
print('분류:', prediction)
print()

head_view(retAtt,retTok)
# Out:
# 입력 문장: Terrible service, but delicious food.
# 분류: Positive
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-f9a9aee575cc43b69f837ca55ea006f7" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
def sort_by_att(attention,tokens):
    '''
        last layer의 attention tensor를 입력 받아 각 token의 attention 값을 head에 대한 평균을 낸 뒤, attention이 높은 token 순으로 idx를 반환하는 함수
    '''
    
    attention=attention[0] # shape: 12,len,len
    
    size=len(tokens)
    
    total_atts_sum=[] # 각 head에 대한 각 토큰의 attention값의 합
    for head in range(0,12):
        att_of_head=attention[head] # 한 head의 attention
        atts_sum_of_head=[0.0]*size # 해당 head 하나의 attention의 합
        for row in att_of_head:
            col=0
            for elem in row:
                value=elem.item()
                atts_sum_of_head[col]+=value # head 하나에 대한 토큰이 가지는 attention 값
                col+=1
        total_atts_sum.append(atts_sum_of_head)
    
    total_sum_value=[0.0]*size
    for elem in total_atts_sum:
        for i in range(0,size):
            total_sum_value[i]+=elem[i]
            

    total_mean=[]
    for elem in total_sum_value:
        total_mean.append(elem/12)
    
    


    idxs=sorted(range(len(total_mean)), key=lambda k: total_mean[k], reverse=True)
    return(idxs)

# %%
# attention 순서대로 텍스트 배경색 주기
color_code=[
    "\033[48;5;243m",
    "\033[48;5;245m",
    "\033[48;5;247m",
    "\033[48;5;249m",
    "\033[48;5;251m",
    "\033[48;5;253m",
    "\033[48;5;255m"
]
def emp_by_att(attIdxs,tokens):   
    valTokens=[]
    for tok in tokens:
        if(tok!='[CLS]' and tok!='[PAD]' and tok!='[SEP]'):
            valTokens.append(tok)
        
    valIdxs=[]
    for idx in attIdxs:
        if len(valIdxs)==7:
            break;
        
        if(idx>0 and idx<=len(valTokens)):
            if(valTokens[idx-1]!=',' and valTokens[idx-1]!='.'):
                valIdxs.append(idx-1)
    
    resultSent=""
    for i in range(len(valTokens)):
        if(i in valIdxs):
            outTok=color_code[valIdxs.index(i)]+valTokens[i]+"\033[0m"
        else:
            outTok=valTokens[i]
        resultSent+=outTok
        resultSent+=' '
    
    print("========================= emphasize by attention result==========================")
    print(resultSent)

# %%
def get_highest_att_tok(idxs,retTok,num):
    count=0
    print("highest attention: ",end="")
    for i in idxs:
        if(i<len(retTok)):
            if(retTok[i]!='[CLS]' and retTok[i]!='[SEP]' and retTok[i]!='.' and retTok[i]!=','):
                if(count<num):
                    print(retTok[i],end=" ")
                    count+=1

# %%
# 개별 문장을 attention이 높은 token 순으로 보여주기
idxs=sort_by_att(retLastAtt,retTok)

emp_by_att(idxs,retTok)

get_highest_att_tok(idxs,retTok,3)
# Out:
# ========================= emphasize by attention result==========================
# terrible service , but delicious food .
# highest attention: food delicious but

# %%
#잘못 분류된 문장의 attention
for sent in wrongResult:
    encoding = preprocessing(sent, tokenizer,50)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: While the ambiance and atmosphere were great, the food and service could have been a lot better.
# 분류: Positive
# MAX_LEN:  23
# ========================= emphasize by attention result==========================
# while the am ##bian ##ce and atmosphere were great , the food and service could have been a lot better .
# highest attention: great been the while
#
#
#
# 입력 문장: I liked the atmosphere very much but the food was not worth the price.
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# i liked the atmosphere very much but the food was not worth the price .
# highest attention: not was much i
#
#
#
# 입력 문장: To be honest, I've had better frozen pizza.
# 분류: Positive
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# to be honest , i ' ve had better frozen pizza .
# highest attention: ' honest i ve
#
#
#
# 입력 문장: Maybe it is good for that one night once in a blue moon when the chefs decide to use fish that's half-way decent.
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# maybe it is good for that one night once in a blue moon when the chefs decide to use fish that ' s half - way decent .
# highest attention: ' to decide maybe
#
#
#
# 입력 문장: – The food was not great & the waiters were rude.
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# – the food was not great & the waiter ##s were rude .
# highest attention: great not rude &
#
#
#
# 입력 문장: They are not greasy or anything.
# 분류: Negative
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# they are not greasy or anything .
# highest attention: are they not or
#
#
#
# 입력 문장: Their calzones are horrific, bad, vomit-inducing, YUCK.
# 분류: Positive
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# their cal ##zone ##s are horrific , bad , vomit - inducing , yu ##ck .
# highest attention: are yu bad ##ck
#
#
#
# 입력 문장: I should have thought to bring it up but never expected the food to be that mild.
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# i should have thought to bring it up but never expected the food to be that mild .
# highest attention: but mild i bring
#
#
#
# 입력 문장: Don't leave the restaurant without it.
# 분류: Negative
# MAX_LEN:  11
# ========================= emphasize by attention result==========================
# don ' t leave the restaurant without it .
# highest attention: ' don t without

# %%
#NAVER test data 세팅

# data/naver_data 폴더에서 리뷰 데이터 불러와서 dataframe으로 저장
test_url='./data/naver_data/naver_food_test.csv'
df = pd.read_csv(test_url,sep=',', header=0,encoding="CP949")
df.head(5)
# Out:
#    Unnamed: 0    id category  \
# 0           0   180     food
# 1           1   580     food
# 2           2   605     food
# 3           3  1696     food
# 4           4  2550     food
#
#                                                 text  polarity  \
# 0  쟁반짜장은 너무 짜고, 면이 불어 있었어요\n탕수육은 비린내가 심하고, 짬뽕은 양파...         0
# 1  매장이 엄청 지저분합니다.\n사이다는 단맛이 하나도 없는 탄산수였습니다.\n직원이 ...         0
# 2                고기 기름이 넘 많네요\n서비스도 조금 부족한듯\n다소 아쉽네요         0
# 3                                  토마호크 비추천.\n고기가 질김         0
# 4  스테이크덮밥이랑 큐브스테이크덮밥을 먹엇는데 개인적으로 다음식 안좋아하는 분은 큐브스...         0
#
#                                           trans_text
# 0  The jajangmyeon on the tray was too salty and ...
# 1  The store is really messy.. Sprite was carbona...
# 2  There's too much meat oil. The service seems t...
# 3  I don't recommend Tomahawk.. the toughness of ...
# 4  I ate rice with steak and rice with cube steak...

# %%
# naver data에 대한 분류 및 accuracy 측정
count=0

test_text = df.trans_text.values
test_labels = df.polarity.values

NaverWrongResult=[]
NaverRightResult=[]

for i in range(len(test_labels)):
    t = df.iloc[i].trans_text
    color_s='\033[31m' 
    color_e='\033[0m'
    
    prediction=test_sentence(t)
    if(prediction=="Negative"):
        result=0
    else:
        result=1
        
    if(result==df.iloc[i].polarity):
        count+=1     
        color_s=''
        color_e=''
        NaverRightResult.append(t)
    else:
        NaverWrongResult.append(t)
    print(color_s+"=============================== Input {} ===============================".format(i+1))
    print(t)
    print("model result:",prediction,"\nanswer:", df.iloc[i].polarity,color_e)
    print("")


print("test accuracy: {:.4f}".format(count/len(test_labels)))
# Out:
# =============================== Input 1 ===============================
# The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# model result: Negative
# answer: 0
#
# =============================== Input 2 ===============================
# The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# model result: Negative
# answer: 0
#
# =============================== Input 3 ===============================
# There's too much meat oil. The service seems to be a little lacking. It's a bit disappointing
# model result: Negative
# answer: 0
#
# =============================== Input 4 ===============================
# I don't recommend Tomahawk.. the toughness of the meat
# model result: Negative
# answer: 0
#
# =============================== Input 5 ===============================
# I ate rice with steak and rice with cube steak, but personally, I don't want to recommend cube steak if you don't like all foods. It's too sweet
# model result: Negative
# answer: 0
#
# =============================== Input 6 ===============================
# Braised hairtail is too salty. I can't eat a hairtail because it's too hard and small. Steamed eggs are too bitter. Dozer's throat is sore  I don't think I'll ever go again
# model result: Negative
# answer: 0
#
# =============================== Input 7 ===============================
# The fried chicken was so greasy that it didn't taste good.
# model result: Negative
# answer: 0
#
# =============================== Input 8 ===============================
# I only ate BBQ chicken, but this time it was too saltyPlease reduce the amount of salt~~
# model result: Negative
# answer: 0
#
# =============================== Input 9 ===============================
# I ordered Cheekki at a reasonable price, so it's a bit tough and hard... Let's just order chicken with BBQ
# model result: Negative
# answer: 0
#
# =============================== Input 10 ===============================
# I've never been to such an insincere and unfriendly restaurant. I read the review and came here saying that it's delicious even if it's unfriendly, but it's not delicious;;
# model result: Positive
# answer: 0
#
# =============================== Input 11 ===============================
# It was just so-so. The seasoning was bland, and I was waiting to pay for the package.. Personally, I don't like it
# model result: Negative
# answer: 0
#
# =============================== Input 12 ===============================
# The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# model result: Negative
# answer: 0
#
# =============================== Input 13 ===============================
# The noodles are broken and have no elasticity at all because they are weak. The delivery came ahead of schedule.
# model result: Negative
# answer: 0
#
# =============================== Input 14 ===============================
# The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# model result: Negative
# answer: 0
#
# =============================== Input 15 ===============================
# Maybe it's just meat. But I can't eat soybean paste with crab. It's too fishy The bibim sauce for naengmyeon is not that bad, but the broth is... Wow..It's a taste I don't want to eat again
# model result: Positive
# answer: 0
#
# =============================== Input 16 ===============================
# I've tried seasoned raw octopus vinegar and octopus garlic raw fish, but the taste...Actually, I don't know. It's not cheap either
# model result: Positive
# answer: 0
#
# =============================== Input 17 ===============================
# It's not the taste of the past. The meat is almost fat
# model result: Negative
# answer: 0
#
# =============================== Input 18 ===============================
# Far from green onion kimchi, cabbage kimchi has fallen... It's greasy to my taste...  I have no intention of revisiting.
# model result: Negative
# answer: 0
#
# =============================== Input 19 ===============================
# Not until long ago. The owner changed and the taste changed
# model result: Negative
# answer: 0
#
# =============================== Input 20 ===============================
# as if it's not seasoned enough
# model result: Negative
# answer: 0
#
# =============================== Input 21 ===============================
# The food is a bit salty. Rice and curry are refilled
# model result: Positive
# answer: 0
#
# =============================== Input 22 ===============================
# I've been to this place often, and I love that there's a cafe like this in the neighborhood!! The interior is clean, the coffee is delicious, and corn cheese toast is especially delicious!!
# model result: Positive
# answer: 1
#
# =============================== Input 23 ===============================
# I thought it was expensive as soon as I entered. But it was the most delicious thing I had this year. I'm going to have a good hangover
# model result: Positive
# answer: 1
#
# =============================== Input 24 ===============================
# It's good. It's been a while, so the price went up
# model result: Positive
# answer: 1
#
# =============================== Input 25 ===============================
# It's so delicious.~~~. However, the employees are not very kind.
# model result: Positive
# answer: 1
#
# =============================== Input 26 ===============================
# I ordered two and shared them with my sister. Both of them were so good I don't know if it's the owner, but the employee is so kind Enjoy your meal
# model result: Positive
# answer: 1
#
# =============================== Input 27 ===============================
# Everyone is kind and the cocktails are so delicious! Thank you for the free shot you gave me as a dart event. It was better because the bathroom was so clean and it didn't smell
# model result: Positive
# answer: 1
#
# =============================== Input 28 ===============================
# Sweet and sour chicken is so delicious.. They cool it down and wrap it up.. The cold gangjeong style...The batter is crispy and it tastes so good.It's real..
# model result: Positive
# answer: 1
#
# =============================== Input 29 ===============================
# Even though it was past lunch time, there was a bit of waiting, but the soup and noodle ingredients were so good as I wanted to come back next time, and it was more delicious with kimchi
# model result: Positive
# answer: 1
#
# =============================== Input 30 ===============================
# The standby system is well-equipped and has a high turnover, so I got in quickly in! I come here regularly because my parents like it! It's good
# model result: Positive
# answer: 1
#
# =============================== Input 31 ===============================
# Although there was a bit of a wait for the weekend. Egg Benedict was so delicious. I want to sit in the outdoor seat on a fine day
# model result: Positive
# answer: 1
#
# =============================== Input 32 ===============================
# I visited because I wanted to eat strawberry dessert. Maybe because it's famous, there are a lot of people even during the day on weekdays. It's expensive, but it tastes good
# model result: Positive
# answer: 1
#
# =============================== Input 33 ===============================
# Even though I waited for 20 minutes and ate alone, they were kind and the food was good without any smell.. It's cost-effective and the radish kimchi is always delicious, so the soup is delicious and a healthy meal is the best
# model result: Positive
# answer: 1
#
# =============================== Input 34 ===============================
# It's so good here... But it's hard to wait, so I'm going to wrap it up now.. I'd like you to change it to a waiting machine! It's so uncomfortable to have to wait in front of the storecrying
# model result: Positive
# answer: 1
#
# =============================== Input 35 ===============================
# Even though it was a weekday evening, the atmosphere was amazing.. But Sundaeguk was so delicious that I could endure and wait. I want to eat it with soju next time! I did it again today!
# model result: Positive
# answer: 1
#
# =============================== Input 36 ===============================
# I've been waiting for 40 minutes for lunch on Saturday It wasn't enough But it's not greasy and it's
# model result: Positive
# answer: 1
#
# =============================== Input 37 ===============================
# I broke my promise with my friend to eat something simple Salted pollack pasta is so delicious and lasagna is the best    It makes me think that I'm home Strongly recommended
# model result: Positive
# answer: 1
#
# =============================== Input 38 ===============================
# I really enjoyed breakfast in Seoul! Braised hairtail is good, but the cheonggukjang is really good The free steamed eggs and fried hairtail were also delicious I want to visit again
# model result: Positive
# answer: 1
#
# =============================== Input 39 ===============================
# Braised hairtail in line. It was delicious. I was a little distracted, but the four Chinese family members at the next table right next to me had such a good voice
# model result: Positive
# answer: 1
#
# =============================== Input 40 ===============================
# The taste is soft and very delicious.. They were very kind and gave us a service. I strongly recommend it.
# model result: Positive
# answer: 1
#
# =============================== Input 41 ===============================
# It's a sandwich I often eat for a meal and it's always delicious and filling :) The vegetables are fresh and the bread is delicious. The staff is also kind, so I use it often
# model result: Positive
# answer: 1
# =============================== Input 42 ===============================
# The bread is chewy. It's delicious. It hasn't been long since it opened, so the baker's. I think it's more passionate.. . Warm bread made by warm people. Try it~~^^
# model result: Positive
# answer: 1
#
# =============================== Input 43 ===============================
# The quality of the meat and the tempura are very fresh and delicious.. I can't help but write a review... Thank you!
# model result: Positive
# answer: 1
#
# =============================== Input 44 ===============================
# It's kind and the oil is clean and crispy and delicious The members really liked it The delivery time is a bit long, so I think I need to order it in advance That's the only thing that's unfortunate
# model result: Positive
# answer: 1
#
# =============================== Input 45 ===============================
# The cost-effectiveness is the best and it's so delicious..
# model result: Positive
# answer: 1
#
# =============================== Input 46 ===============================
# It was a little noisy because there were many students and the music was loud, but it was okay because the snacks were delicious and the price was reasonable
# model result: Positive
# answer: 1
#
# =============================== Input 47 ===============================
# Except when there are a lot of people, it's loud enough to make people's ears ring with the sound of music... The food is delicious and inexpensive, and even the thin ice of beer is very good!
# model result: Positive
# answer: 1
#
# =============================== Input 48 ===============================
# They are kind and the drinks are delicious. It would be better if the store was a little bigger
# model result: Positive
# answer: 1
#
# =============================== Input 49 ===============================
# The meat is so goodIt's my first time in Pyeongtaek, and thanks to you, I have a good memory. They grill meat themselves, and they're all so nice and kind
# model result: Positive
# answer: 1
#
# =============================== Input 50 ===============================
# The pork belly was really good, but the pork neck was crazy!!! I'm amazed as soon as I eat it Do you really recommend it!!!! It's so nice that the staff cooked it deliciously. I'll save it as a good restaurant
# model result: Positive
# answer: 1
#
# =============================== Input 51 ===============================
# He was kind and the drink was very delicious! The side tastes good, too
# model result: Positive
# answer: 1
#
# =============================== Input 52 ===============================
# Parking is a little inconvenient, but the atmosphere of the store is so good and all the menus are delicious :)
# model result: Positive
# answer: 1
#
# =============================== Input 53 ===============================
# It was good because there was a lot. They gave me a big piece of high quality meat and the jjajo was really good.
# model result: Positive
# answer: 1
#
# =============================== Input 54 ===============================
# The food is delicious and clean! And he was very kind. Maybe that's why there were a lot of customers
# model result: Positive
# answer: 1
#
# =============================== Input 55 ===============================
# It's incredibly unkind. It tastes good. Green onion recommendation
# model result: Positive
# answer: 1
#
# =============================== Input 56 ===============================
# The food is delicious but not kind
# model result: Positive
# answer: 1
#
# =============================== Input 57 ===============================
# The owner is kind, the drinks are good, and the interior of the store is pretty
# model result: Positive
# answer: 1
#
# =============================== Input 58 ===============================
# The grain powder taste is good.. But... the two working women are very unkind. You seem to be very dissatisfied with society as to what's upsetting about you.
# model result: Positive
# answer: 1
#
# =============================== Input 59 ===============================
# It's so good. The food is really good and it comes out clean. Above all, the staff are so kind!! There's always a lot of waiting, but it's inevitable that there's a lot of waitingㅠ
# model result: Positive
# answer: 1
#
# =============================== Input 60 ===============================
# Instant tteokbokki is good. I put in the noodles and the last fried rice
# model result: Positive
# answer: 1
#
# =============================== Input 61 ===============================
# The owner is kind and the side dish is very delicious! There's a variety of drinks, so it's fun to choose one every time you go
# model result: Positive
# answer: 1
#
# =============================== Input 62 ===============================
# The atmosphere is good and the taste is good!! However, as the hall was full, it was a little noisy and the air was hot, too. :-( It was too bad
# model result: Positive
# answer: 1
#
# =============================== Input 63 ===============================
# It's delicious and kind. I am happy that there is a bar in the neighborhood where I can drink various traditional liquor. It's a place where you have to wait because it's a place where you have to wait.
# model result: Positive
# answer: 1
#
# =============================== Input 64 ===============================
# It's as delicious as it's rumored. I think it's a bit expensive
# model result: Positive
# answer: 1
#
# =============================== Input 65 ===============================
# The food is really good. I knew why it was so famous. Mackerel sushi is really good, but there are no pictures!It's so good
# model result: Positive
# answer: 1
#
# =============================== Input 66 ===============================
# I really enjoyed the meal! It was the most delicious place I've ever been to. I'll go again later
# model result: Positive
# answer: 1
#
# =============================== Input 67 ===============================
# It's good, but the staff members are kind... I understand if it's because you're busy..
# model result: Positive
# answer: 1
#
# =============================== Input 68 ===============================
# It's clean and delicious. It's a shame that the price went up
# model result: Positive
# answer: 1
#
# =============================== Input 69 ===============================
# The food was delicious and the staff were very kind, so I had a nice meal. It's nice to have a seat for Da-Ji!
# model result: Positive
# answer: 1
#
# =============================== Input 70 ===============================
# I can't say it's cheap and the waiting is long. A taste I want to go again!! The ingredients are fresh and it tastes healthy and delicious!
# model result: Positive
# answer: 1
#
# =============================== Input 71 ===============================
# It's a bit pricey, but it's good
# model result: Positive
# answer: 1
#
# =============================== Input 72 ===============================
# It's good. It's not that sweet. It's really good
# model result: Positive
# answer: 1
#
# =============================== Input 73 ===============================
# I had a preconceived notion that it was vegan, but it's more delicious than other regular breads!!  The bread is more chewy and delicious, so I'm going to revisit it!!
# model result: Positive
# answer: 1
#
# =============================== Input 74 ===============================
# The owner is so kind and it's a vegan bakery, so it's unique and so delicious!! Especially, tofu brownies are the best!^^^♡
# model result: Positive
# answer: 1
#
# =============================== Input 75 ===============================
# It's cost-effective and the ingredients are fresh and delicious
# model result: Positive
# answer: 1
#
# =============================== Input 76 ===============================
# There's a lot and it'sI hope it's controlled
# model result: Positive
# answer: 1
#
# =============================== Input 77 ===============================
# The staff are so kind. I enjoyed my meal, too!
# model result: Positive
# answer: 1
#
# =============================== Input 78 ===============================
# Fresh ingredients. Thank you for the food
# model result: Positive
# answer: 1
#
# =============================== Input 79 ===============================
# The staff is kind and it tastes better with Tabasco sauce that you recommended!!! I went alone, and it's nice to enjoy delicious food and relaxation♥
# model result: Positive
# answer: 1
#
# =============================== Input 80 ===============================
# It's good. But it's small and they didn't give me a fork
# model result: Positive
# answer: 1
#
# test accuracy: 0.9500

# %%
#잘못 분류된 문장의 attention
for sent in NaverWrongResult:
    encoding = preprocessing(sent, tokenizer,70)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: I've never been to such an insincere and unfriendly restaurant. I read the review and came here saying that it's delicious even if it's unfriendly, but it's not delicious;;
# 분류: Positive
# MAX_LEN:  52
# ========================= emphasize by attention result==========================
# i ' ve never been to such an ins ##in ##cer ##e and un ##fr ##ien ##dly restaurant . i read the review and came here saying that it ' s delicious even if it ' s un ##fr ##ien ##dly , but it ' s not delicious ; ;
# highest attention: ' ' ' '
#
#
#
# 입력 문장: Maybe it's just meat. But I can't eat soybean paste with crab. It's too fishy The bibim sauce for naengmyeon is not that bad, but the broth is... Wow..It's a taste I don't want to eat again
# 분류: Positive
# MAX_LEN:  67
# ========================= emphasize by attention result==========================
# maybe it ' s just meat . but i can ' t eat soy ##be ##an paste with crab . it ' s too fish ##y the bi ##bi ##m sauce for na ##eng ##my ##eon is not that bad , but the bro ##th is . . . wow . . it ' s a taste i don ' t want to eat again
# highest attention: ' ' ' '
#
#
#
# 입력 문장: I've tried seasoned raw octopus vinegar and octopus garlic raw fish, but the taste...Actually, I don't know. It's not cheap either
# 분류: Positive
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# i ' ve tried seasoned raw octopus vinegar and octopus garlic raw fish , but the taste . . . actually , i don ' t know . it ' s not cheap either
# highest attention: ' ' ' raw
#
#
#
# 입력 문장: The food is a bit salty. Rice and curry are refilled
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the food is a bit salty . rice and curry are ref ##ille ##d
# highest attention: bit salty are ##ille

# %%
#잘 분류된 문장의 attention
for sent in NaverRightResult:
    encoding = preprocessing(sent, tokenizer,70)
    MAX_LEN_IN=get_val_len(encoding['input_ids'][0])


    retAtt,retLastAtt,retTok,prediction=get_attention(encoding)

    print('입력 문장:', sent)
    print('분류:', prediction)
    print('MAX_LEN: ',MAX_LEN_IN)
    
    idxs=sort_by_att(retLastAtt,retTok)

    emp_by_att(idxs,retTok)
    
    get_highest_att_tok(idxs,retTok,4)
    print()
    print()
    print()
    print()
# Out:
# 입력 문장: The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# 분류: Negative
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# the ja ##jan ##gm ##ye ##on on the tray was too salty and the noodles were swollen . tang ##su ##yu ##k had a bad fish ##y smell , jj ##amp ##pon ##g had a lot of onions , and squid had only 3 pieces
# highest attention: were and and a
#
#
#
# 입력 문장: The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# 분류: Negative
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# the store is really messy . . sp ##rite was carbonate ##d water without any sweetness . . there seemed to be a shortage of staff .
# highest attention: messy shortage be really
#
#
#
# 입력 문장: There's too much meat oil. The service seems to be a little lacking. It's a bit disappointing
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# there ' s too much meat oil . the service seems to be a little lacking . it ' s a bit disappointing
# highest attention: ' little bit be
#
#
#
# 입력 문장: I don't recommend Tomahawk.. the toughness of the meat
# 분류: Negative
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# i don ' t recommend tom ##aha ##wk . . the tough ##ness of the meat
# highest attention: ' i don t
#
#
#
# 입력 문장: I ate rice with steak and rice with cube steak, but personally, I don't want to recommend cube steak if you don't like all foods. It's too sweet
# 분류: Negative
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# i ate rice with steak and rice with cube steak , but personally , i don ' t want to recommend cube steak if you don ' t like all foods . it ' s too sweet
# highest attention: ' ' ' too
#
#
#
# 입력 문장: Braised hairtail is too salty. I can't eat a hairtail because it's too hard and small. Steamed eggs are too bitter. Dozer's throat is sore  I don't think I'll ever go again
# 분류: Negative
# MAX_LEN:  51
# ========================= emphasize by attention result==========================
# bra ##ised hair ##tail is too salty . i can ' t eat a hair ##tail because it ' s too hard and small . steamed eggs are too bitter . do ##zer ' s throat is sore i don ' t think i ' ll ever go again
# highest attention: ' ' ' '
#
#
#
# 입력 문장: The fried chicken was so greasy that it didn't taste good.
# 분류: Negative
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# the fried chicken was so greasy that it didn ' t taste good .
# highest attention: ' that was it
#
#
#
# 입력 문장: I only ate BBQ chicken, but this time it was too saltyPlease reduce the amount of salt~~
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# i only ate bb ##q chicken , but this time it was too salty ##ple ##ase reduce the amount of salt ~ ~
# highest attention: too was it ~
#
#
#
# 입력 문장: I ordered Cheekki at a reasonable price, so it's a bit tough and hard... Let's just order chicken with BBQ
# 분류: Negative
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# i ordered cheek ##ki at a reasonable price , so it ' s a bit tough and hard . . . let ' s just order chicken with bb ##q
# highest attention: ' ' bit and
#
#
#
# 입력 문장: It was just so-so. The seasoning was bland, and I was waiting to pay for the package.. Personally, I don't like it
# 분류: Negative
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# it was just so - so . the season ##ing was bland , and i was waiting to pay for the package . . personally , i don ' t like it
# highest attention: ' personally just was
#
#
#
# 입력 문장: The jajangmyeon on the tray was too salty and the noodles were swollen. Tangsuyuk had a bad fishy smell, jjamppong had a lot of onions, and squid had only 3 pieces
# 분류: Negative
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# the ja ##jan ##gm ##ye ##on on the tray was too salty and the noodles were swollen . tang ##su ##yu ##k had a bad fish ##y smell , jj ##amp ##pon ##g had a lot of onions , and squid had only 3 pieces
# highest attention: were and and a
#
#
#
# 입력 문장: The noodles are broken and have no elasticity at all because they are weak. The delivery came ahead of schedule.
# 분류: Negative
# MAX_LEN:  25
# ========================= emphasize by attention result==========================
# the noodles are broken and have no elastic ##ity at all because they are weak . the delivery came ahead of schedule .
# highest attention: because are they and
#
#
#
# 입력 문장: The store is really messy.. Sprite was carbonated water without any sweetness.. There seemed to be a shortage of staff.
# 분류: Negative
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# the store is really messy . . sp ##rite was carbonate ##d water without any sweetness . . there seemed to be a shortage of staff .
# highest attention: messy shortage be really
#
#
#
# 입력 문장: It's not the taste of the past. The meat is almost fat
# 분류: Negative
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# it ' s not the taste of the past . the meat is almost fat
# highest attention: ' almost fat is
#
#
#
# 입력 문장: Far from green onion kimchi, cabbage kimchi has fallen... It's greasy to my taste...  I have no intention of revisiting.
# 분류: Negative
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# far from green onion kim ##chi , cabbage kim ##chi has fallen . . . it ' s greasy to my taste . . . i have no intention of rev ##isi ##ting .
# highest attention: ' no intention greasy
#
#
#
# 입력 문장: Not until long ago. The owner changed and the taste changed
# 분류: Negative
# MAX_LEN:  14
# ========================= emphasize by attention result==========================
# not until long ago . the owner changed and the taste changed
# highest attention: changed changed and not
#
#
#
# 입력 문장: as if it's not seasoned enough
# 분류: Negative
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# as if it ' s not seasoned enough
# highest attention: ' as if not
#
#
#
# 입력 문장: I've been to this place often, and I love that there's a cafe like this in the neighborhood!! The interior is clean, the coffee is delicious, and corn cheese toast is especially delicious!!
# 분류: Positive
# MAX_LEN:  46
# ========================= emphasize by attention result==========================
# i ' ve been to this place often , and i love that there ' s a cafe like this in the neighborhood ! ! the interior is clean , the coffee is delicious , and corn cheese toast is especially delicious ! !
# highest attention: ' ' cafe to
#
#
#
# 입력 문장: I thought it was expensive as soon as I entered. But it was the most delicious thing I had this year. I'm going to have a good hangover
# 분류: Positive
# MAX_LEN:  35
# ========================= emphasize by attention result==========================
# i thought it was expensive as soon as i entered . but it was the most delicious thing i had this year . i ' m going to have a good hang ##over
# highest attention: ' expensive thought was
#
#
#
# 입력 문장: It's good. It's been a while, so the price went up
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it ' s good . it ' s been a while , so the price went up
# highest attention: ' s up it
#
#
#
# 입력 문장: It's so delicious.~~~. However, the employees are not very kind.
# 분류: Positive
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# it ' s so delicious . ~ ~ ~ . however , the employees are not very kind .
# highest attention: ' s it delicious
#
#
#
# 입력 문장: I ordered two and shared them with my sister. Both of them were so good I don't know if it's the owner, but the employee is so kind Enjoy your meal
# 분류: Positive
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# i ordered two and shared them with my sister . both of them were so good i don ' t know if it ' s the owner , but the employee is so kind enjoy your meal
# highest attention: ' ' i so
#
#
#
# 입력 문장: Everyone is kind and the cocktails are so delicious! Thank you for the free shot you gave me as a dart event. It was better because the bathroom was so clean and it didn't smell
# 분류: Positive
# MAX_LEN:  42
# ========================= emphasize by attention result==========================
# everyone is kind and the cocktail ##s are so delicious ! thank you for the free shot you gave me as a dart event . it was better because the bathroom was so clean and it didn ' t smell
# highest attention: ' was didn the
#
#
#
# 입력 문장: Sweet and sour chicken is so delicious.. They cool it down and wrap it up.. The cold gangjeong style...The batter is crispy and it tastes so good.It's real..
# 분류: Positive
# MAX_LEN:  47
# ========================= emphasize by attention result==========================
# sweet and sour chicken is so delicious . . they cool it down and wrap it up . . the cold gang ##je ##ong style . . . the batter is crisp ##y and it tastes so good . it ' s real . .
# highest attention: ' chicken batter sour
#
#
#
# 입력 문장: Even though it was past lunch time, there was a bit of waiting, but the soup and noodle ingredients were so good as I wanted to come back next time, and it was more delicious with kimchi
# 분류: Positive
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# even though it was past lunch time , there was a bit of waiting , but the soup and no ##odle ingredients were so good as i wanted to come back next time , and it was more delicious with kim ##chi
# highest attention: so bit ##chi waiting
#
#
#
# 입력 문장: The standby system is well-equipped and has a high turnover, so I got in quickly in! I come here regularly because my parents like it! It's good
# 분류: Positive
# MAX_LEN:  37
# ========================= emphasize by attention result==========================
# the stand ##by system is well - equipped and has a high turnover , so i got in quickly in ! i come here regularly because my parents like it ! it ' s good
# highest attention: ' turnover equipped is
#
#
#
# 입력 문장: Although there was a bit of a wait for the weekend. Egg Benedict was so delicious. I want to sit in the outdoor seat on a fine day
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# although there was a bit of a wait for the weekend . egg benedict was so delicious . i want to sit in the outdoor seat on a fine day
# highest attention: so was although delicious
#
#
#
# 입력 문장: I visited because I wanted to eat strawberry dessert. Maybe because it's famous, there are a lot of people even during the day on weekdays. It's expensive, but it tastes good
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# i visited because i wanted to eat strawberry dessert . maybe because it ' s famous , there are a lot of people even during the day on weekdays . it ' s expensive , but it tastes good
# highest attention: ' ' good tastes
#
#
#
# 입력 문장: Even though I waited for 20 minutes and ate alone, they were kind and the food was good without any smell.. It's cost-effective and the radish kimchi is always delicious, so the soup is delicious and a healthy meal is the best
# 분류: Positive
# MAX_LEN:  55
# ========================= emphasize by attention result==========================
# even though i waited for 20 minutes and ate alone , they were kind and the food was good without any smell . . it ' s cost - effective and the ra ##dis ##h kim ##chi is always delicious , so the soup is delicious and a healthy meal is the best
# highest attention: ' 20 soup food
#
#
#
# 입력 문장: It's so good here... But it's hard to wait, so I'm going to wrap it up now.. I'd like you to change it to a waiting machine! It's so uncomfortable to have to wait in front of the storecrying
# 분류: Positive
# MAX_LEN:  60
# ========================= emphasize by attention result==========================
# it ' s so good here . . . but it ' s hard to wait , so i ' m going to wrap it up now . . i ' d like you to change it to a waiting machine ! it ' s so uncomfortable to have to wait in front of the store ##cr ##ying
# highest attention: ' ' ' '
#
#
#
# 입력 문장: Even though it was a weekday evening, the atmosphere was amazing.. But Sundaeguk was so delicious that I could endure and wait. I want to eat it with soju next time! I did it again today!
# 분류: Positive
# MAX_LEN:  48
# ========================= emphasize by attention result==========================
# even though it was a weekday evening , the atmosphere was amazing . . but sun ##dae ##gu ##k was so delicious that i could endure and wait . i want to eat it with so ##ju next time ! i did it again today !
# highest attention: to so atmosphere i
#
#
#
# 입력 문장: I've been waiting for 40 minutes for lunch on Saturday It wasn't enough But it's not greasy and it's
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# i ' ve been waiting for 40 minutes for lunch on saturday it wasn ' t enough but it ' s not greasy and it ' s
# highest attention: ' ' ' greasy
#
#
#
# 입력 문장: I broke my promise with my friend to eat something simple Salted pollack pasta is so delicious and lasagna is the best    It makes me think that I'm home Strongly recommended
# 분류: Positive
# MAX_LEN:  39
# ========================= emphasize by attention result==========================
# i broke my promise with my friend to eat something simple salt ##ed poll ##ack pasta is so delicious and las ##ag ##na is the best it makes me think that i ' m home strongly recommended
# highest attention: ' salt pasta promise
#
#
#
# 입력 문장: I really enjoyed breakfast in Seoul! Braised hairtail is good, but the cheonggukjang is really good The free steamed eggs and fried hairtail were also delicious I want to visit again
# 분류: Positive
# MAX_LEN:  43
# ========================= emphasize by attention result==========================
# i really enjoyed breakfast in seoul ! bra ##ised hair ##tail is good , but the che ##ong ##gu ##k ##jan ##g is really good the free steamed eggs and fried hair ##tail were also delicious i want to visit again
# highest attention: seoul bra breakfast ##ised
#
#
#
# 입력 문장: Braised hairtail in line. It was delicious. I was a little distracted, but the four Chinese family members at the next table right next to me had such a good voice
# 분류: Positive
# MAX_LEN:  38
# ========================= emphasize by attention result==========================
# bra ##ised hair ##tail in line . it was delicious . i was a little distracted , but the four chinese family members at the next table right next to me had such a good voice
# highest attention: distracted bra in ##ised
#
#
#
# 입력 문장: The taste is soft and very delicious.. They were very kind and gave us a service. I strongly recommend it.
# 분류: Positive
# MAX_LEN:  26
# ========================= emphasize by attention result==========================
# the taste is soft and very delicious . . they were very kind and gave us a service . i strongly recommend it .
# highest attention: very is very soft
#
#
#
# 입력 문장: It's a sandwich I often eat for a meal and it's always delicious and filling :) The vegetables are fresh and the bread is delicious. The staff is also kind, so I use it often
# 분류: Positive
# MAX_LEN:  44
# ========================= emphasize by attention result==========================
# it ' s a sandwich i often eat for a meal and it ' s always delicious and filling : ) the vegetables are fresh and the bread is delicious . the staff is also kind , so i use it often
# highest attention: ' ' sandwich bread
#
#
#
# 입력 문장: The bread is chewy. It's delicious. It hasn't been long since it opened, so the baker's. I think it's more passionate.. . Warm bread made by warm people. Try it~~^^
# 분류: Positive
# MAX_LEN:  52
# ========================= emphasize by attention result==========================
# the bread is chew ##y . it ' s delicious . it hasn ' t been long since it opened , so the baker ' s . i think it ' s more passionate . . . warm bread made by warm people . try it ~ ~ ^ ^
# highest attention: ' ' ' bread
#
#
#
# 입력 문장: The quality of the meat and the tempura are very fresh and delicious.. I can't help but write a review... Thank you!
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# the quality of the meat and the te ##mp ##ura are very fresh and delicious . . i can ' t help but write a review . . . thank you !
# highest attention: ' i meat very
#
#
#
# 입력 문장: It's kind and the oil is clean and crispy and delicious The members really liked it The delivery time is a bit long, so I think I need to order it in advance That's the only thing that's unfortunate
# 분류: Positive
# MAX_LEN:  49
# ========================= emphasize by attention result==========================
# it ' s kind and the oil is clean and crisp ##y and delicious the members really liked it the delivery time is a bit long , so i think i need to order it in advance that ' s the only thing that ' s unfortunate
# highest attention: ' ' ' oil
#
#
#
# 입력 문장: The cost-effectiveness is the best and it's so delicious..
# 분류: Positive
# MAX_LEN:  17
# ========================= emphasize by attention result==========================
# the cost - effectiveness is the best and it ' s so delicious . .
# highest attention: cost ' is s
#
#
#
# 입력 문장: It was a little noisy because there were many students and the music was loud, but it was okay because the snacks were delicious and the price was reasonable
# 분류: Positive
# MAX_LEN:  32
# ========================= emphasize by attention result==========================
# it was a little noisy because there were many students and the music was loud , but it was okay because the snacks were delicious and the price was reasonable
# highest attention: loud were reasonable was
#
#
#
# 입력 문장: Except when there are a lot of people, it's loud enough to make people's ears ring with the sound of music... The food is delicious and inexpensive, and even the thin ice of beer is very good!
# 분류: Positive
# MAX_LEN:  49
# ========================= emphasize by attention result==========================
# except when there are a lot of people , it ' s loud enough to make people ' s ears ring with the sound of music . . . the food is delicious and inexpensive , and even the thin ice of beer is very good !
# highest attention: ' music with loud
#
#
#
# 입력 문장: They are kind and the drinks are delicious. It would be better if the store was a little bigger
# 분류: Positive
# MAX_LEN:  22
# ========================= emphasize by attention result==========================
# they are kind and the drinks are delicious . it would be better if the store was a little bigger
# highest attention: drinks are kind delicious
#
#
#
# 입력 문장: The meat is so goodIt's my first time in Pyeongtaek, and thanks to you, I have a good memory. They grill meat themselves, and they're all so nice and kind
# 분류: Positive
# MAX_LEN:  45
# ========================= emphasize by attention result==========================
# the meat is so good ##it ' s my first time in p ##ye ##ong ##ta ##ek , and thanks to you , i have a good memory . they grill meat themselves , and they ' re all so nice and kind
# highest attention: ' ' meat in
#
#
#
# 입력 문장: The pork belly was really good, but the pork neck was crazy!!! I'm amazed as soon as I eat it Do you really recommend it!!!! It's so nice that the staff cooked it deliciously. I'll save it as a good restaurant
# 분류: Positive
# MAX_LEN:  59
# ========================= emphasize by attention result==========================
# the pork belly was really good , but the pork neck was crazy ! ! ! i ' m amazed as soon as i eat it do you really recommend it ! ! ! ! it ' s so nice that the staff cooked it delicious ##ly . i ' ll save it as a good restaurant
# highest attention: crazy ' ' '
#
#
#
# 입력 문장: He was kind and the drink was very delicious! The side tastes good, too
# 분류: Positive
# MAX_LEN:  18
# ========================= emphasize by attention result==========================
# he was kind and the drink was very delicious ! the side tastes good , too
# highest attention: drink very he kind
#
#
#
# 입력 문장: Parking is a little inconvenient, but the atmosphere of the store is so good and all the menus are delicious :)
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# parking is a little inc ##on ##ven ##ient , but the atmosphere of the store is so good and all the menu ##s are delicious : )
# highest attention: parking little ##ient inc
#
#
#
# 입력 문장: It was good because there was a lot. They gave me a big piece of high quality meat and the jjajo was really good.
# 분류: Positive
# MAX_LEN:  30
# ========================= emphasize by attention result==========================
# it was good because there was a lot . they gave me a big piece of high quality meat and the jj ##aj ##o was really good .
# highest attention: jj meat there it
#
#
#
# 입력 문장: The food is delicious and clean! And he was very kind. Maybe that's why there were a lot of customers
# 분류: Positive
# MAX_LEN:  26
# ========================= emphasize by attention result==========================
# the food is delicious and clean ! and he was very kind . maybe that ' s why there were a lot of customers
# highest attention: ' customers food is
#
#
#
# 입력 문장: It's incredibly unkind. It tastes good. Green onion recommendation
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# it ' s incredibly un ##kind . it tastes good . green onion recommendation
# highest attention: ##kind un ' green
#
#
#
# 입력 문장: The food is delicious but not kind
# 분류: Positive
# MAX_LEN:  9
# ========================= emphasize by attention result==========================
# the food is delicious but not kind
# highest attention: food is the delicious
#
#
#
# 입력 문장: The owner is kind, the drinks are good, and the interior of the store is pretty
# 분류: Positive
# MAX_LEN:  20
# ========================= emphasize by attention result==========================
# the owner is kind , the drinks are good , and the interior of the store is pretty
# highest attention: drinks owner kind is
#
#
#
# 입력 문장: The grain powder taste is good.. But... the two working women are very unkind. You seem to be very dissatisfied with society as to what's upsetting about you.
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# the grain powder taste is good . . but . . . the two working women are very un ##kind . you seem to be very dissatisfied with society as to what ' s upset ##ting about you .
# highest attention: ' dissatisfied good is
#
#
#
# 입력 문장: It's so good. The food is really good and it comes out clean. Above all, the staff are so kind!! There's always a lot of waiting, but it's inevitable that there's a lot of waitingㅠ
# 분류: Positive
# MAX_LEN:  51
# ========================= emphasize by attention result==========================
# it ' s so good . the food is really good and it comes out clean . above all , the staff are so kind ! ! there ' s always a lot of waiting , but it ' s inevitable that there ' s a lot of [UNK]
# highest attention: ' ' ' '
#
#
#
# 입력 문장: Instant tteokbokki is good. I put in the noodles and the last fried rice
# 분류: Positive
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# instant tt ##eo ##k ##bo ##kki is good . i put in the noodles and the last fried rice
# highest attention: tt rice instant put
#
#
#
# 입력 문장: The owner is kind and the side dish is very delicious! There's a variety of drinks, so it's fun to choose one every time you go
# 분류: Positive
# MAX_LEN:  34
# ========================= emphasize by attention result==========================
# the owner is kind and the side dish is very delicious ! there ' s a variety of drinks , so it ' s fun to choose one every time you go
# highest attention: ' ' side owner
#
#
#
# 입력 문장: The atmosphere is good and the taste is good!! However, as the hall was full, it was a little noisy and the air was hot, too. :-( It was too bad
# 분류: Positive
# MAX_LEN:  41
# ========================= emphasize by attention result==========================
# the atmosphere is good and the taste is good ! ! however , as the hall was full , it was a little noisy and the air was hot , too . : - ( it was too bad
# highest attention: was it atmosphere is
#
#
#
# 입력 문장: It's delicious and kind. I am happy that there is a bar in the neighborhood where I can drink various traditional liquor. It's a place where you have to wait because it's a place where you have to wait.
# 분류: Positive
# MAX_LEN:  50
# ========================= emphasize by attention result==========================
# it ' s delicious and kind . i am happy that there is a bar in the neighborhood where i can drink various traditional liquor . it ' s a place where you have to wait because it ' s a place where you have to wait .
# highest attention: ' ' ' bar
#
#
#
# 입력 문장: It's as delicious as it's rumored. I think it's a bit expensive
# 분류: Positive
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# it ' s as delicious as it ' s rumored . i think it ' s a bit expensive
# highest attention: ' ' bit it
#
#
#
# 입력 문장: The food is really good. I knew why it was so famous. Mackerel sushi is really good, but there are no pictures!It's so good
# 분류: Positive
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# the food is really good . i knew why it was so famous . mack ##ere ##l su ##shi is really good , but there are no pictures ! it ' s so good
# highest attention: ' food good really
#
#
#
# 입력 문장: I really enjoyed the meal! It was the most delicious place I've ever been to. I'll go again later
# 분류: Positive
# MAX_LEN:  27
# ========================= emphasize by attention result==========================
# i really enjoyed the meal ! it was the most delicious place i ' ve ever been to . i ' ll go again later
# highest attention: ' ' meal i
#
#
#
# 입력 문장: It's good, but the staff members are kind... I understand if it's because you're busy..
# 분류: Positive
# MAX_LEN:  29
# ========================= emphasize by attention result==========================
# it ' s good , but the staff members are kind . . . i understand if it ' s because you ' re busy . .
# highest attention: ' ' ' kind
#
#
#
# 입력 문장: It's clean and delicious. It's a shame that the price went up
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it ' s clean and delicious . it ' s a shame that the price went up
# highest attention: up ' price s
#
#
#
# 입력 문장: The food was delicious and the staff were very kind, so I had a nice meal. It's nice to have a seat for Da-Ji!
# 분류: Positive
# MAX_LEN:  33
# ========================= emphasize by attention result==========================
# the food was delicious and the staff were very kind , so i had a nice meal . it ' s nice to have a seat for da - ji !
# highest attention: ' staff food -
#
#
#
# 입력 문장: I can't say it's cheap and the waiting is long. A taste I want to go again!! The ingredients are fresh and it tastes healthy and delicious!
# 분류: Positive
# MAX_LEN:  37
# ========================= emphasize by attention result==========================
# i can ' t say it ' s cheap and the waiting is long . a taste i want to go again ! ! the ingredients are fresh and it tastes healthy and delicious !
# highest attention: ' cheap ' waiting
#
#
#
# 입력 문장: It's a bit pricey, but it's good
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# it ' s a bit price ##y , but it ' s good
# highest attention: bit a s it
#
#
#
# 입력 문장: It's good. It's not that sweet. It's really good
# 분류: Positive
# MAX_LEN:  19
# ========================= emphasize by attention result==========================
# it ' s good . it ' s not that sweet . it ' s really good
# highest attention: ' s it really
#
#
#
# 입력 문장: I had a preconceived notion that it was vegan, but it's more delicious than other regular breads!!  The bread is more chewy and delicious, so I'm going to revisit it!!
# 분류: Positive
# MAX_LEN:  51
# ========================= emphasize by attention result==========================
# i had a pre ##con ##ce ##ive ##d notion that it was vega ##n , but it ' s more delicious than other regular bread ##s ! ! the bread is more chew ##y and delicious , so i ' m going to rev ##isi ##t it ! !
# highest attention: ' ' vega that
#
#
#
# 입력 문장: The owner is so kind and it's a vegan bakery, so it's unique and so delicious!! Especially, tofu brownies are the best!^^^♡
# 분류: Positive
# MAX_LEN:  40
# ========================= emphasize by attention result==========================
# the owner is so kind and it ' s a vega ##n bakery , so it ' s unique and so delicious ! ! especially , to ##fu brown ##ies are the best ! ^ ^ ^ [UNK]
# highest attention: ' ' bakery vega
#
#
#
# 입력 문장: It's cost-effective and the ingredients are fresh and delicious
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# it ' s cost - effective and the ingredients are fresh and delicious
# highest attention: ' s it ingredients
#
#
#
# 입력 문장: There's a lot and it'sI hope it's controlled
# 분류: Positive
# MAX_LEN:  16
# ========================= emphasize by attention result==========================
# there ' s a lot and it ' si hope it ' s controlled
# highest attention: controlled ' lot and
#
#
#
# 입력 문장: The staff are so kind. I enjoyed my meal, too!
# 분류: Positive
# MAX_LEN:  15
# ========================= emphasize by attention result==========================
# the staff are so kind . i enjoyed my meal , too !
# highest attention: staff so kind are
#
#
#
# 입력 문장: Fresh ingredients. Thank you for the food
# 분류: Positive
# MAX_LEN:  10
# ========================= emphasize by attention result==========================
# fresh ingredients . thank you for the food
# highest attention: ingredients fresh thank you
#
#
#
# 입력 문장: The staff is kind and it tastes better with Tabasco sauce that you recommended!!! I went alone, and it's nice to enjoy delicious food and relaxation♥
# 분류: Positive
# MAX_LEN:  36
# ========================= emphasize by attention result==========================
# the staff is kind and it tastes better with tab ##asco sauce that you recommended ! ! ! i went alone , and it ' s nice to enjoy delicious food and relaxation ##♥
# highest attention: ' staff i tastes
#
#
#
# 입력 문장: It's good. But it's small and they didn't give me a fork
# 분류: Positive
# MAX_LEN:  21
# ========================= emphasize by attention result==========================
# it ' s good . but it ' s small and they didn ' t give me a fork
# highest attention: ' ' didn good
